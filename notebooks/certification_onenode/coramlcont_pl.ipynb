# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt
from pathlib import Path

# %%
exp = dict(
    collection = "l_coramlcont_n10_pl",
    start_id = 1,
    end_id = 2520,
    n_seeds = 3,
)

attack_nodes = "train_val"
postfix = ""
savedir = Path("./figures")
delta_l = [0, 0.01, 0.02, 0.05]
n_adv_l = [140]
#print("hellos")
experiments = [exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# Loading 500th experiment...
# Loading 1000th experiment...
# Loading 1500th experiment...
# Loading 2000th experiment...
# Loading 2500th experiment...

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})
savedir = Path("./figures")

# %%
C_l = None
plt.close("all")
delta_l = [0, 0.01, 0.02, 0.05]
models = ["GCN", "SGC", "MLP", "APPNP", "GCN_skipalpha", "GCN_skippc", "GraphSAGE", "GIN"]
legend_labels = ["GCN", "SGC", "MLP", "APPNP", "GCN_skipalpha", "GCN_skippc", "GraphSAGE", "GIN"]
pert_model = "l2"
label_fontsize = 22
legend_fontsize = 16
ticks_fontsize = 12
savefig = "coraml_pl_l2_nadv140" + postfix + ".pdf"
linewidth = 1.5
markersize = 6
capsize = 6
framealpha = 0.5
experiment_manager.plot_robust_acc_delta_v2(models, C_l, attack_nodes, 
                                         legend_labels=legend_labels,
                                         n_adv=140, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=framealpha)

# %%
C_l = [0.0575,0.004,0.05]
n_adv = n_adv_l[0]
experiment_manager.plot_robust_acc_delta(["GCN","SGC", "APPNP"], C_l, "test", n_adv, delta_l, spacing="even")
# Out:
# ['GCN', 'APPNP', 'SGC']
# {'GCN': {0.05: {'test': {142: {0.01: <utils.Experiment object at 0x7feb037c2010>, 0.02: <utils.Experiment object at 0x7feae4ad2010>, 0.05: <utils.Experiment object at 0x7feae412f990>}}}}, 'APPNP': {0.004: {'test': {142: {0.01: <utils.Experiment object at 0x7feae4a37d10>, 0.02: <utils.Experiment object at 0x7feacdf49390>, 0.05: <utils.Experiment object at 0x7feacdf9fa50>}}}}, 'SGC': {0.0575: {'test': {142: {0.01: <utils.Experiment object at 0x7feae4133750>, 0.02: <utils.Experiment object at 0x7feacdeb6150>, 0.05: <utils.Experiment object at 0x7feacdd2d010>}}}}}
# ...

# %%
C_l = [0.00350]
experiment_manager.plot_robust_acc_delta(["GCN"], C_l, "test", 128, [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5], spacing="even")

# %%
experiment_manager.print_clean_acc(["GCN"], [0.001, 0.002, 0.003, 0.004, 0.005, 0.0075],
                                   "test", 256, 0.01)
# Out:
# GCN C=0.00100 Target Acc. 0.729+-0.012
# GCN C=0.00200 Target Acc. 0.733+-0.007
# GCN C=0.00300 Target Acc. 0.767+-0.037
# GCN C=0.00400 Target Acc. 0.810+-0.047
# GCN C=0.00500 Target Acc. 0.824+-0.047
# GCN C=0.00750 Target Acc. 0.810+-0.044

# %%
experiment_manager.print_cert_ratio(["GCN"], [0.001, 0.002, 0.003, 0.004, 0.005, 0.0075],
                                   "test", 256, 0.01)
# Out:
# 70 70
# 70 70
# 70 70
# GCN C=0.00100 Cert. Ratio 0.824+-0.024
# 70 70
# 70 70
# 70 70
# GCN C=0.00200 Cert. Ratio 0.824+-0.024
# 70 70
# 70 70
# 70 70
# GCN C=0.00300 Cert. Ratio 0.781+-0.044
# 70 70
# 70 70
# 70 70
# GCN C=0.00400 Cert. Ratio 0.757+-0.040
# 70 70
# 70 70
# 70 70
# GCN C=0.00500 Cert. Ratio 0.748+-0.036
# 70 70
# 70 70
# 70 70
# GCN C=0.00750 Cert. Ratio 0.776+-0.036

# %%
experiment_manager.get_test_acc(["GCN"], [0.001, 0.002, 0.003, 0.004, 0.005, 0.0075],
                                   "test", 256, 0.01)
# Out:
# GCN C=0.00100 Cert. Ratio 0.729+-0.012
# GCN C=0.00200 Cert. Ratio 0.733+-0.007
# GCN C=0.00300 Cert. Ratio 0.767+-0.037
# GCN C=0.00400 Cert. Ratio 0.810+-0.047
# GCN C=0.00500 Cert. Ratio 0.824+-0.047
# GCN C=0.00750 Cert. Ratio 0.810+-0.044

# %%
C_l = [0.001, 0.002, 0.003, 0.004, 0.005, 0.0075]
experiment_manager.plot_robust_acc_delta(["GCN"], C_l, "test", 256, [0, 0.01])

# %%
C_l = [0.003, 0.0075]
experiment_manager.plot_robust_acc_delta(["GCN"], C_l, "test", 256, [0, 0.01])

# %%
C_l = [0.003, 0.0075]
experiment_manager.plot_robust_acc_delta(["GCN"], C_l, "test", 256, [0.01, 0.02, 0.05, 0.1, 0.2, 0.5], spacing="log")
# Out:
# /ceph/ssd/staff/gosl/src/ntk-robust/notebooks/certification_onenode/utils.py:402: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   ax.set_xlim(left=-0.3)

# %%
C_l = [0.003]
experiment_manager.plot_robust_acc_delta(["GCN"], C_l, "test", 128, [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5])

# %%
C_l = [0.003]
experiment_manager.plot_robust_acc_delta(["GCN"], C_l, "test", 1284, [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5])

# %%
C_l = [0.003]
experiment_manager.plot_robust_acc_delta(["GCN"], C_l, "test", 12, [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5])

# %%
C_l = [0.003, 0.0075]
experiment_manager.plot_robust_acc_delta(["GCN"], C_l, "test", 256, [0.01, 0.02, 0.05, 0.1, 0.2, 0.5],
                                         spacing="log")

# %%
C_l = [0.001, 0.002, 0.003, 0.004, 0.005, 0.0075]
experiment_manager.plot_robust_acc_delta(["GCN"], C_l, "test", 256, [0.01, 0.02, 0.05, 0.1, 0.2, 0.5])

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})

# %%
C_l = [0.01]
experiment_manager.plot_robust_acc_delta_nadv(K, ["GCN"], C_l, attack_nodes, 
                                              n_adv_l=n_adv_l, delta_l=delta_l)

# %%
C_l = [0.01]
experiment_manager.plot_robust_acc_delta_nadv(K, ["GCN_l2"], C_l, attack_nodes, 
                                              n_adv_l=n_adv_l, delta_l=delta_l)

# %%
C_l = [0.01]
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
models = ["GCN", "GCN_l2"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.01]
models = ["GCN", "APPNP", "APPNP_alpha0", "APPNP_alpha0.1", "APPNP_alpha0.3", "APPNP_alpha0.5", "APPNP_alpha1"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.01]
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2]
models = ["GCN", "SGC", "APPNP", "APPNP_alpha0.3", "APPNP_alpha0.5", "APPNP_alpha1"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.01]
delta_l = [0, 0.01, 0.02, 0.05]
models = ["GCN", "SGC", "APPNP", "APPNP_alpha0.3", "APPNP_alpha0.5", "APPNP_alpha1"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=120, delta_l=delta_l)

# %%
C_l = [0.01]
models = ["GCN", "APPNP", "APPNP_alpha0", "APPNP_alpha0.1", "APPNP_alpha0.3", "APPNP_alpha0.5", "APPNP_alpha1"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=60, delta_l=delta_l)

# %%
C_l = [0.01]
models = ["GCN", "APPNP", "APPNP_alpha0.1", "GCN_skippc", "SGC"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.1, 0.01, 0.001]
experiment_manager.plot_robust_acc_delta(K, ["GCN"], C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.01, 0.001]
experiment_manager.plot_robust_acc_delta(K, ["APPNP"], C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.01]
models = ["SGC", "SGC_depth2", "SGC_depth4"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.01]
models = ["SGC", "SGC_depth2", "SGC_depth4"]
n_adv_list = [12, 24]
experiment_manager.plot_robust_acc_delta_nadv(K, models, C_l, attack_nodes, 
                                              n_adv_l=n_adv_list, delta_l=delta_l)

# %%
C = 0.01
experiment_manager.plot_nadv_delta_heatmap(K, ["GCN"], C, 
                              attack_nodes, n_adv_l, delta_l[::-1],
                              width=1, ratio=1.5, cbar_normalized=True)

# %%
C = 0.01
experiment_manager.plot_nadv_delta_heatmap(K, ["GCN"], C, 
                              attack_nodes, n_adv_l, delta_l[::-1],
                              width=1, ratio=1.5, cbar_normalized=True)

# %%
C = 0.01
experiment_manager.plot_nadv_delta_heatmap(K, ["APPNP"], C, 
                              attack_nodes, n_adv_l, delta_l[::-1],
                              width=1, ratio=1.5, cbar_normalized=True)

# %%
C = 0.01
experiment_manager.plot_nadv_delta_heatmap(K, ["SGC"], C, 
                              attack_nodes, n_adv_l, delta_l[::-1],
                              width=1, ratio=1.5, cbar_normalized=True)

# %%
C = 0.01
experiment_manager.plot_nadv_delta_heatmap(K, ["GCN_skippc"], C, 
                              attack_nodes, n_adv_l, delta_l[::-1],
                              width=1, ratio=1.5, cbar_normalized=True)
