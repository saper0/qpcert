# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt

# %%
label_fontsize = 24 #20 #29
legend_fontsize = 14 #12 #14
ticks_fontsize = 14 #12 #14
use_custom_legend = True
linewidth = 1.3 #1.2 #1.5
markersize = 4 #6
capsize = 4 #6
framealpha = 0.5

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})

# %% [markdown]
# ## Collective cert

# %%
gcn_coll_exp = dict(
    label = "GCN",
    # relabel = "GCN_coll",
    collection = "m_label_collect_cba_gcn",
    start_id = 1,
    end_id = 40,
    n_seeds = 5,
)
gcn_depth2_coll_exp = dict(
    label = "GCN_depth2",
    # relabel = "GCN_depth2_coll",
    collection = "m_label_collect_cba_gcn",
    start_id = 41,
    end_id = 80,
    n_seeds = 5,
)
gcn_depth4_coll_exp = dict(
    label = "GCN_depth4",
    # relabel = "GCN_depth4_coll",
    collection = "m_label_collect_cba_gcn",
    start_id = 81,
    end_id = 120,
    n_seeds = 5,
)
sgc_coll_exp = dict(
    label = "SGC",
    # relabel = "SGC_coll",
    collection = "m_label_collect_cba_sgc",
    start_id = 1,
    end_id = 40,
    n_seeds = 5,
)
sgc_depth2_coll_exp = dict(
    label = "SGC_depth2",
    # relabel = "SGC_depth2_coll",
    collection = "m_label_collect_cba_sgc",
    start_id = 41,
    end_id = 80,
    n_seeds = 5,
)
sgc_depth4_coll_exp = dict(
    label = "SGC_depth4",
    # relabel = "SGC_depth4_coll",
    collection = "m_label_collect_cba_sgc",
    start_id = 81,
    end_id = 120,
    n_seeds = 5,
)
appnp_alp03_coll_exp = dict(
    label = "APPNP_0.3",
    relabel = "APPNP",
    collection = "m_label_collect_cba_appnp",
    start_id = 1,
    end_id = 40,
    n_seeds = 5,
)
mlp_coll_exp = dict(
    label = "MLP",
    # relabel = "APPNP_linear_alpha1_coll",
    collection = "m_label_collect_cba_appnp",
    start_id = 41,
    end_id = 80,
    n_seeds = 5,
)
gin_coll_exp = dict(
    label = "GIN",
    # relabel = "",
    collection = "m_label_collect_cba_gin",
    start_id = 1,
    end_id = 40,
    n_seeds = 5,
)
gsage_coll_exp = dict(
    label = "GraphSAGE",
    # relabel = "",
    collection = "m_label_collect_cba_graphsage",
    start_id = 1,
    end_id = 40,
    n_seeds = 5,
)
gsage_d2_coll_exp = dict(
    label = "GraphSAGE_depth2",
    # relabel = "",
    collection = "m_label_collect_cba_graphsage",
    start_id = 41,
    end_id = 80,
    n_seeds = 5,
)
gsage_d4_coll_exp = dict(
    label = "GraphSAGE_depth4",
    # relabel = "",
    collection = "m_label_collect_cba_graphsage",
    start_id = 81,
    end_id = 120,
    n_seeds = 5,
)
skippc_coll_exp = dict(
    label = "GCN_skippc_linear",
    relabel = "GCN_skippc",
    collection = "m_label_collect_cba_gcn_skippc",
    start_id = 1,
    end_id = 40,
    n_seeds = 5,
)
skippc_depth2_coll_exp = dict(
    label = "GCN_skippc_linear_depth2",
    # relabel = "",
    collection = "m_label_collect_cba_gcn_skippc",
    start_id = 41,
    end_id = 80,
    n_seeds = 5,
)
skippc_depth4_coll_exp = dict(
    label = "GCN_skippc_linear_depth4",
    # relabel = "",
    collection = "m_label_collect_cba_gcn_skippc",
    start_id = 81,
    end_id = 120,
    n_seeds = 5,
)
skipalpha_coll_exp = dict(
    label = "GCN_skipalpha_linear",
    relabel = "GCN_skipalpha",
    collection = "m_label_collect_cba_gcn_skipalpha",
    start_id = 1,
    end_id = 40,
    n_seeds = 5,
)
skipalpha_d2_coll_exp = dict(
    label = "GCN_skipalpha_linear_depth2",
    # relabel = "",
    collection = "m_label_collect_cba_gcn_skipalpha",
    start_id = 41,
    end_id = 80,
    n_seeds = 5,
)
skipalpha_d4_coll_exp = dict(
    label = "GCN_skipalpha_linear_depth4",
    # relabel = "",
    collection = "m_label_collect_cba_gcn_skipalpha",
    start_id = 81,
    end_id = 120,
    n_seeds = 5,
)
K = 1.5
delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.5, 1]

# %% [markdown]
# ## GNNs

# %%
experiments = [
                gcn_coll_exp, gcn_depth2_coll_exp, gcn_depth4_coll_exp,
                sgc_coll_exp, sgc_depth2_coll_exp, sgc_depth4_coll_exp,
                appnp_alp03_coll_exp, 
                mlp_coll_exp, 
                gin_coll_exp, 
                gsage_coll_exp, #gsage_d2_coll_exp, gsage_d4_coll_exp,
                skippc_coll_exp, skippc_depth2_coll_exp, skippc_depth4_coll_exp,
                skipalpha_coll_exp, skipalpha_d2_coll_exp, skipalpha_d4_coll_exp
                ]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN No. of experiments 8
# GCN_depth2 No. of experiments 8
# GCN_depth4 No. of experiments 8
# SGC No. of experiments 8
# SGC_depth2 No. of experiments 8
# SGC_depth4 No. of experiments 8
# APPNP_0.3 No. of experiments 8
# MLP No. of experiments 8
# GIN No. of experiments 8
# GraphSAGE No. of experiments 8
# GCN_skippc_linear No. of experiments 8
# GCN_skippc_linear_depth2 No. of experiments 8
# GCN_skippc_linear_depth4 No. of experiments 8
# GCN_skipalpha_linear No. of experiments 8
# GCN_skipalpha_linear_depth2 No. of experiments 8
# GCN_skipalpha_linear_depth4 No. of experiments 8

# %%
C_l = None
models = ["GCN", "SGC", "APPNP", 
"GIN", 
"GraphSAGE", 
"GCN_skipalpha", 
"GCN_skippc", "MLP",
          ]
legend_labels = ["GCN", "SGC", "APPNP", 
"GIN", 
"GraphSAGE", 
"GCN Skip-$\\alpha$", 
"GCN Skip-PC", "MLP",]
savefig = "cba_n10_collective.pdf"
linewidth = 1.2
markersize = 5
capsize = 5
label_fontsize = 24
legend_fontsize = 16
ticks_fontsize = 16
use_custom_legend = True
legend_args = dict(
    framealpha = 0.5,
    handlelength = 1.5,
    handletextpad = 0.5,
    labelspacing = 0.3,
    loc="lower left",
    #bbox_to_anchor=(0.60,.49),
    bbox_to_anchor=(0.33,.58),
    ncol=2,
    columnspacing=0.3,
    #columnspacing=1
)

experiment_manager.plot_robust_acc_delta_v2(K,models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels,
                                        label_fontsize=label_fontsize,
                                        legend_fontsize=legend_fontsize,
                                        ticks_fontsize=ticks_fontsize,
                                        markersize=markersize,
                                        capsize=capsize,
                                        linewidth=linewidth,
                                        legend_args=legend_args,
                                         savefig=savefig,
                                         use_custom_legend=True,
                                         certified_acc=False
                                        )

# %%
C_l = None
models = ["GCN", "SGC", "APPNP_0.3", 
"GIN", 
"GraphSAGE", 
"GCN_skipalpha_linear", 
"GCN_skippc_linear",
         "MLP", ]
legend_labels = ["GCN", "SGC", "APPNP", 
"GIN", 
"GraphSAGE", 
"GCN Skip-$\\alpha$", 
"GCN Skip-PC", "MLP",]
# savefig = "sbm_n10_collective.pdf"
experiment_manager.rank_models(K, models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels,
                                         weak_threshold=0.1, intermediate_threshold=0.25, 
                                         decimal_round_off = 2
                                        #  xlogscale=False,
                                        #  savefig=savefig,
                                        #  label_fontsize=label_fontsize,
                                        # legend_fontsize=legend_fontsize,
                                        # ticks_fontsize=ticks_fontsize,
                                        # markersize=markersize,
                                        # capsize=capsize,
                                        # linewidth=linewidth,
                                        # framealpha=framealpha,
                                        )
# Out:
#                model  0 0.05 0.1 0.15 0.2 0.25 0.3 0.5  1  weak intermediate  \
# 0                GCN  3    4   5    5   5    2   2   6  1   4.0          4.0
# 1                SGC  1    1   1    1   1    1   6   8  1   1.0          1.0
# 2              APPNP  6    7   4    3   6    5   1   1  1  5.67         4.67
# 3                GIN  7    6   6    7   7    7   8   5  1  6.33          7.0
# 4          GraphSAGE  1    5   7    4   3    4   7   3  1  4.33         3.67
# 5  GCN Skip-$\alpha$  4    3   3    5   4    3   4   4  1  3.33          4.0
# 6        GCN Skip-PC  5    2   2    2   2    6   5   7  1   3.0         3.33
# 7                MLP  8    8   8    8   8    8   3   2  1   8.0          8.0
#
#   strong total
# 0    3.0  3.67
# 1    5.0  2.33
# 2    1.0  3.78
# 3   4.67   6.0
# 4   3.67  3.89
# 5    3.0  3.44
# 6   4.33  3.56
# 7    2.0   6.0

# %%
C_l = None
models = ["GCN_depth2", "SGC_depth2", #"APPNP_0.3", "MLP",
# "GIN", "GraphSAGE", 
"GCN_skipalpha_linear_depth2", 
"GCN_skippc_linear_depth2"
          ]
legend_labels = ["GCN $d=2$", "SGC $d=2$", #"APPNP", "MLP",
# "GIN", "GraphSAGE", 
"GCN Skip-$\\alpha$ $d=2$", 
"GCN Skip-PC $d=2$"]
savefig = None #"sbm_collective.pdf"
experiment_manager.plot_robust_acc_delta_v2(K, models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels, 
                                         xlogscale=False,
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                                        legend_fontsize=legend_fontsize,
                                        ticks_fontsize=ticks_fontsize,
                                        markersize=markersize,
                                        capsize=capsize,
                                        linewidth=linewidth,
                                        framealpha=framealpha,
                                        )

# %%
C_l = None
models = ["GCN_depth4", "SGC_depth4", #"APPNP_0.3", "MLP",
# "GIN", "GraphSAGE", 
"GCN_skipalpha_linear_depth4", 
"GCN_skippc_linear_depth4"
          ]
legend_labels = ["GCN $d=4$", "SGC $d=4$", #"APPNP", "MLP",
# "GIN", "GraphSAGE", 
"GCN Skip-$\\alpha$ $d=4$", 
"GCN Skip-PC $d=4$"]
savefig = None #"sbm_collective.pdf"
experiment_manager.plot_robust_acc_delta_v2(K, models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels, 
                                         xlogscale=False,
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                                        legend_fontsize=legend_fontsize,
                                        ticks_fontsize=ticks_fontsize,
                                        markersize=markersize,
                                        capsize=capsize,
                                        linewidth=linewidth,
                                        framealpha=framealpha,
                                        )

# %% [markdown]
# ## depth

# %%
C_l = None
models = ["GCN", "GCN_depth2", "GCN_depth4" 
          ]
legend_labels = ["GCN $d=1$", "GCN $d=2$", "GCN $d=4$" 
]
savefig = None #"sbm_collective.pdf"
experiment_manager.plot_robust_acc_delta_v2(K, models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels, 
                                         xlogscale=False,
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                                        legend_fontsize=legend_fontsize,
                                        ticks_fontsize=ticks_fontsize,
                                        markersize=markersize,
                                        capsize=capsize,
                                        linewidth=linewidth,
                                        framealpha=framealpha,
                                        )

# %%
C_l = None
models = ["SGC", "SGC_depth2", "SGC_depth4" 
          ]
legend_labels = ["SGC $d=1$", "SGC $d=2$", "SGC $d=4$" 
]
savefig = None #"sbm_collective.pdf"
experiment_manager.plot_robust_acc_delta_v2(K, models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels, 
                                         xlogscale=False,
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                                        legend_fontsize=legend_fontsize,
                                        ticks_fontsize=ticks_fontsize,
                                        markersize=markersize,
                                        capsize=capsize,
                                        linewidth=linewidth,
                                        framealpha=framealpha,
                                        )

# %%
C_l = None
models = ["GCN_skippc_linear", "GCN_skippc_linear_depth2", "GCN_skippc_linear_depth4" 
          ]
legend_labels = ["GCN Skip-PC $d=1$", "GCN Skip-PC $d=2$", "GCN Skip-PC $d=4$" 
]
savefig = None #"sbm_collective.pdf"
experiment_manager.plot_robust_acc_delta_v2(K, models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels, 
                                         xlogscale=False,
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                                        legend_fontsize=legend_fontsize,
                                        ticks_fontsize=ticks_fontsize,
                                        markersize=markersize,
                                        capsize=capsize,
                                        linewidth=linewidth,
                                        framealpha=framealpha,
                                        )

# %%
C_l = None
models = ["GCN_skipalpha_linear", "GCN_skipalpha_linear_depth2", "GCN_skipalpha_linear_depth4" 
          ]
legend_labels = ["GCN Skip-$\\alpha$ $d=1$", "GCN Skip-$\\alpha$ $d=2$", "GCN Skip-$\\alpha$ $d=4$" 
]
savefig = None #"sbm_collective.pdf"
experiment_manager.plot_robust_acc_delta_v2(K, models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels, 
                                         xlogscale=False,
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                                        legend_fontsize=legend_fontsize,
                                        ticks_fontsize=ticks_fontsize,
                                        markersize=markersize,
                                        capsize=capsize,
                                        linewidth=linewidth,
                                        framealpha=framealpha,
                                        )

# %%
C_l = None
models = ["GCN", "GCN_skipalpha", "GCN_skippc" 
          ]
legend_labels = ["GCN", "GCN Skip-$\\alpha$", "GCN Skip-PC" 
]
savefig = "cba_n10_coll_depth1.pdf"
linewidth = 1.8
markersize = 6
capsize = 6
label_fontsize = 24
legend_fontsize = 16
ticks_fontsize = 16
use_custom_legend = True
legend_args = dict(
    framealpha = 0.5,
    handlelength = 1.5,
    handletextpad = 0.5,
    labelspacing = 0.3,
    loc="lower left",
    # bbox_to_anchor=(0.585,.238),
   bbox_to_anchor=(0.55,.60),
    #bbox_to_anchor=(0.33,.585),
    ncol=1,
    #columnspacing=0.3,
    columnspacing=1
)
experiment_manager.plot_robust_acc_delta_v2(K,models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels,
                                        label_fontsize=label_fontsize,
                                        legend_fontsize=legend_fontsize,
                                        ticks_fontsize=ticks_fontsize,
                                        markersize=markersize,
                                        capsize=capsize,
                                        linewidth=linewidth,
                                        legend_args=legend_args,
                                         savefig=savefig,
                                         use_custom_legend=True,
                                         certified_acc=False,
                                         use_style=False
                                        )

# %%
C_l = None
models = ["GCN_depth2", "GCN_skipalpha_linear_depth2", "GCN_skippc_linear_depth2" 
          ]
legend_labels = ["GCN", "GCN Skip-$\\alpha$", "GCN Skip-PC" 
]
savefig = "cba_n10_coll_depth2.pdf"
linewidth = 1.8
markersize = 6
capsize = 6
label_fontsize = 24
legend_fontsize = 16
ticks_fontsize = 16
use_custom_legend = True
legend_args = dict(
    framealpha = 0.5,
    handlelength = 1.5,
    handletextpad = 0.5,
    labelspacing = 0.3,
    loc="lower left",
    # bbox_to_anchor=(0.585,.238),
   bbox_to_anchor=(0.55,.60),
    #bbox_to_anchor=(0.33,.585),
    ncol=1,
    #columnspacing=0.3,
    columnspacing=1
)
experiment_manager.plot_robust_acc_delta_v2(K,models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels,
                                        label_fontsize=label_fontsize,
                                        legend_fontsize=legend_fontsize,
                                        ticks_fontsize=ticks_fontsize,
                                        markersize=markersize,
                                        capsize=capsize,
                                        linewidth=linewidth,
                                        legend_args=legend_args,
                                         savefig=savefig,
                                         use_custom_legend=True,
                                         certified_acc=False,
                                         use_style=False
                                        )

# %%
C_l = None
models = ["GCN_depth4", "GCN_skipalpha_linear_depth4", "GCN_skippc_linear_depth4" 
          ]
legend_labels = ["GCN", "GCN Skip-$\\alpha$", "GCN Skip-PC" 
]
savefig = "cba_n10_coll_depth4.pdf"
linewidth = 1.8
markersize = 6
capsize = 6
label_fontsize = 24
legend_fontsize = 16
ticks_fontsize = 16
use_custom_legend = True
legend_args = dict(
    framealpha = 0.5,
    handlelength = 1.5,
    handletextpad = 0.5,
    labelspacing = 0.3,
    loc="lower left",
    # bbox_to_anchor=(0.585,.238),
   bbox_to_anchor=(0.55,.60),
    #bbox_to_anchor=(0.33,.585),
    ncol=1,
    #columnspacing=0.3,
    columnspacing=1
)
experiment_manager.plot_robust_acc_delta_v2(K,models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels,
                                        label_fontsize=label_fontsize,
                                        legend_fontsize=legend_fontsize,
                                        ticks_fontsize=ticks_fontsize,
                                        markersize=markersize,
                                        capsize=capsize,
                                        linewidth=linewidth,
                                        legend_args=legend_args,
                                         savefig=savefig,
                                         use_custom_legend=True,
                                         certified_acc=False,
                                         use_style=False
                                        )

# %% [markdown]
# # sparsity

# %%
gcn_s1_coll_exp = dict(
    label = "GCN_sparsity_1",
    # relabel = "GCN_coll",
    collection = "m_label_collect_cba_gcn",
    start_id = 121,
    end_id = 160,
    n_seeds = 5,
)
gcn_s2_coll_exp = dict(
    label = "GCN_sparsity_2",
    # relabel = "GCN_coll",
    collection = "m_label_collect_cba_gcn",
    start_id = 161,
    end_id = 200,
    n_seeds = 5,
)
sgc_s1_coll_exp = dict(
    label = "SGC_sparsity_1",
    # relabel = "GCN_coll",
    collection = "m_label_collect_cba_sgc",
    start_id = 121,
    end_id = 160,
    n_seeds = 5,
)
sgc_s2_coll_exp = dict(
    label = "SGC_sparsity_2",
    # relabel = "GCN_coll",
    collection = "m_label_collect_cba_sgc",
    start_id = 161,
    end_id = 200,
    n_seeds = 5,
)

# %%
experiments = [
                gcn_coll_exp, gcn_s1_coll_exp, gcn_s2_coll_exp,
                sgc_coll_exp, sgc_s1_coll_exp, sgc_s2_coll_exp,mlp_coll_exp
                ]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN No. of experiments 8
# GCN_sparsity_1 No. of experiments 8
# GCN_sparsity_2 No. of experiments 8
# SGC No. of experiments 8
# SGC_sparsity_1 No. of experiments 8
# SGC_sparsity_2 No. of experiments 8
# MLP No. of experiments 8

# %%
C_l = None
models = [ "GCN_sparsity_1","GCN",  "GCN_sparsity_2", "MLP" 
          ]
legend_labels = ["GCN $2\\times$", "GCN $1\\times$", 
                 "GCN $0.5\\times$", "GCN $0\\times$" 
]
savefig = "cba_gcn_n10_coll_sparsity.pdf"
linewidth = 1.8
markersize = 6
capsize = 6
label_fontsize = 24
legend_fontsize = 16
ticks_fontsize = 16
use_custom_legend = True
legend_args = dict(
    framealpha = 0.5,
    handlelength = 1.5,
    handletextpad = 0.5,
    labelspacing = 0.3,
    loc="lower left",
    # bbox_to_anchor=(0.585,.238),
   bbox_to_anchor=(0.60,.55),
    #bbox_to_anchor=(0.33,.585),
    ncol=1,
    #columnspacing=0.3,
    columnspacing=1
)
experiment_manager.plot_robust_acc_delta_v2(K,models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels,
                                        label_fontsize=label_fontsize,
                                        legend_fontsize=legend_fontsize,
                                        ticks_fontsize=ticks_fontsize,
                                        markersize=markersize,
                                        capsize=capsize,
                                        linewidth=linewidth,
                                        legend_args=legend_args,
                                         savefig=savefig,
                                         use_custom_legend=True,
                                         certified_acc=False,
                                         use_style=False
                                        )

# %%
C_l = None
models = ["SGC_sparsity_1", "SGC", "SGC_sparsity_2", "MLP" 
          ]
legend_labels = ["SGC $2\\times$","SGC $1\\times$",  "SGC $0.5\\times$", "SGC $0\\times$" 
]
savefig = "cba_sgc_n10_coll_sparsity.pdf"
linewidth = 1.8
markersize = 6
capsize = 6
label_fontsize = 24
legend_fontsize = 16
ticks_fontsize = 16
use_custom_legend = True
legend_args = dict(
    framealpha = 0.5,
    handlelength = 1.5,
    handletextpad = 0.5,
    labelspacing = 0.3,
    loc="lower left",
    # bbox_to_anchor=(0.585,.238),
   bbox_to_anchor=(0.60,.55),
    #bbox_to_anchor=(0.33,.585),
    ncol=1,
    #columnspacing=0.3,
    columnspacing=1
)
experiment_manager.plot_robust_acc_delta_v2(K,models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels,
                                        label_fontsize=label_fontsize,
                                        legend_fontsize=legend_fontsize,
                                        ticks_fontsize=ticks_fontsize,
                                        markersize=markersize,
                                        capsize=capsize,
                                        linewidth=linewidth,
                                        legend_args=legend_args,
                                         savefig=savefig,
                                         use_custom_legend=True,
                                         certified_acc=False,
                                         use_style=False
                                        )

# %%
appnp1_coll_exp = dict(
    label = "APPNP_0.1",
    collection = "m_label_collect_cba_appnp",
    start_id = 81,
    end_id = 120,
    n_seeds = 5,
)
appnp2_coll_exp = dict(
    label = "APPNP_0.2",
    collection = "m_label_collect_cba_appnp",
    start_id = 121,
    end_id = 160,
    n_seeds = 5,
)
appnp5_coll_exp = dict(
    label = "APPNP_0.5",
    collection = "m_label_collect_cba_appnp",
    start_id = 161,
    end_id = 200,
    n_seeds = 5,
)
appnp0_coll_exp = dict(
    label = "APPNP_0",
    collection = "m_label_collect_cba_appnp",
    start_id = 201,
    end_id = 240,
    n_seeds = 5,
)

# %%
experiments = [
                appnp_alp03_coll_exp, appnp0_coll_exp,
                appnp2_coll_exp, appnp1_coll_exp, 
                appnp5_coll_exp, mlp_coll_exp
                ]
experiment_manager = ExperimentManager(experiments)
# Out:
# APPNP_0.3 No. of experiments 8
# APPNP_0 No. of experiments 8
# APPNP_0.2 No. of experiments 8
# APPNP_0.1 No. of experiments 8
# APPNP_0.5 No. of experiments 8
# MLP No. of experiments 8

# %%
C_l = None
models = ["APPNP_0", "APPNP_0.1", "APPNP_0.2",
           "APPNP_0.5", "MLP"
          ]
legend_labels = ["APPNP 0", "APPNP 0.1", "APPNP 0.2",
           "APPNP 0.5", "MLP"
]
experiment_manager.plot_robust_acc_delta_v2(K, models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels)
