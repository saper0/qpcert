# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt

# %%
gcn_exp = dict(
    label = "GCN",
    collection = "l_sbm_cert_gcn",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
appnp_exp = dict(
    label = "APPNP",
    collection = "l_sbm_cert_appnp",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
K = 1.5
attack_nodes = "test"
delta_l = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 6, 12, 24, 60, 120]

experiments = [gcn_exp, appnp_exp]
experiment_manager = ExperimentManager(experiments)

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})

# %%
C_l = [0.01, 0.001]
experiment_manager.plot_robust_acc_delta(K, ["GCN"], C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)
# Out:
# 0.8450000000000001
# 0.8300000000000001
# 0.7816666666666667
# 0.6283333333333333
# 0.34500000000000003
# 0.034999999999999996
# 0.0
# 0.8450000000000001
# 0.8300000000000001
# 0.78
# 0.6266666666666667
# 0.34500000000000003
# 0.048333333333333325
# 0.005

# %%
C_l = [0.01, 0.001]
experiment_manager.plot_robust_acc_delta(K, ["APPNP"], C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)
# Out:
# 0.835
# 0.825
# 0.79
# 0.685
# 0.465
# 0.09166666666666667
# 0.003333333333333333
# 0.835
# 0.825
# 0.7783333333333333
# 0.6766666666666666
# 0.465
# 0.12333333333333332
# 0.013333333333333332
