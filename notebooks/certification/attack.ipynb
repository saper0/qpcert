# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt

# %%
#gcn_att_exp = dict(
#    collection = "l_sbm_attack_ntk_gcn",
#    start_id = 1,
#    end_id = 4200,
#    n_seeds = 5,
#)
appnp_att_exp = dict(
    collection = "l_sbm_attack_ntk_appnp",
    start_id = 1,
    end_id = 840,
    n_seeds = 5,
)
gcn_att_exp_v2 = dict(
    collection = "l_sbm_attack_ntk_gcn_norm",
    start_id = 1,
    end_id = 210,
    n_seeds = 5,
)
appnp_att_exp_v2 = dict(
    collection = "l_sbm_attack_ntk_appnp_norm",
    start_id = 1,
    end_id = 210,
    n_seeds = 5,
)
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 6, 12, 24, 60, 120]
experiments = [gcn_att_exp_v2, appnp_att_exp_v2, appnp_att_exp]
experiment_manager = ExperimentManager(experiments)

# %%
C_l = [0.01]
K = 1.5
attack_nodes = "test"
models = ["GCN_att_eta10", "GCN_norm_eta10", "GCN_norm_eta2"]
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l, use_style=False)

# %%
C_l = [0.01]
K = 1.5
attack_nodes = "test"
models = ["APPNP_alpha0.2", "APPNP_alpha0.2_att_eta10", "APPNP_alpha0.2_eta2"]
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l, use_style=False)

# %%
gcn_exp = dict(
    label = "GCN",
    collection = "l_sbm_cert_gcn",
    start_id = 1,
    end_id = 735,
    n_seeds = 5,
)
gcn_att_exp = dict(
    collection = "l_sbm_attack_ntk_gcn",
    start_id = 1,
    end_id = 4200,
    n_seeds = 5,
)
appnp_exp = dict(
    label = "APPNP",
    collection = "l_sbm_cert_appnp",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
appnp_att_exp = dict(
    collection = "l_sbm_attack_ntk_appnp",
    start_id = 1,
    end_id = 840,
    n_seeds = 5,
)
sgc_exp = dict(
    label = "SGC",
    collection = "m_sbm_cert_sgc",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
gcn_skip_exp = dict(
    label = "GCN_skippc",
    collection = "m_sbm_cert_gcn_skippc",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
sgc_depth2_exp = dict(
    label = "SGC_depth2",
    collection = "m_sbm_cert_sgc_depth2",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
sgc_depth4_exp = dict(
    label = "SGC_depth4",
    collection = "m_sbm_cert_sgc_depth4",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
K = 1.5
attack_nodes = "test"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 6, 12, 24, 60, 120]
experiments = [gcn_exp, gcn_att_exp, appnp_exp, appnp_att_exp]
experiment_manager = ExperimentManager(experiments)

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})

# %%
C_l = [0.01]
experiment_manager.plot_robust_acc_delta_nadv(K, ["GCN"], C_l, attack_nodes, 
                                              n_adv_l=n_adv_l, delta_l=delta_l)

# %%
C_l = [0.01]
models = ["GCN", "GCN_att_eta10", "APPNP", "APPNP_alpha0.2"]
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.01, 0.1]
#models = ["GCN", "GCN_att_eta2", "GCN_att_eta10", "GCN_att_eta100"]
models = ["GCN", "GCN_att_eta10"]
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.01]
models = ["GCN_att_eta2", "GCN_att_eta10", "GCN_att_eta100"]
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.001]
models = ["GCN_att_eta2", "GCN_att_eta10", "GCN_att_eta100"]
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.001]
models = ["GCN_att_eta2", "GCN_att_eta10", "GCN_att_eta100"]
delta_l = [0, 0.01, 0.02, 0.05, 0.1]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.3, 0.5, 0.75, 1]
C_l = [0.001]
models = ["GCN_att_eta2", "GCN_att_eta10", "GCN_att_eta100"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.001]
models = ["GCN", "GCN_att_eta2", "GCN_att_eta10", "GCN_att_eta100"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=60, delta_l=delta_l)

# %%
C_l = [0.001]
models = ["GCN", "GCN_att_eta2", "GCN_att_eta10", "GCN_att_eta100"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=120, delta_l=delta_l)

# %%
C_l = [0.01]
models = ["GCN", "APPNP", "GCN_skippc", "SGC"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.01]
models = ["GCN", "APPNP", "APPNP_alpha0.1", "GCN_skippc", "SGC"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.01]
experiment_manager.plot_robust_acc_delta(K, ["GCN", "APPNP"], C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.01, 0.001]
experiment_manager.plot_robust_acc_delta(K, ["APPNP"], C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.01]
models = ["SGC", "SGC_depth2", "SGC_depth4"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.01]
models = ["SGC", "SGC_depth2", "SGC_depth4"]
n_adv_list = [12, 24]
experiment_manager.plot_robust_acc_delta_nadv(K, models, C_l, attack_nodes, 
                                              n_adv_l=n_adv_list, delta_l=delta_l)

# %%
C = 0.01
experiment_manager.plot_nadv_delta_heatmap(K, ["GCN"], C, 
                              attack_nodes, n_adv_l, delta_l[::-1],
                              width=1, ratio=1.5, cbar_normalized=True)

# %%
C = 0.01
experiment_manager.plot_nadv_delta_heatmap(K, ["APPNP"], C, 
                              attack_nodes, n_adv_l, delta_l[::-1],
                              width=1, ratio=1.5, cbar_normalized=True)

# %%
C = 0.01
experiment_manager.plot_nadv_delta_heatmap(K, ["SGC"], C, 
                              attack_nodes, n_adv_l, delta_l[::-1],
                              width=1, ratio=1.5, cbar_normalized=True)

# %%
C = 0.01
experiment_manager.plot_nadv_delta_heatmap(K, ["GCN_skippc"], C, 
                              attack_nodes, n_adv_l, delta_l[::-1],
                              width=1, ratio=1.5, cbar_normalized=True)
