# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})

# %%
label_fontsize = 29
legend_fontsize = 16 # 18
ticks_fontsize = 16 #18
use_custom_legend = True
linewidth = 1.5
markersize = 6
capsize = 6
framealpha = 0.5

# %%
gcn_trn_exp = dict(
    label = "GCN",
    collection = "m_sbm_cert_gcn",
    start_id = 1961,
    end_id = 2450,
    n_seeds = 5,
)
gcn_trn_adv_exp = dict(
    label = "GCN",
    relabel = "GCN_adv",
    collection = "l_sbm_attack_surrogate_pl",
    start_id = 246,
    end_id = 315,
    n_seeds = 5,
)
sgc_trn_exp = dict(
    label = "SGC",
    collection = "m_sbm_cert_sgc",
    start_id = 2451,
    end_id = 2940,
    n_seeds = 5,
)
sgc_trn_adv_exp = dict(
    label = "SGC",
    relabel = "SGC_adv",
    collection = "l_sbm_attack_surrogate_pl",
    start_id = 316,
    end_id = 385,
    n_seeds = 5,
)
appnp_trn_exp = dict(
    label = "APPNP_alpha0.2",
    relabel = "APPNP",
    collection = "m_sbm_cert_appnp",
    start_id = 5391,
    end_id = 5880,
    n_seeds = 5,
)
appnp_trn_adv_exp = dict(
    label = "APPNP",
    relabel = "APPNP_adv",
    collection = "l_sbm_attack_surrogate_pl",
    start_id = 1,
    end_id = 245,
    n_seeds = 5,
)
appnp_alpha1_trn_exp = dict(
    label = "APPNP_alpha1",
    relabel = "APPNP_alpha1",
    collection = "m_sbm_cert_appnp",
    start_id = 6861,
    end_id = 7350,
    n_seeds = 5,
)
appnp_alpha1_trn_adv_exp = dict(
    label = "MLP",
    relabel = "APPNP_alpha1_adv",
    collection = "l_sbm_attack_surrogate_pl",
    start_id = 386,
    end_id = 455,
    n_seeds = 5,
)
gcn_skippc_linear_trn_exp = dict(
    label = "GCN_skippc_linear",
    collection = "m_sbm_cert_gcn_skippc",
    start_id = 981,
    end_id = 1225,
    n_seeds = 5,
)
gcn_skippc_linear_trn_adv_exp = dict(
    label = "GCN_skippc_linear",
    relabel = "GCN_skippc_linear_adv",
    collection = "l_sbm_attack_surrogate_pl",
    start_id = 526,
    end_id = 595,
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha02_trn_exp = dict(
    label = "GCN_skipalpha_linear",
    relabel = "GCN_skipalpha_linear_alpha0.2",
    collection = "m_sbm_cert_gcn_skipalpha",
    start_id = 2206,
    end_id = 2450,
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha02_trn_adv_exp = dict(
    label = "GCN_skipalpha_linear",
    relabel = "GCN_skipalpha_linear_alpha0.2_adv",
    collection = "l_sbm_attack_surrogate_pl",
    start_id = 456,
    end_id = 525,
    n_seeds = 5,
)
gin_trn_exp = dict(
    label = "GIN",
    collection = "m_sbm_cert_pl",
    start_id = 1226,
    end_id = 1470,
    n_seeds = 5,
)
gin_trn_exp = dict(
    label = "GIN",
    collection = "m_sbm_cert_pl",
    start_id = 1226, #1716, 
    end_id = 1470, #1960,
    n_seeds = 5,
)
gin_trn_adv_exp = dict(
    label = "GIN",
    relabel = "GIN_adv",
    collection = "l_sbm_attack_surrogate_pl",
    start_id = 666, #1,
    end_id = 735, #245,
    n_seeds = 5,
)
graphsage_trn_exp = dict(
    label = "GraphSage",
    relabel = "GraphSAGE",
    collection = "m_sbm_cert_pl",
    start_id = 2206,
    end_id = 2450,
    n_seeds = 5,
)
graphsage_trn_adv_exp = dict(
    label = "GraphSAGE",
    relabel = "GraphSAGE_adv",
    collection = "l_sbm_attack_surrogate_pl",
    start_id = 596,
    end_id = 665,
    n_seeds = 5,
)
K = 1.5
attack_nodes = "train_val"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 4, 8, 16, 40, 80]

# %%
experiments = [gcn_trn_exp, gcn_trn_adv_exp,
               sgc_trn_exp, sgc_trn_adv_exp,
               appnp_trn_exp, appnp_trn_adv_exp,
               appnp_alpha1_trn_exp, appnp_alpha1_trn_adv_exp,
               gcn_skippc_linear_trn_exp, gcn_skippc_linear_trn_adv_exp,
               gcn_skipalpha_linear_alpha02_trn_exp, gcn_skipalpha_linear_alpha02_trn_adv_exp,
               gin_trn_exp, gin_trn_adv_exp,
               graphsage_trn_exp, graphsage_trn_adv_exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN No. of experiments 98
# GCN No. of experiments 14
# SGC No. of experiments 98
# SGC No. of experiments 14
# APPNP_alpha0.2 No. of experiments 98
# APPNP No. of experiments 49
# APPNP_alpha1 No. of experiments 98
# MLP No. of experiments 14
# GCN_skippc_linear No. of experiments 49
# GCN_skippc_linear No. of experiments 14
# GCN_skipalpha_linear No. of experiments 49
# GCN_skipalpha_linear No. of experiments 14
# GIN No. of experiments 49
# GIN No. of experiments 14
# GraphSage No. of experiments 49
# GraphSAGE No. of experiments 14

# %%
C_l = [0.01]
models = ["GCN","GCN_adv",
          "APPNP", "APPNP_adv",
           "SGC","SGC_adv",
           "GIN", "GIN_adv",
          "GraphSAGE", "GraphSAGE_adv",
          "GCN_skippc_linear", "GCN_skippc_linear_adv",
          "GCN_skipalpha_linear_alpha0.2", "GCN_skipalpha_linear_alpha0.2_adv",
          "APPNP_alpha1", "APPNP_alpha1_adv",
          ]
legend_labels = ["GCN","_nolegend_",
                 "APPNP", "_nolegend_",
                  "SGC", "_nolegend_",
                 "GIN", "_nolegend_",
                 "GraphSAGE", "_nolegend_",
                 "GCN Skip-PC", "_nolegend_",
                 "GCN Skip-$\\alpha$", "_nolegend_",
                 "MLP", "_nolegend_",
                 ]
dummy_legends = [("-", "lower bound"), ("--", "upper bound")]
n_adv_plot = 16
savefig = "sbm_attack_surrogate_pl.pdf" #f'gnn_mlp_adv_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
pert_model="linf"
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize-2,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              pert_model=pert_model,
                              dummy_legend=dummy_legends)

# %%
C_l = [0.01]
models = ["GCN","GCN_adv",
          "APPNP", "APPNP_adv",
           "SGC","SGC_adv",
           "GIN", "GIN_adv",
          "GraphSAGE", "GraphSAGE_adv",
          "GCN_skippc_linear", "GCN_skippc_linear_adv",
          "GCN_skipalpha_linear_alpha0.2", "GCN_skipalpha_linear_alpha0.2_adv",
          "APPNP_alpha1", "APPNP_alpha1_adv",
          ]
legend_labels = ["GCN","_nolegend_",
                 "APPNP", "_nolegend_",
                  "SGC", "_nolegend_",
                 "GIN", "_nolegend_",
                 "GraphSAGE", "_nolegend_",
                 "GCN Skip-PC", "_nolegend_",
                 "GCN Skip-$\\alpha$", "_nolegend_",
                 "MLP", "_nolegend_",
                 ]
dummy_legends = [("-", "lower bound"), ("--", "upper bound")]
n_adv_plot = 16
savefig = None #f'gnn_mlp_adv_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
pert_model="linf"
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize-2,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              pert_model=pert_model,
                              dummy_legend=dummy_legends)

# %%
C_l = [0.01]
models = ["GCN","GCN_adv",
          "APPNP", "APPNP_adv",
           "SGC","SGC_adv",
           "GIN", "GIN_adv",
          "GraphSAGE", "GraphSAGE_adv",
          "GCN_skippc_linear", "GCN_skippc_linear_adv",
          "GCN_skipalpha_linear_alpha0.2", "GCN_skipalpha_linear_alpha0.2_adv",
          "APPNP_alpha1", "APPNP_alpha1_adv",
          ]
legend_labels = ["GCN","_nolegend_",
                 "APPNP", "_nolegend_",
                  "SGC", "_nolegend_",
                 "GIN", "_nolegend_",
                 "GraphSAGE", "_nolegend_",
                 "GCN Skip-PC", "_nolegend_",
                 "GCN Skip-$\\alpha$", "_nolegend_",
                 "MLP", "_nolegend_",
                 ]
dummy_legends = [("-", "lower bound"), ("--", "upper bound")]
n_adv_plot = 16
savefig = f'gnn_mlp_adv_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
pert_model="linf"
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize-2,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              pert_model=pert_model,
                              dummy_legend=dummy_legends)
