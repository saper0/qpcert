# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})

# %%
label_fontsize = 29
legend_fontsize = 16 # 18
ticks_fontsize = 16 #18
use_custom_legend = True
linewidth = 1.5
markersize = 6
capsize = 6
framealpha = 0.5

# %%
gcn_trn_exp = dict(
    label = "GCN",
    collection = "m_sbm_cert_backdoor_gcn",
    start_id = 1,
    end_id = 245,
    n_seeds = 5,
)
gcn_trn_adv_exp = dict(
    label = "GCN",
    relabel = "GCN_adv",
    collection = "l_sbm_attack_bl",
    attack_nodes_relabel = "train_val_backdoor",
    start_id = 36,
    end_id = 70,
    n_seeds = 5,
)
sgc_trn_exp = dict(
    label = "SGC",
    collection = "m_sbm_cert_backdoor_sgc",
    start_id = 1,
    end_id = 245,
    n_seeds = 5,
)
sgc_trn_adv_exp = dict(
    label = "SGC",
    relabel = "SGC_adv",
    collection = "l_sbm_attack_bl",
    attack_nodes_relabel = "train_val_backdoor",
    start_id = 71,
    end_id = 105,
    n_seeds = 5,
)
appnp_trn_exp = dict(
    label = "APPNP_alpha0.2",
    relabel = "APPNP",
    collection = "m_sbm_cert_backdoor_appnp",
    start_id = 491,
    end_id = 735,
    n_seeds = 5,
)
appnp_trn_adv_exp = dict(
    label = "APPNP",
    relabel = "APPNP_adv",
    collection = "l_sbm_attack_bl",
    attack_nodes_relabel = "train_val_backdoor",
    start_id = 1,
    end_id = 35,
    n_seeds = 5,
)
appnp_alpha1_trn_exp = dict(
    label = "APPNP_alpha1",
    relabel = "APPNP_alpha1",
    collection = "m_sbm_cert_backdoor_appnp",
    start_id = 1226,
    end_id = 1470,
    n_seeds = 5,
)
appnp_alpha1_trn_adv_exp = dict(
    label = "MLP",
    relabel = "APPNP_alpha1_adv",
    collection = "l_sbm_attack_bl",
    attack_nodes_relabel = "train_val_backdoor",
    start_id = 106,
    end_id = 140,
    n_seeds = 5,
)
gcn_skippc_linear_trn_exp = dict(
    label = "GCN_skippc_linear",
    collection = "m_sbm_cert_backdoor_gcn_skippc",
    start_id = 1,
    end_id = 245,
    n_seeds = 5,
)
gcn_skippc_linear_trn_adv_exp = dict(
    label = "GCN_skippc_linear",
    relabel = "GCN_skippc_linear_adv",
    collection = "l_sbm_attack_bl",
    attack_nodes_relabel = "train_val_backdoor",
    start_id = 176,
    end_id = 210,
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha02_trn_exp = dict(
    label = "GCN_skipalpha_linear",
    relabel = "GCN_skipalpha_linear_alpha0.2",
    collection = "m_sbm_cert_backdoor_gcn_skipalpha",
    start_id = 246,
    end_id = 490,
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha02_trn_adv_exp = dict(
    label = "GCN_skipalpha_linear",
    relabel = "GCN_skipalpha_linear_alpha0.2_adv",
    collection = "l_sbm_attack_bl",
    attack_nodes_relabel = "train_val_backdoor",
    start_id = 141,
    end_id = 175,
    n_seeds = 5,
)
gin_trn_exp = dict(
    label = "GIN",
    collection = "m_sbm_cert_bl",
    start_id = 1,
    end_id = 245,
    n_seeds = 5,
)
gin_trn_adv_exp = dict(
    label = "GIN",
    relabel = "GIN_adv",
    collection = "l_sbm_attack_bl",
    attack_nodes_relabel = "train_val_backdoor",
    start_id = 246,
    end_id = 280,
    n_seeds = 5,
)
graphsage_trn_exp = dict(
    label = "GraphSAGE",
    relabel = "GraphSAGE",
    collection = "m_sbm_cert_bl",
    start_id = 246,
    end_id = 490,
    n_seeds = 5,
)
graphsage_trn_adv_exp = dict(
    label = "GraphSAGE",
    relabel = "GraphSAGE_adv",
    collection = "l_sbm_attack_bl",
    attack_nodes_relabel = "train_val_backdoor",
    start_id = 211,
    end_id = 245,
    n_seeds = 5,
)
K = 1.5
attack_nodes = "train_val_backdoor"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 4, 8, 16, 40, 80]

# %%
experiments = [gcn_trn_exp, gcn_trn_adv_exp,
               sgc_trn_exp, sgc_trn_adv_exp,
               appnp_trn_exp, appnp_trn_adv_exp,
               appnp_alpha1_trn_exp, appnp_alpha1_trn_adv_exp,
               gcn_skippc_linear_trn_exp, gcn_skippc_linear_trn_adv_exp,
               gcn_skipalpha_linear_alpha02_trn_exp, gcn_skipalpha_linear_alpha02_trn_adv_exp,
               gin_trn_exp, gin_trn_adv_exp,
               graphsage_trn_exp, graphsage_trn_adv_exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN No. of experiments 49
# GCN No. of experiments 7
# SGC No. of experiments 49
# SGC No. of experiments 7
# APPNP_alpha0.2 No. of experiments 49
# APPNP No. of experiments 7
# APPNP_alpha1 No. of experiments 49
# MLP No. of experiments 7
# GCN_skippc_linear No. of experiments 49
# GCN_skippc_linear No. of experiments 7
# GCN_skipalpha_linear No. of experiments 49
# GCN_skipalpha_linear No. of experiments 7
# GIN No. of experiments 49
# GIN No. of experiments 7
# GraphSAGE No. of experiments 49
# GraphSAGE No. of experiments 7

# %%
C_l = [0.01]
models = ["GCN","GCN_adv",
          "APPNP", "APPNP_adv",
           "SGC","SGC_adv",
           "GIN", "GIN_adv",
          "GraphSAGE", "GraphSAGE_adv",
          "GCN_skippc_linear", "GCN_skippc_linear_adv",
          "GCN_skipalpha_linear_alpha0.2", "GCN_skipalpha_linear_alpha0.2_adv",
          "APPNP_alpha1", "APPNP_alpha1_adv",
          ]
legend_labels = ["GCN","_nolegend_",
                 "APPNP", "_nolegend_",
                  "SGC", "_nolegend_",
                 "GIN", "_nolegend_",
                 "GraphSAGE", "_nolegend_",
                 "GCN Skip-PC", "_nolegend_",
                 "GCN Skip-$\\alpha$", "_nolegend_",
                 "MLP", "_nolegend_",
                 ]
dummy_legends = [("-", "lower bound"), ("--", "upper bound")]
n_adv_plot = 16
savefig = "sbm_attack_bl_strong.pdf" #f'gnn_mlp_adv_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
pert_model="linf"
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize-2,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              pert_model=pert_model,
                              dummy_legend=dummy_legends)

# %%
C_l = [0.01]
models = ["GCN","GCN_adv",
          "APPNP", "APPNP_adv",
           "SGC","SGC_adv",
           #"GIN", "GIN_adv",
          "GraphSAGE", "GraphSAGE_adv",
          "GCN_skippc_linear", "GCN_skippc_linear_adv",
          "GCN_skipalpha_linear_alpha0.2", "GCN_skipalpha_linear_alpha0.2_adv",
          "APPNP_alpha1", "APPNP_alpha1_adv",
          ]
legend_labels = ["GCN","_nolegend_",
                 "APPNP", "_nolegend_",
                  "SGC", "_nolegend_",
                 #"GIN", "_nolegend_",
                 "GraphSAGE", "_nolegend_",
                 "GCN Skip-PC", "_nolegend_",
                 "GCN Skip-$\\alpha$", "_nolegend_",
                 "MLP", "_nolegend_",
                 ]
dummy_legends = [("-", "lower bound"), ("--", "upper bound")]
n_adv_plot = 80
savefig = "sbm_attack_surrogate_pl.pdf" #f'gnn_mlp_adv_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
pert_model="linf"
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize-2,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              pert_model=pert_model,
                              dummy_legend=dummy_legends)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 24
#      22 savefig = "sbm_attack_surrogate_pl.pdf" #f'gnn_mlp_adv_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
#      23 pert_model="linf"
# ---> 24 experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes,
#      25                                          n_adv=n_adv_plot, delta_l=delta_l,
#      26                                          legend_labels=legend_labels, xlogscale=True,
#      27                                          savefig=savefig,
#      28                                          label_fontsize=label_fontsize,
#      29                               legend_fontsize=legend_fontsize-2,
#      30                               ticks_fontsize=ticks_fontsize,
#      31                               markersize=markersize,
#      32                               capsize=capsize,
#      33                               linewidth=linewidth,
#      34                               framealpha=framealpha,
#      35                               use_custom_legend=use_custom_legend,
#      36                               pert_model=pert_model,
#      37                               dummy_legend=dummy_legends)
#
# File /ceph/ssd/staff/gosl/src/ntk-robust/notebooks/certification/utils.py:476, in ExperimentManager.plot_robust_acc_delta(self, K, models, C_l, attack_nodes, n_adv, delta_l, legend_labels, width, ratio, xlogscale, savefig, use_style, label_fontsize, legend_fontsize, ticks_fontsize, markersize, capsize, linewidth, framealpha, use_custom_legend, pert_model, dummy_legend)
#     474 for delta in delta_l:
#     475     if delta == 0.:
# --> 476         exp = self.experiments_dict[label][K][C][attack_nodes][n_adv][delta_l[1]]
#     477         y, y_std = exp.get_result("accuracy_test")
#     478     else:
#
# KeyError: 80

# %%
C_l = [0.01]
models = ["GCN","GCN_adv",
          "APPNP", "APPNP_adv",
           "SGC","SGC_adv",
           "GIN", "GIN_adv",
          "GraphSAGE", "GraphSAGE_adv",
          "GCN_skippc_linear", "GCN_skippc_linear_adv",
          "GCN_skipalpha_linear_alpha0.2", "GCN_skipalpha_linear_alpha0.2_adv",
          "APPNP_alpha1", "APPNP_alpha1_adv",
          ]
legend_labels = ["GCN","_nolegend_",
                 "APPNP", "_nolegend_",
                  "SGC", "_nolegend_",
                 "GIN", "_nolegend_",
                 "GraphSAGE", "_nolegend_",
                 "GCN Skip-PC", "_nolegend_",
                 "GCN Skip-$\\alpha$", "_nolegend_",
                 "MLP", "_nolegend_",
                 ]
dummy_legends = [("-", "lower bound"), ("--", "upper bound")]
n_adv_plot = 16
savefig = f'gnn_mlp_adv_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
pert_model="linf"
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize-2,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              pert_model=pert_model,
                              dummy_legend=dummy_legends)
