# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
sys.path.append('..')

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt

# %%
label_fontsize = 29
legend_fontsize = 18
ticks_fontsize = 18
use_custom_legend = True
linewidth = 1.5
markersize = 6
capsize = 6
framealpha = 0.5

# %% [markdown]
# ## Certificate linf

# %% [markdown]
# ### attack_nodes: test

# %%
gcn_exp = dict(
    label = "GCN",
    collection = "l_sbm_cert_gcn",
    start_id = 1,
    end_id = 735,
    n_seeds = 5,
)
appnp_exp = dict(
    label = "APPNP",
    collection = "l_sbm_cert_appnp",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
appnp_alpha1_exp = dict(
    label = "APPNP_alpha1",
    collection = "l_sbm_cert_appnp",
    start_id = 1471,
    end_id = 1715,
    n_seeds = 5,
)
sgc_exp = dict(
    label = "SGC",
    collection = "m_sbm_cert_sgc",
    start_id = 246,
    end_id = 490,
    n_seeds = 5,
)
gcn_skippc_linear_exp = dict(
    label = "GCN_skippc_linear",
    collection = "m_sbm_cert_gcn_skippc",
    start_id = [246, 736],
    end_id = [490, 980],
    n_seeds = 5,
)
# gcn_skippc_relu_exp = dict(
#     label = "GCN_skippc_relu",
#     collection = "m_sbm_cert_gcn_skippc",
#     start_id = [1, 491],
#     end_id = [245, 735],
#     n_seeds = 5,
# )
gcn_skipalpha_linear_alpha01_exp = dict(
    label = "GCN_skipalpha_linear_alpha0.1",
    collection = "m_sbm_cert_gcn_skipalpha",
    start_id = [491, 1471],
    end_id = [735, 1715],
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha02_exp = dict(
    label = "GCN_skipalpha_linear_alpha0.2",
    collection = "m_sbm_cert_gcn_skipalpha",
    start_id = [736, 1716],
    end_id = [980, 1960],
    n_seeds = 5,
)
# gcn_skipalpha_relu_alpha01_exp = dict(
#     label = "GCN_skipalpha_relu_alpha0.1",
#     collection = "m_sbm_cert_gcn_skipalpha",
#     start_id = [1, 981],
#     end_id = [245, 1225],
#     n_seeds = 5,
# )
# gcn_skipalpha_relu_alpha02_exp = dict(
#     label = "GCN_skipalpha_relu_alpha0.2",
#     collection = "m_sbm_cert_gcn_skipalpha",
#     start_id = [246, 1226],
#     end_id = [490, 1470],
#     n_seeds = 5,
# )
K = 1.5
attack_nodes = "test"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 6, 12, 24, 60, 120]

# %%
experiments = [gcn_exp, appnp_exp, sgc_exp, appnp_alpha1_exp,
               gcn_skippc_linear_exp, 
               gcn_skipalpha_linear_alpha01_exp, gcn_skipalpha_linear_alpha02_exp,
               ]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN No. of experiments 147
# APPNP No. of experiments 98
# SGC No. of experiments 49
# APPNP_alpha1 No. of experiments 49
# GCN_skippc_linear No. of experiments 49
# GCN_skippc_linear No. of experiments 49
# GCN_skipalpha_linear_alpha0.1 No. of experiments 49
# GCN_skipalpha_linear_alpha0.1 No. of experiments 49
# GCN_skipalpha_linear_alpha0.2 No. of experiments 49
# GCN_skipalpha_linear_alpha0.2 No. of experiments 49

# %%
C_l = [0.01]
models = ["GCN","APPNP", "SGC", 
           "GCN_skippc_linear",
          "GCN_skipalpha_linear_alpha0.2", "APPNP_alpha1"]
legend_labels = ["GCN","APPNP", "SGC", 
           "GCN Skip-PC",
          "GCN Skip-$\\alpha$", "MLP"]
n_adv_plot = 24
savefig = f'gnn_mlp_cert_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
linf = True
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              linf=linf)

# %%
C_l = [0.01]
models = ["GCN","APPNP", "SGC", 
           "GCN_skippc_linear",
          "GCN_skipalpha_linear_alpha0.2", "APPNP_alpha1"]
legend_labels = ["GCN","APPNP", "SGC", 
           "GCN Skip-PC",
          "GCN Skip-$\\alpha$", "MLP"]
n_adv_plot = 12
savefig = f'gnn_mlp_cert_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.png'
linf = True
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              linf=linf)

# %%
C_l = [0.01]
models = ["GCN","APPNP", "SGC", 
           "GCN_skippc_linear",
          "GCN_skipalpha_linear_alpha0.2", "APPNP_alpha1"]
legend_labels = ["GCN","APPNP", "SGC", 
           "GCN Skip-PC",
          "GCN Skip-$\\alpha$", "MLP"]
n_adv_plot = 120
savefig = None #f'gnn_mlp_cert_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.png'
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, legend_labels=legend_labels, xlogscale=True, savefig=savefig)

# %% [markdown]
# ### attack_nodes: train_val

# %%
gcn_trn_exp = dict(
    label = "GCN",
    collection = "m_sbm_cert_gcn",
    start_id = 1961,
    end_id = 2450,
    n_seeds = 5,
)
appnp_trn_exp = dict(
    label = "APPNP_alpha0.2",
    relabel = "APPNP",
    collection = "m_sbm_cert_appnp",
    start_id = 5391,
    end_id = 5880,
    n_seeds = 5,
)
appnp_alpha1_trn_exp = dict(
    label = "APPNP_alpha1",
    collection = "m_sbm_cert_appnp",
    start_id = 6861,
    end_id = 7350,
    n_seeds = 5,
)
sgc_trn_exp = dict(
    label = "SGC",
    collection = "m_sbm_cert_sgc",
    start_id = 2451,
    end_id = 2940,
    n_seeds = 5,
)
gcn_skippc_linear_trn_exp = dict(
    label = "GCN_skippc_linear",
    collection = "m_sbm_cert_gcn_skippc",
    start_id = 981,
    end_id = 1225,
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha01_trn_exp = dict(
    label = "GCN_skipalpha_linear",
    relabel = "GCN_skipalpha_linear_alpha0.1",
    collection = "m_sbm_cert_gcn_skipalpha",
    start_id = 1961,
    end_id = 2205,
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha02_trn_exp = dict(
    label = "GCN_skipalpha_linear",
    relabel = "GCN_skipalpha_linear_alpha0.2",
    collection = "m_sbm_cert_gcn_skipalpha",
    start_id = 2206,
    end_id = 2450,
    n_seeds = 5,
)
K = 1.5
attack_nodes = "train_val"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 4, 8, 16, 40, 80]

# %%
experiments = [gcn_trn_exp, sgc_trn_exp, appnp_trn_exp, appnp_alpha1_trn_exp,
               gcn_skippc_linear_trn_exp, #gcn_skippc_relu_exp, 
               gcn_skipalpha_linear_alpha01_trn_exp, gcn_skipalpha_linear_alpha02_trn_exp] #,
            #    gcn_skipalpha_relu_alpha01_exp, gcn_skipalpha_relu_alpha02_exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN No. of experiments 98
# SGC No. of experiments 98
# APPNP_alpha0.2 No. of experiments 98
# APPNP_alpha1 No. of experiments 98
# GCN_skippc_linear No. of experiments 49
# GCN_skipalpha_linear No. of experiments 49
# GCN_skipalpha_linear No. of experiments 49

# %%
C_l = [0.01]
models = ["GCN","APPNP", "SGC", 
           "GCN_skippc_linear",
          "GCN_skipalpha_linear_alpha0.2", "APPNP_alpha1"]
legend_labels = ["GCN","APPNP", "SGC", 
           "GCN Skip-PC",
          "GCN Skip-$\\alpha$", "MLP"]
n_adv_plot = 16
savefig = f'gnn_mlp_cert_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
linf = True
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              linf=linf)

# %%
C_l = [0.01]
models = ["GCN","APPNP", "SGC", 
           "GCN_skippc_linear",
          "GCN_skipalpha_linear_alpha0.2", "APPNP_alpha1"]
legend_labels = ["GCN","APPNP", "SGC", 
           "GCN Skip-PC",
          "GCN Skip-$\\alpha$", "MLP"]
n_adv_plot = 80
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2]
savefig = f'gnn_mlp_cert_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
linf = True
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              linf=linf)

# %% [markdown]
# ### attack_nodes: train_val_backdoor

# %%
gcn_trn_bd_exp = dict(
    label = "GCN",
    collection = "m_sbm_cert_backdoor_gcn",
    start_id = 1,
    end_id = 245,
    n_seeds = 5,
)
appnp_trn_bd_exp = dict(
    label = "APPNP_alpha0.2",
    relabel = "APPNP",
    collection = "m_sbm_cert_backdoor_appnp",
    start_id = 491,
    end_id = 735,
    n_seeds = 5,
)
appnp_alpha1_trn_bd_exp = dict(
    label = "APPNP_alpha1",
    collection = "m_sbm_cert_backdoor_appnp",
    start_id = 1226,
    end_id = 1470,
    n_seeds = 5,
)
sgc_trn_bd_exp = dict(
    label = "SGC",
    collection = "m_sbm_cert_backdoor_sgc",
    start_id = 1,
    end_id = 245,
    n_seeds = 5,
)
gcn_skippc_linear_trn_bd_exp = dict(
    label = "GCN_skippc_linear",
    collection = "m_sbm_cert_backdoor_gcn_skippc",
    start_id = 1,
    end_id = 245,
    n_seeds = 5,
)
# gcn_skippc_relu_exp = dict(
#     label = "GCN_skippc_relu",
#     collection = "m_sbm_cert_gcn_skippc",
#     start_id = [1, 491],
#     end_id = [245, 735],
#     n_seeds = 5,
# )
gcn_skipalpha_linear_alpha01_trn_bd_exp = dict(
    label = "GCN_skipalpha_linear",
    relabel = "GCN_skipalpha_linear_alpha0.1",
    collection = "m_sbm_cert_backdoor_gcn_skipalpha",
    start_id = 1,
    end_id = 245,
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha02_trn_bd_exp = dict(
    label = "GCN_skipalpha_linear",
    relabel = "GCN_skipalpha_linear_alpha0.2",
    collection = "m_sbm_cert_backdoor_gcn_skipalpha",
    start_id = 246,
    end_id = 490,
    n_seeds = 5,
)
# gcn_skipalpha_relu_alpha01_exp = dict(
#     label = "GCN_skipalpha_relu_alpha0.1",
#     collection = "m_sbm_cert_gcn_skipalpha",
#     start_id = [1, 981],
#     end_id = [245, 1225],
#     n_seeds = 5,
# )
# gcn_skipalpha_relu_alpha02_exp = dict(
#     label = "GCN_skipalpha_relu_alpha0.2",
#     collection = "m_sbm_cert_gcn_skipalpha",
#     start_id = [246, 1226],
#     end_id = [490, 1470],
#     n_seeds = 5,
# )
K = 1.5
attack_nodes = "train_val_backdoor"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 4, 8, 16, 40, 80]

# %%
experiments = [gcn_trn_bd_exp, sgc_trn_bd_exp, appnp_trn_bd_exp, appnp_alpha1_trn_bd_exp,
               gcn_skippc_linear_trn_bd_exp, #gcn_skippc_relu_exp, 
               gcn_skipalpha_linear_alpha01_trn_bd_exp, gcn_skipalpha_linear_alpha02_trn_bd_exp] #,
            #    gcn_skipalpha_relu_alpha01_exp, gcn_skipalpha_relu_alpha02_exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN No. of experiments 49
# SGC No. of experiments 49
# APPNP_alpha0.2 No. of experiments 49
# APPNP_alpha1 No. of experiments 49
# GCN_skippc_linear No. of experiments 49
# GCN_skipalpha_linear No. of experiments 49
# GCN_skipalpha_linear No. of experiments 49

# %%
C_l = [0.01]
models = ["GCN","APPNP", "SGC", 
           "GCN_skippc_linear",
          "GCN_skipalpha_linear_alpha0.2", "APPNP_alpha1"]
legend_labels = ["GCN","APPNP", "SGC", 
           "GCN Skip-PC",
          "GCN Skip-$\\alpha$", "MLP"]
n_adv_plot = 16
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
savefig = f'gnn_mlp_cert_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
linf = True
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              linf=linf)

# %% [markdown]
# ### attack_nodes: test_backdoor

# %%
gcn_test_bd_exp = dict(
    label = "GCN",
    collection = "m_sbm_cert_backdoor_gcn",
    start_id = 246,
    end_id = 490,
    n_seeds = 5,
)
appnp_test_bd_exp = dict(
    label = "APPNP_alpha0.2",
    relabel = "APPNP",
    collection = "m_sbm_cert_backdoor_appnp",
    start_id = 1961,
    end_id = 2205,
    n_seeds = 5,
)
appnp_alpha1_test_bd_exp = dict(
    label = "APPNP_alpha1",
    collection = "m_sbm_cert_backdoor_appnp",
    start_id = 2696,
    end_id = 2940,
    n_seeds = 5,
)
sgc_test_bd_exp = dict(
    label = "SGC",
    collection = "m_sbm_cert_backdoor_sgc",
    start_id = 246,
    end_id = 490,
    n_seeds = 5,
)
gcn_skippc_linear_test_bd_exp = dict(
    label = "GCN_skippc_linear",
    collection = "m_sbm_cert_backdoor_gcn_skippc",
    start_id = 246,
    end_id = 490,
    n_seeds = 5,
)
# gcn_skippc_relu_exp = dict(
#     label = "GCN_skippc_relu",
#     collection = "m_sbm_cert_gcn_skippc",
#     start_id = [1, 491],
#     end_id = [245, 735],
#     n_seeds = 5,
# )
gcn_skipalpha_linear_alpha01_test_bd_exp = dict(
    label = "GCN_skipalpha_linear",
    relabel = "GCN_skipalpha_linear_alpha0.1",
    collection = "m_sbm_cert_backdoor_gcn_skipalpha",
    start_id = 491,
    end_id = 735,
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha02_test_bd_exp = dict(
    label = "GCN_skipalpha_linear",
    relabel = "GCN_skipalpha_linear_alpha0.2",
    collection = "m_sbm_cert_backdoor_gcn_skipalpha",
    start_id = 736,
    end_id = 980,
    n_seeds = 5,
)
# gcn_skipalpha_relu_alpha01_exp = dict(
#     label = "GCN_skipalpha_relu_alpha0.1",
#     collection = "m_sbm_cert_gcn_skipalpha",
#     start_id = [1, 981],
#     end_id = [245, 1225],
#     n_seeds = 5,
# )
# gcn_skipalpha_relu_alpha02_exp = dict(
#     label = "GCN_skipalpha_relu_alpha0.2",
#     collection = "m_sbm_cert_gcn_skipalpha",
#     start_id = [246, 1226],
#     end_id = [490, 1470],
#     n_seeds = 5,
# )
K = 1.5
attack_nodes = "test_backdoor"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 6, 12, 24, 60, 120]

# %%
experiments = [gcn_test_bd_exp, sgc_test_bd_exp, appnp_test_bd_exp, appnp_alpha1_test_bd_exp,
               gcn_skippc_linear_test_bd_exp, #gcn_skippc_relu_exp, 
               gcn_skipalpha_linear_alpha01_test_bd_exp, gcn_skipalpha_linear_alpha02_test_bd_exp] #,
            #    gcn_skipalpha_relu_alpha01_exp, gcn_skipalpha_relu_alpha02_exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN No. of experiments 49
# SGC No. of experiments 49
# APPNP_alpha0.2 No. of experiments 49
# APPNP_alpha1 No. of experiments 49
# GCN_skippc_linear No. of experiments 49
# GCN_skipalpha_linear No. of experiments 49
# GCN_skipalpha_linear No. of experiments 49

# %%
C_l = [0.01]
models = ["GCN","APPNP", "SGC", 
           "GCN_skippc_linear",
          "GCN_skipalpha_linear_alpha0.2", "APPNP_alpha1"]
legend_labels = ["GCN","APPNP", "SGC", 
           "GCN Skip-PC",
          "GCN Skip-$\\alpha$", "MLP"]
n_adv_plot = 24
savefig = f'gnn_mlp_cert_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
linf = True
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              linf=linf)

# %% [markdown]
# ### Adv attack

# %% [markdown]
# #### test nodes

# %%
gcn_exp = dict(
    label = "GCN",
    collection = "l_sbm_cert_gcn",
    start_id = 1,
    end_id = 735,
    n_seeds = 5,
)
gcn_adv_exp = dict(
    label = "GCN",
    relabel = "GCN_adv",
    collection = "m_sbm_fast_attack_gcn",
    start_id = 1,
    end_id = 245,
    n_seeds = 5,
)
sgc_exp = dict(
    label = "SGC",
    collection = "m_sbm_cert_sgc",
    start_id = 246,
    end_id = 490,
    n_seeds = 5,
)
sgc_adv_exp = dict(
    label = "SGC",
    relabel = "SGC_adv",
    collection = "m_sbm_fast_attack_sgc",
    start_id = 1,
    end_id = 245,
    n_seeds = 5,
)
appnp_exp = dict(
    label = "APPNP",
    collection = "l_sbm_cert_appnp",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
appnp_adv_exp = dict(
    label = "APPNP_alpha0.2",
    relabel = "APPNP_adv",
    collection = "m_sbm_fast_attack_appnp",
    start_id = 1,
    end_id = 245,
    n_seeds = 5,
)
appnp_alpha1_exp = dict(
    label = "APPNP_alpha1",
    relabel = "APPNP_alpha1_ls_solid",
    collection = "l_sbm_cert_appnp",
    start_id = 1471,
    end_id = 1715,
    n_seeds = 5,
)
appnp_alpha1_adv_exp = dict(
    label = "APPNP_alpha1",
    relabel = "APPNP_alpha1_adv",
    collection = "m_sbm_fast_attack_appnp",
    start_id = 246,
    end_id = 490,
    n_seeds = 5,
)
gcn_skippc_linear_exp = dict(
    label = "GCN_skippc_linear",
    collection = "m_sbm_cert_gcn_skippc",
    start_id = [246, 736],
    end_id = [490, 980],
    n_seeds = 5,
)
gcn_skippc_linear_adv_exp = dict(
    label = "GCN_skippc_linear",
    relabel = "GCN_skippc_linear_adv",
    collection = "m_sbm_fast_attack_gcn_skippc",
    start_id = 1,
    end_id = 245,
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha02_exp = dict(
    label = "GCN_skipalpha_linear_alpha0.2",
    collection = "m_sbm_cert_gcn_skipalpha",
    start_id = [736, 1716],
    end_id = [980, 1960],
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha02_adv_exp = dict(
    label = "GCN_skipalpha_linear",
    relabel = "GCN_skipalpha_linear_alpha0.2_adv",
    collection = "m_sbm_fast_attack_gcn_skipalpha",
    start_id = 1,
    end_id = 245,
    n_seeds = 5,
)
K = 1.5
attack_nodes = "test"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 6, 12, 24, 60, 120]

# %%
experiments = [gcn_exp, gcn_adv_exp,
               sgc_exp, sgc_adv_exp,
               appnp_exp, appnp_adv_exp,
               appnp_alpha1_exp, appnp_alpha1_adv_exp,
               gcn_skippc_linear_exp, gcn_skippc_linear_adv_exp,
               gcn_skipalpha_linear_alpha02_exp, gcn_skipalpha_linear_alpha02_adv_exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN No. of experiments 147
# GCN No. of experiments 49
# SGC No. of experiments 49
# SGC No. of experiments 49
# APPNP No. of experiments 98
# APPNP_alpha0.2 No. of experiments 49
# APPNP_alpha1 No. of experiments 49
# APPNP_alpha1 No. of experiments 49
# GCN_skippc_linear No. of experiments 49
# GCN_skippc_linear No. of experiments 49
# GCN_skippc_linear No. of experiments 49
# GCN_skipalpha_linear_alpha0.2 No. of experiments 49
# GCN_skipalpha_linear_alpha0.2 No. of experiments 49
# GCN_skipalpha_linear No. of experiments 49

# %%
C_l = [0.01]
models = ["GCN","GCN_adv",
          "APPNP", "APPNP_adv",
          "SGC", "SGC_adv",
          "GCN_skippc_linear", "GCN_skippc_linear_adv",
          "GCN_skipalpha_linear_alpha0.2", "GCN_skipalpha_linear_alpha0.2_adv",
          "APPNP_alpha1_ls_solid", "APPNP_alpha1_adv"]
legend_labels = ["GCN","_nolegend_",
                 "APPNP", "_nolegend_",
                 "SGC", "_nolegend_",
                 "GCN Skip-PC", "_nolegend_",
                 "GCN Skip-$\\alpha$", "_nolegend_",
                 "MLP", "_nolegend_"]
dummy_legends = [("-", "lower bound"), ("--", "upper bound")]
n_adv_plot = 24
savefig = f'gnn_mlp_adv_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
linf = True
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize-2,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              linf=linf,
                              dummy_legend=dummy_legends)

# %% [markdown]
# #### train_val attack

# %%
gcn_trn_exp = dict(
    label = "GCN",
    collection = "m_sbm_cert_gcn",
    start_id = 1961,
    end_id = 2450,
    n_seeds = 5,
)
gcn_trn_adv_exp = dict(
    label = "GCN",
    relabel = "GCN_adv",
    collection = "m_sbm_fast_attack_gcn",
    start_id = 246,
    end_id = 490,
    n_seeds = 5,
)
sgc_trn_exp = dict(
    label = "SGC",
    collection = "m_sbm_cert_sgc",
    start_id = 2451,
    end_id = 2940,
    n_seeds = 5,
)
sgc_trn_adv_exp = dict(
    label = "SGC",
    relabel = "SGC_adv",
    collection = "m_sbm_fast_attack_sgc",
    start_id = 246,
    end_id = 490,
    n_seeds = 5,
)
appnp_trn_exp = dict(
    label = "APPNP_alpha0.2",
    relabel = "APPNP",
    collection = "m_sbm_cert_appnp",
    start_id = 5391,
    end_id = 5880,
    n_seeds = 5,
)
appnp_trn_adv_exp = dict(
    label = "APPNP_alpha0.2",
    relabel = "APPNP_adv",
    collection = "m_sbm_fast_attack_appnp",
    start_id = 491,
    end_id = 735,
    n_seeds = 5,
)
appnp_alpha1_trn_exp = dict(
    label = "APPNP_alpha1",
    relabel = "APPNP_alpha1_ls_solid",
    collection = "m_sbm_cert_appnp",
    start_id = 6861,
    end_id = 7350,
    n_seeds = 5,
)
appnp_alpha1_trn_adv_exp = dict(
    label = "APPNP_alpha1",
    relabel = "APPNP_alpha1_adv",
    collection = "m_sbm_fast_attack_appnp",
    start_id = 736,
    end_id = 980,
    n_seeds = 5,
)
gcn_skippc_linear_trn_exp = dict(
    label = "GCN_skippc_linear",
    collection = "m_sbm_cert_gcn_skippc",
    start_id = 981,
    end_id = 1225,
    n_seeds = 5,
)
gcn_skippc_linear_trn_adv_exp = dict(
    label = "GCN_skippc_linear",
    relabel = "GCN_skippc_linear_adv",
    collection = "m_sbm_fast_attack_gcn_skippc",
    start_id = 246,
    end_id = 490,
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha02_trn_exp = dict(
    label = "GCN_skipalpha_linear",
    relabel = "GCN_skipalpha_linear_alpha0.2",
    collection = "m_sbm_cert_gcn_skipalpha",
    start_id = 2206,
    end_id = 2450,
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha02_trn_adv_exp = dict(
    label = "GCN_skipalpha_linear",
    relabel = "GCN_skipalpha_linear_alpha0.2_adv",
    collection = "m_sbm_fast_attack_gcn_skipalpha",
    start_id = 246,
    end_id = 490,
    n_seeds = 5,
)
K = 1.5
attack_nodes = "train_val"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 4, 8, 16, 40, 80]

# %%
experiments = [gcn_trn_exp, gcn_trn_adv_exp,
               sgc_trn_exp, sgc_trn_adv_exp,
               appnp_trn_exp, appnp_trn_adv_exp,
               appnp_alpha1_trn_exp, appnp_alpha1_trn_adv_exp,
               gcn_skippc_linear_trn_exp, gcn_skippc_linear_trn_adv_exp,
               gcn_skipalpha_linear_alpha02_trn_exp, gcn_skipalpha_linear_alpha02_trn_adv_exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN No. of experiments 98
# GCN No. of experiments 49
# SGC No. of experiments 98
# SGC No. of experiments 49
# APPNP_alpha0.2 No. of experiments 98
# APPNP_alpha0.2 No. of experiments 49
# APPNP_alpha1 No. of experiments 98
# APPNP_alpha1 No. of experiments 49
# GCN_skippc_linear No. of experiments 49
# GCN_skippc_linear No. of experiments 49
# GCN_skipalpha_linear No. of experiments 49
# GCN_skipalpha_linear No. of experiments 49

# %%
C_l = [0.01]
models = ["GCN","GCN_adv",
          "SGC","SGC_adv",
          "APPNP", "APPNP_adv",
          "APPNP_alpha1_ls_solid", "APPNP_alpha1_adv",
          "GCN_skippc_linear", "GCN_skippc_linear_adv",
          "GCN_skipalpha_linear_alpha0.2", "GCN_skipalpha_linear_alpha0.2_adv"]
legend_labels = ["GCN","_nolegend_",
                 "SGC", "_nolegend_",
                 "APPNP", "_nolegend_",
                 "MLP", "_nolegend_",
                 "GCN Skip-PC", "_nolegend_",
                 "GCN Skip-$\\alpha$", "_nolegend_",
                 ]
dummy_legends = [("-", "lower bound"), ("--", "upper bound")]
n_adv_plot = 16
savefig = f'gnn_mlp_adv_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
linf = True
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize-2,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              linf=linf,
                              dummy_legend=dummy_legends)

# %% [markdown]
# ### Sparsity
# labels with sparsity_1 : within_deg = 2x, between_deg = 2x
#
# labels with sparsity_2 : within_deg = x/2, between_deg = x/2
#
# labels with sparsity_3 : within_deg = x/4, between_deg = x/4

# %% [markdown]
# #### test nodes attacked

# %%
gcn_sparsity_1_exp = dict(
    label = "GCN_sparsity_1",
    collection = "m_sbm_cert_gcn",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
gcn_sparsity_2_exp = dict(
    label = "GCN_sparsity_2",
    collection = "m_sbm_cert_gcn",
    start_id = 491,
    end_id = 980,
    n_seeds = 5,
)
gcn_sparsity_3_exp = dict(
    label = "GCN_sparsity_3",
    collection = "m_sbm_cert_gcn",
    start_id = 981,
    end_id = 1470,
    n_seeds = 5,
)
sgc_sparsity_1_exp = dict(
    label = "SGC_sparsity_1",
    collection = "m_sbm_cert_sgc",
    start_id = 491,
    end_id = 980,
    n_seeds = 5,
)
sgc_sparsity_2_exp = dict(
    label = "SGC_sparsity_2",
    collection = "m_sbm_cert_sgc",
    start_id = 981,
    end_id = 1470,
    n_seeds = 5,
)
sgc_sparsity_3_exp = dict(
    label = "SGC_sparsity_3",
    collection = "m_sbm_cert_sgc",
    start_id = 1471,
    end_id = 1960,
    n_seeds = 5,
)
appnp_sparsity_1_exp = dict(
    label = "APPNP_sparsity_1",
    collection = "m_sbm_cert_appnp",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
appnp_sparsity_2_exp = dict(
    label = "APPNP_sparsity_2",
    collection = "m_sbm_cert_appnp",
    start_id = 491,
    end_id = 980,
    n_seeds = 5,
)
appnp_sparsity_3_exp = dict(
    label = "APPNP_sparsity_3",
    collection = "m_sbm_cert_appnp",
    start_id = 981,
    end_id = 1470,
    n_seeds = 5,
)
appnp_alpha1_exp = dict(
    label = "APPNP_alpha1",
    collection = "l_sbm_cert_appnp",
    start_id = 1471,
    end_id = 1715,
    n_seeds = 5,
)
K = 1.5
attack_nodes = "test"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 6, 12, 24, 60, 120]

# %%
experiments = [gcn_exp, sgc_exp, appnp_exp,
               gcn_sparsity_1_exp, gcn_sparsity_2_exp, gcn_sparsity_3_exp,
               sgc_sparsity_1_exp, sgc_sparsity_2_exp, sgc_sparsity_3_exp,
               appnp_sparsity_1_exp, appnp_sparsity_2_exp, appnp_sparsity_3_exp,
               appnp_alpha1_exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN No. of experiments 147
# SGC No. of experiments 49
# APPNP No. of experiments 98
# GCN_sparsity_1 No. of experiments 98
# GCN_sparsity_2 No. of experiments 98
# GCN_sparsity_3 No. of experiments 98
# SGC_sparsity_1 No. of experiments 98
# SGC_sparsity_2 No. of experiments 98
# SGC_sparsity_3 No. of experiments 98
# APPNP_sparsity_1 No. of experiments 98
# APPNP_sparsity_2 No. of experiments 98
# APPNP_sparsity_3 No. of experiments 98
# APPNP_alpha1 No. of experiments 49

# %%
C_l = [0.01]
models = ["GCN_sparsity_1", "GCN",  "GCN_sparsity_2", "GCN_sparsity_3", "APPNP_alpha1"]
legend_labels = ["GCN $2\\times$", "GCN $1\\times$", "GCN $0.5\\times$", "GCN $0.25\\times$", "GCN $0\\times$"]
n_adv_plot = 24
savefig = f'GCN_sparsity_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
linf = True
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              linf=linf)

# %%
C_l = [0.01]
models = ["SGC_sparsity_1","SGC",  "SGC_sparsity_2", "SGC_sparsity_3", "APPNP_alpha1"]
legend_labels = ["SGC $2\\times$", "SGC $1\\times$", "SGC $0.5\\times$", "SGC $0.25\\times$", "SGC $0\\times$"]

n_adv_plot = 24
savefig = f'SGC_sparsity_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
linf = True
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              linf=linf)

# %%
C_l = [0.01]
models = ["APPNP_sparsity_1","APPNP",  "APPNP_sparsity_2", "APPNP_sparsity_3", "APPNP_alpha1"]
legend_labels = ["APPNP $2\\times$", "APPNP $1\\times$", "APPNP $0.5\\times$", "APPNP $0.25\\times$", "APPNP $0\\times$"]

n_adv_plot = 24
savefig = f'APPNP_sparsity_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
linf = True
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              linf=linf)

# %% [markdown]
# #### train-val

# %%
gcn_sparsity_1_trn_exp = dict(
    label = "GCN_sparsity_1",
    collection = "m_sbm_cert_gcn",
    start_id = 2696,
    end_id = 2940,
    n_seeds = 5,
)
gcn_sparsity_2_trn_exp = dict(
    label = "GCN_sparsity_2",
    collection = "m_sbm_cert_gcn",
    start_id = 2941,
    end_id = 3185,
    n_seeds = 5,
)
gcn_sparsity_3_trn_exp = dict(
    label = "GCN_sparsity_3",
    collection = "m_sbm_cert_gcn",
    start_id = 3186,
    end_id = 3430,
    n_seeds = 5,
)
# sgc_sparsity_1_exp = dict(
#     label = "SGC_sparsity_1",
#     collection = "m_sbm_cert_sgc",
#     start_id = 491,
#     end_id = 980,
#     n_seeds = 5,
# )
# sgc_sparsity_2_exp = dict(
#     label = "SGC_sparsity_2",
#     collection = "m_sbm_cert_sgc",
#     start_id = 981,
#     end_id = 1470,
#     n_seeds = 5,
# )
# sgc_sparsity_3_exp = dict(
#     label = "SGC_sparsity_3",
#     collection = "m_sbm_cert_sgc",
#     start_id = 1471,
#     end_id = 1960,
#     n_seeds = 5,
# )
# appnp_sparsity_1_exp = dict(
#     label = "APPNP_sparsity_1",
#     collection = "m_sbm_cert_appnp",
#     start_id = 1,
#     end_id = 490,
#     n_seeds = 5,
# )
# appnp_sparsity_2_exp = dict(
#     label = "APPNP_sparsity_2",
#     collection = "m_sbm_cert_appnp",
#     start_id = 491,
#     end_id = 980,
#     n_seeds = 5,
# )
# appnp_sparsity_3_exp = dict(
#     label = "APPNP_sparsity_3",
#     collection = "m_sbm_cert_appnp",
#     start_id = 981,
#     end_id = 1470,
#     n_seeds = 5,
# )
# appnp_alpha1_exp = dict(
#     label = "APPNP_alpha1",
#     collection = "l_sbm_cert_appnp",
#     start_id = 1471,
#     end_id = 1715,
#     n_seeds = 5,
# )
K = 1.5
attack_nodes = "train_val"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 4, 8, 16, 40, 80]

# %%
experiments = [gcn_trn_exp, #sgc_exp, appnp_exp,
               gcn_sparsity_1_trn_exp, gcn_sparsity_2_trn_exp, gcn_sparsity_3_trn_exp,
            #    sgc_sparsity_1_exp, sgc_sparsity_2_exp, sgc_sparsity_3_exp,
            #    appnp_sparsity_1_exp, appnp_sparsity_2_exp, appnp_sparsity_3_exp,
            #    appnp_alpha1_exp
            ]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN No. of experiments 98
# GCN_sparsity_1 No. of experiments 49
# GCN_sparsity_2 No. of experiments 49
# GCN_sparsity_3 No. of experiments 49

# %%
C_l = [0.01]
models = ["GCN_sparsity_1", "GCN",  "GCN_sparsity_2", "GCN_sparsity_3"]#, "APPNP_alpha1"]
legend_labels = ["GCN $2\\times$", "GCN $1\\times$", "GCN $0.5\\times$", "GCN $0.25\\times$"]#, "GCN $0\\times$"]
n_adv_plot = 16
savefig = f'GCN_sparsity_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
linf = True
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              linf=linf)

# %% [markdown]
# ### APPNP alpha

# %% [markdown]
# #### test

# %%
appnp_alpha0_exp = dict(
    label = "APPNP_alpha0",
    collection = "l_sbm_cert_appnp",
    start_id = 736,
    end_id = 980,
    n_seeds = 5,
)
appnp_alpha01_exp = dict(
    label = "APPNP_alpha0.1",
    collection = "l_sbm_cert_appnp",
    start_id = 491,
    end_id = 735,
    n_seeds = 5,
)
appnp_exp = dict(
    label = "APPNP",
    collection = "l_sbm_cert_appnp",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
appnp_alpha03_exp = dict(
    label = "APPNP_alpha0.3",
    collection = "l_sbm_cert_appnp",
    start_id = 981,
    end_id = 1225,
    n_seeds = 5,
)
appnp_alpha05_exp = dict(
    label = "APPNP_alpha0.5",
    collection = "l_sbm_cert_appnp",
    start_id = 1226,
    end_id = 1470,
    n_seeds = 5,
)
appnp_alpha1_exp = dict(
    label = "APPNP_alpha1",
    collection = "l_sbm_cert_appnp",
    start_id = 1471,
    end_id = 1715,
    n_seeds = 5,
)
K = 1.5
attack_nodes = "test"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 6, 12, 24, 60, 120]

# %%
experiments = [appnp_exp, 
               appnp_alpha0_exp, appnp_alpha01_exp, appnp_alpha03_exp, 
               appnp_alpha05_exp, appnp_alpha1_exp
               ]
experiment_manager = ExperimentManager(experiments)
# Out:
# APPNP No. of experiments 98
# APPNP_alpha0 No. of experiments 49
# APPNP_alpha0.1 No. of experiments 49
# APPNP_alpha0.3 No. of experiments 49
# APPNP_alpha0.5 No. of experiments 49
# APPNP_alpha1 No. of experiments 49

# %%
C_l = [0.01]
models = [ "APPNP_alpha0", "APPNP_alpha0.1", "APPNP", "APPNP_alpha0.3", "APPNP_alpha0.5", "APPNP_alpha1"]
legend_labels = [ "$\\alpha=0.0$", "$\\alpha=0.1$", "$\\alpha=0.2$", 
                 "$\\alpha=0.3$", "$\\alpha=0.5$", "$\\alpha=1.0$ (MLP)"]
n_adv_plot = 24
savefig = f'APPNP_graph_information_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
linf = True
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              linf=linf)

# %% [markdown]
# #### train_val

# %%
appnp_alpha0_trn_exp = dict(
    label = "APPNP_alpha0",
    collection = "m_sbm_cert_appnp",
    start_id = 4411,
    end_id = 4900,
    n_seeds = 5,
)
appnp_alpha01_trn_exp = dict(
    label = "APPNP_alpha0.1",
    collection = "m_sbm_cert_appnp",
    start_id = 4901,
    end_id = 5390,
    n_seeds = 5,
)
appnp_trn_exp = dict(
    label = "APPNP_alpha0.2",
    relabel = "APPNP",
    collection = "m_sbm_cert_appnp",
    start_id = 5391,
    end_id = 5880,
    n_seeds = 5,
)
appnp_alpha03_trn_exp = dict(
    label = "APPNP_alpha0.3",
    collection = "m_sbm_cert_appnp",
    start_id = 5881,
    end_id = 6370,
    n_seeds = 5,
)
appnp_alpha05_trn_exp = dict(
    label = "APPNP_alpha0.5",
    collection = "m_sbm_cert_appnp",
    start_id = 6371,
    end_id = 6860,
    n_seeds = 5,
)
appnp_alpha1_trn_exp = dict(
    label = "APPNP_alpha1",
    collection = "m_sbm_cert_appnp",
    start_id = 6861,
    end_id = 7350,
    n_seeds = 5,
)
K = 1.5
attack_nodes = "train_val"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 4, 8, 16, 40, 80]

# %%
experiments = [appnp_trn_exp, 
               appnp_alpha0_trn_exp, appnp_alpha01_trn_exp, appnp_alpha03_trn_exp, 
               appnp_alpha05_trn_exp, appnp_alpha1_trn_exp
               ]
experiment_manager = ExperimentManager(experiments)
# Out:
# APPNP_alpha0.2 No. of experiments 98
# APPNP_alpha0 No. of experiments 98
# APPNP_alpha0.1 No. of experiments 98
# APPNP_alpha0.3 No. of experiments 98
# APPNP_alpha0.5 No. of experiments 98
# APPNP_alpha1 No. of experiments 98

# %%
C_l = [0.01]
models = [ "APPNP_alpha0", "APPNP_alpha0.1", "APPNP", "APPNP_alpha0.3", "APPNP_alpha0.5", "APPNP_alpha1"]
legend_labels = [ "$\\alpha=0.0$", "$\\alpha=0.1$", "$\\alpha=0.2$", 
                 "$\\alpha=0.3$", "$\\alpha=0.5$", "$\\alpha=1.0$ (MLP)"]
n_adv_plot = 16
savefig = f'APPNP_graph_information_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
linf = True
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              linf=linf)

# %% [markdown]
# ### Heatmap

# %%
hm_label_fontsize=26 #20,
hm_ticks_fontsize=15 #10,
hm_cbar_fontsize=22

# %% [markdown]
# #### test attack

# %%
experiments = [gcn_exp, appnp_exp, sgc_exp, appnp_alpha1_exp,
               gcn_skippc_linear_exp, 
               gcn_skipalpha_linear_alpha01_exp, gcn_skipalpha_linear_alpha02_exp,
               ]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN No. of experiments 147
# APPNP No. of experiments 98
# SGC No. of experiments 49
# APPNP_alpha1 No. of experiments 49
# GCN_skippc_linear No. of experiments 49
# GCN_skippc_linear No. of experiments 49
# GCN_skipalpha_linear_alpha0.1 No. of experiments 49
# GCN_skipalpha_linear_alpha0.1 No. of experiments 49
# GCN_skipalpha_linear_alpha0.2 No. of experiments 49
# GCN_skipalpha_linear_alpha0.2 No. of experiments 49

# %%
C = 0.01
model = "GCN"
mlp = "APPNP_alpha1"
savefig = f'{model}_graph_info_robust_gain_attack{attack_nodes}_C{C}_linf.pdf'
linf = True
xticks_l = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.2, savefig=savefig,
                              label_fontsize=hm_label_fontsize, #20,
                              ticks_fontsize=hm_ticks_fontsize, #10,
                              cbar_fontsize=hm_cbar_fontsize,
                              linf=linf,
                              xticks_l=xticks_l)

# %%
C = 0.01
model = "SGC"
mlp = "APPNP_alpha1"
savefig = f'{model}_graph_info_robust_gain_attack{attack_nodes}_C{C}_linf.pdf'
title_label = "SGC"
linf = True
xticks_l = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.2, savefig=savefig,
                              label_fontsize=hm_label_fontsize, #20,
                              ticks_fontsize=hm_ticks_fontsize, #10,
                              cbar_fontsize=hm_cbar_fontsize,
                              linf=linf,
                              xticks_l=xticks_l)

# %%
C = 0.01
model = "APPNP"
mlp = "APPNP_alpha1"
savefig = f'{model}_graph_info_robust_gain_linf.pdf'
linf = True
xticks_l = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.2, savefig=savefig,
                              label_fontsize=hm_label_fontsize, #20,
                              ticks_fontsize=hm_ticks_fontsize, #10,
                              cbar_fontsize=hm_cbar_fontsize,
                              linf=linf,
                              xticks_l=xticks_l)

# %%
C = 0.01
model = "GCN_skippc_linear"
mlp = "APPNP_alpha1"
savefig = f'{model}_graph_info_robust_gain_linf.pdf'
linf = True
xticks_l = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.2, savefig=savefig,
                              label_fontsize=hm_label_fontsize, #20,
                              ticks_fontsize=hm_ticks_fontsize, #10,
                              cbar_fontsize=hm_cbar_fontsize,
                              linf=linf,
                              xticks_l=xticks_l)

# %%
C = 0.01
model = "GCN_skipalpha_linear_alpha0.2"
mlp = "APPNP_alpha1"
savefig = f'{model}_graph_info_robust_gain_linf.pdf'
xticks_l = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
linf = True
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.2, savefig=savefig,
                              label_fontsize=hm_label_fontsize, #20,
                              ticks_fontsize=hm_ticks_fontsize, #10,
                              cbar_fontsize=hm_cbar_fontsize,
                              linf=linf,
                              xticks_l=xticks_l)

# %% [markdown]
# ## architecture insight

# %% [markdown]
# ### row vs sym

# %%
gcn_row_exp = dict(
    label = "GCN_row",
    collection = "m_dcsbm_cert_gcn",
    start_id = 1,
    end_id = 245,
    n_seeds = 5,
)
gcn_sym_exp = dict(
    label = "GCN_sym",
    collection = "m_dcsbm_cert_gcn",
    start_id = 246,
    end_id = 490,
    n_seeds = 5,
)
sgc_row_exp = dict(
    label = "SGC_row",
    collection = "m_dcsbm_cert_sgc",
    start_id = 1,
    end_id = 245,
    n_seeds = 5,
)
sgc_sym_exp = dict(
    label = "SGC_sym",
    collection = "m_dcsbm_cert_sgc",
    start_id = 246,
    end_id = 490,
    n_seeds = 5,
)
K = 1.5
attack_nodes = "test"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 6, 12, 24, 60, 120]

# %%
experiments = [gcn_row_exp, gcn_sym_exp, sgc_row_exp, sgc_sym_exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN_row No. of experiments 49
# GCN_sym No. of experiments 49
# SGC_row No. of experiments 49
# SGC_sym No. of experiments 49

# %%
C_l = [0.01]
models = ["GCN_row","GCN_sym",
        "SGC_row","SGC_sym"]
legend_labels = ["GCN row","GCN sym",
            "SGC row","SGC sym"]
n_adv_plot = 24
savefig = f'row_sym_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
linf = True
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              linf=linf)

# %% [markdown]
# ### depth

# %%
sgc_exp = dict(
    label = "SGC",
    collection = "m_sbm_cert_sgc",
    start_id = 246,
    end_id = 490,
    n_seeds = 5,
)
sgc_depth2_exp = dict(
    label = "SGC_depth2",
    collection = "m_sbm_cert_sgc_depth2",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
sgc_depth4_exp = dict(
    label = "SGC_depth4",
    collection = "m_sbm_cert_sgc_depth4",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
gcn_skippc_linear_exp = dict(
    label = "GCN_skippc_linear",
    collection = "m_sbm_cert_gcn_skippc",
    start_id = [246, 736],
    end_id = [490, 980],
    n_seeds = 5,
)
gcn_skippc_linear_depth2_exp = dict(
    label = "GCN_skippc_linear_depth2",
    collection = "m_sbm_cert_gcn_skippc_depth2",
    start_id = [246, 736],
    end_id = [490, 980],
    n_seeds = 5,
)
gcn_skippc_linear_depth4_exp = dict(
    label = "GCN_skippc_linear_depth4",
    collection = "m_sbm_cert_gcn_skippc_depth4",
    start_id = [246, 736],
    end_id = [490, 980],
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha01_exp = dict(
    label = "GCN_skipalpha_linear_alpha0.1",
    collection = "m_sbm_cert_gcn_skipalpha",
    start_id = [491, 1471],
    end_id = [735, 1715],
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha01_depth2_exp = dict(
    label = "GCN_skipalpha_linear_alpha0.1_depth2",
    collection = "m_sbm_cert_gcn_skipalpha_depth2",
    start_id = [491, 1471],
    end_id = [735, 1715],
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha01_depth4_exp = dict(
    label = "GCN_skipalpha_linear_alpha0.1_depth4",
    collection = "m_sbm_cert_gcn_skipalpha_depth4",
    start_id = [491, 1471],
    end_id = [735, 1715],
    n_seeds = 5,
)
K = 1.5
attack_nodes = "test"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 6, 12, 24, 60, 120]

# %%
experiments = [sgc_exp, sgc_depth2_exp, sgc_depth4_exp, 
                # gcn_skippc_linear_exp, gcn_skippc_linear_depth2_exp, gcn_skippc_linear_depth4_exp,
            #    gcn_skipalpha_linear_alpha01_depth4_exp, gcn_skipalpha_linear_alpha01_depth2_exp, gcn_skipalpha_linear_alpha01_depth4_exp, 
               ]
experiment_manager = ExperimentManager(experiments)
# Out:
# SGC No. of experiments 49
# SGC_depth2 No. of experiments 98
# SGC_depth4 No. of experiments 98

# %%
C_l = [0.01]
models = ["SGC", "SGC_depth2", "SGC_depth4"]
legend_labels = ["SGC $L=1$", "SGC $L=2$", "SGC $L=4$"]
n_adv_plot = 24
savefig = f'sgc_depth_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
linf = True
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              linf=linf)

# %% [markdown]
# ## old

# %%
C = 0.01
model = "GCN"
mlp = "APPNP_alpha1"
n_adv_plot = 24
savefig = f'{model}_graph_info_robust_gain_C{C}_linf.png'
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.5, savefig=savefig)

# %%
C = 0.01
model = "GCN"
mlp = "APPNP_alpha1"
n_adv_plot = 24
savefig = f'{model}_graph_info_robust_gain_C{C}_linf.png'
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.5, cbar_normalized=False)

# %%
C = 0.01
model = "SGC"
mlp = "APPNP_alpha1"
n_adv_plot = 24
savefig = f'{model}_graph_info_robust_gain_C{C}_linf.png'
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.5, savefig=savefig)

# %%
C = 0.01
model = "APPNP"
mlp = "APPNP_alpha1"
n_adv_plot = 24
savefig = f'{model}_graph_info_robust_gain_C{C}_linf.png'
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.5, savefig=savefig)

# %%
C = 0.01
model = "GCN_skippc_linear"
mlp = "APPNP_alpha1"
n_adv_plot = 24
savefig = f'{model}_graph_info_robust_gain_C{C}_linf.png'
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.5, savefig=savefig)

# %%
C = 0.01
model = "GCN_skipalpha_linear_alpha0.2"
mlp = "APPNP_alpha1"
n_adv_plot = 24
savefig = f'{model}_graph_info_robust_gain_C{C}_linf.png'
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.5, savefig=savefig)

# %% [markdown]
# ## Sparsity vs robustness
# labels with sparsity_1 : within_deg = 2x, between_deg = 2x
#
# labels with sparsity_2 : within_deg = x/2, between_deg = x/2
#
# labels with sparsity_3 : within_deg = x/4, between_deg = x/4

# %%
gcn_sparsity_1_exp = dict(
    label = "GCN_sparsity_1",
    collection = "m_sbm_cert_gcn",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
gcn_sparsity_2_exp = dict(
    label = "GCN_sparsity_2",
    collection = "m_sbm_cert_gcn",
    start_id = 491,
    end_id = 980,
    n_seeds = 5,
)
gcn_sparsity_3_exp = dict(
    label = "GCN_sparsity_3",
    collection = "m_sbm_cert_gcn",
    start_id = 981,
    end_id = 1470,
    n_seeds = 5,
)
sgc_sparsity_1_exp = dict(
    label = "SGC_sparsity_1",
    collection = "m_sbm_cert_sgc",
    start_id = 491,
    end_id = 980,
    n_seeds = 5,
)
sgc_sparsity_2_exp = dict(
    label = "SGC_sparsity_2",
    collection = "m_sbm_cert_sgc",
    start_id = 981,
    end_id = 1470,
    n_seeds = 5,
)
sgc_sparsity_3_exp = dict(
    label = "SGC_sparsity_3",
    collection = "m_sbm_cert_sgc",
    start_id = 1471,
    end_id = 1960,
    n_seeds = 5,
)
appnp_sparsity_1_exp = dict(
    label = "APPNP_sparsity_1",
    collection = "m_sbm_cert_appnp",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
appnp_sparsity_2_exp = dict(
    label = "APPNP_sparsity_2",
    collection = "m_sbm_cert_appnp",
    start_id = 491,
    end_id = 980,
    n_seeds = 5,
)
appnp_sparsity_3_exp = dict(
    label = "APPNP_sparsity_3",
    collection = "m_sbm_cert_appnp",
    start_id = 981,
    end_id = 1470,
    n_seeds = 5,
)

# %%
experiments = [gcn_exp, sgc_exp, 
               gcn_sparsity_1_exp, gcn_sparsity_2_exp, gcn_sparsity_3_exp,
               sgc_sparsity_1_exp, sgc_sparsity_2_exp, sgc_sparsity_3_exp
               ]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN No. of experiments 147
# SGC No. of experiments 98
# GCN_sparsity_1 No. of experiments 98
# GCN_sparsity_2 No. of experiments 98
# GCN_sparsity_3 No. of experiments 98
# SGC_sparsity_1 No. of experiments 98
# SGC_sparsity_2 No. of experiments 98
# SGC_sparsity_3 No. of experiments 98

# %%
C_l = [0.001]
models = ["GCN_sparsity_1", "GCN",  "GCN_sparsity_2", "GCN_sparsity_3"]
legend_labels = ["GCN $2\\times$", "GCN $1\\times$", "GCN $0.5\\times$", "GCN $0.25\\times$"]
n_adv_plot = 24
savefig = f'GCN_sparsity_C{C_l[0]}_adv{n_adv_plot}_linf.png'
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, legend_labels=legend_labels, xlogscale=False, savefig=savefig)

# %%
C_l = [0.01]
models = ["GCN_sparsity_1", "GCN",  "GCN_sparsity_2", "GCN_sparsity_3"]
legend_labels = ["GCN $2\\times$", "GCN $1\\times$", "GCN $0.5\\times$", "GCN $0.25\\times$"]
n_adv_plot = 24
savefig = f'GCN_sparsity_C{C_l[0]}_adv{n_adv_plot}_linf.png'
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, legend_labels=legend_labels, xlogscale=False, savefig=savefig)

# %%
C_l = [0.001]
models = ["SGC_sparsity_1","SGC",  "SGC_sparsity_2", "SGC_sparsity_3"]
legend_labels = ["SGC $2\\times$", "SGC $1\\times$", "SGC $0.5\\times$", "SGC $0.25\\times$"]

n_adv_plot = 24
savefig = f'SGC_sparsity_C{C_l[0]}_adv{n_adv_plot}_linf.png'
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, legend_labels=legend_labels, xlogscale=False, savefig=savefig)

# %%
C_l = [0.01]
models = ["SGC_sparsity_1","SGC",  "SGC_sparsity_2", "SGC_sparsity_3"]
legend_labels = ["SGC $2\\times$", "SGC $1\\times$", "SGC $0.5\\times$", "SGC $0.25\\times$"]

n_adv_plot = 24
savefig = f'SGC_sparsity_C{C_l[0]}_adv{n_adv_plot}_linf.png'
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, legend_labels=legend_labels, xlogscale=False, savefig=savefig)

# %%
experiments = [appnp_exp, 
               appnp_sparsity_1_exp, appnp_sparsity_2_exp, appnp_sparsity_3_exp
               ]
experiment_manager = ExperimentManager(experiments)
# Out:
# APPNP No. of experiments 98
# APPNP_sparsity_1 No. of experiments 98
# APPNP_sparsity_2 No. of experiments 98
# APPNP_sparsity_3 No. of experiments 98

# %%
C_l = [0.01]
models = ["APPNP_sparsity_1","APPNP",  "APPNP_sparsity_2", "APPNP_sparsity_3"]
legend_labels = ["APPNP $2\\times$", "APPNP $1\\times$", "APPNP $0.5\\times$", "APPNP $0.25\\times$"]

n_adv_plot = 24
savefig = f'APPNP_sparsity_C{C_l[0]}_adv{n_adv_plot}_linf.png'
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, legend_labels=legend_labels, xlogscale=False, savefig=savefig)

# %%
C_l = [0.001]
models = ["APPNP_sparsity_1","APPNP",  "APPNP_sparsity_2", "APPNP_sparsity_3"]
legend_labels = ["APPNP $2\\times$", "APPNP $1\\times$", "APPNP $0.5\\times$", "APPNP $0.25\\times$"]

n_adv_plot = 24
savefig = f'APPNP_sparsity_C{C_l[0]}_adv{n_adv_plot}_linf.png'
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, legend_labels=legend_labels, xlogscale=False, savefig=savefig)

# %% [markdown]
# ## Collective certificate

# %%
sgc_coll_exp = dict(
    label = "SGC",
    collection = "m_sbm_collective_cert_sgc",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
gcn_coll_exp = dict(
    label = "GCN",
    collection = "m_sbm_collective_cert_gcn",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
K = 1.5

# %%
experiments = [gcn_coll_exp, sgc_coll_exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN No. of experiments 98
# SGC No. of experiments 98

# %%
C_l = [0.01]
models = ["GCN", "SGC"]
legend_labels = ["GCN","SGC"]
n_adv_plot = 24
savefig = None #f'gnn_certificate_C{C_l[0]}_adv{n_adv_plot}_linf.png'
experiment_manager.plot_collective_cert_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, legend_labels=legend_labels, xlogscale=False, savefig=savefig)

# %%
C_l = [0.01]
models = ["GCN", "SGC"]
legend_labels = ["GCN","SGC"]
n_adv_plot = 60
savefig = None #f'gnn_certificate_C{C_l[0]}_adv{n_adv_plot}_linf.png'
experiment_manager.plot_collective_cert_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, legend_labels=legend_labels, xlogscale=False, savefig=savefig)

# %%
C_l = [0.01]
models = ["GCN", "SGC"]
legend_labels = ["GCN","SGC"]
n_adv_plot = 120
savefig = None #f'gnn_certificate_C{C_l[0]}_adv{n_adv_plot}_linf.png'
experiment_manager.plot_collective_cert_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, legend_labels=legend_labels, xlogscale=False, savefig=savefig)

# %%
C_l = [0.01]
models = ["GCN","SGC"]
legend_labels = ["GCN", "SGC"]
n_adv_plot = 24
savefig = None #f'gnn_certificate_C{C_l[0]}_adv{n_adv_plot}_linf.png'
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, legend_labels=legend_labels, xlogscale=False, savefig=savefig)

# %%
C_l = [0.01]
models = ["GCN","SGC"]
legend_labels = ["GCN", "SGC"]
n_adv_plot = 60
savefig = None #f'gnn_certificate_C{C_l[0]}_adv{n_adv_plot}_linf.png'
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, legend_labels=legend_labels, xlogscale=False, savefig=savefig)

# %% [markdown]
# ## collective vs non collective

# %%
sgc_coll_exp = dict(
    label = "SGC",
    relabel = "SGC_coll",
    collection = "m_sbm_collective_cert_sgc",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
gcn_coll_exp = dict(
    label = "GCN",
    relabel = "GCN_coll",
    collection = "m_sbm_collective_cert_gcn",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
K = 1.5

# %%
experiments = [gcn_exp, gcn_coll_exp, sgc_exp, sgc_coll_exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN No. of experiments 147
# GCN No. of experiments 98
# SGC No. of experiments 98
# SGC No. of experiments 98

# %%
C_l = [0.01]
models = ["GCN","SGC","GCN_coll","SGC_coll" ]
legend_labels = ["GCN", "SGC", "GCN collective", "SGC collective"]
n_adv_plot = 24
savefig = None #f'gnn_certificate_C{C_l[0]}_adv{n_adv_plot}_linf.png'
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, legend_labels=legend_labels, xlogscale=False, savefig=savefig)

# %%
C_l = [0.01]
models = ["GCN","SGC","GCN_coll","SGC_coll" ]
legend_labels = ["GCN", "SGC", "GCN collective", "SGC collective"]
n_adv_plot = 24
delta_ll = [0.1, 0.2, 0.5, 1]
savefig = None #f'gnn_certificate_C{C_l[0]}_adv{n_adv_plot}_linf.png'
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_ll, legend_labels=legend_labels, xlogscale=False, savefig=savefig)

# %%
C_l = [0.01]
models = ["GCN","SGC","GCN_coll","SGC_coll" ]
legend_labels = ["GCN", "SGC", "GCN collective", "SGC collective"]
n_adv_plot = 24
delta_ll = [0, 0.01, 0.02, 0.05, 0.1]
savefig = None #f'gnn_certificate_C{C_l[0]}_adv{n_adv_plot}_linf.png'
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_ll, legend_labels=legend_labels, xlogscale=False, savefig=savefig)

# %%
C_l = [0.01]
models = ["GCN","SGC","GCN_coll","SGC_coll" ]
legend_labels = ["GCN", "SGC", "GCN collective", "SGC collective"]
n_adv_plot = 60
# n_adv_l = [1, 2, 6, 12, 24, 60, 120]
delta_ll = [0.1, 0.2, 0.5, 1]
savefig = None #f'gnn_certificate_C{C_l[0]}_adv{n_adv_plot}_linf.png'
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, legend_labels=legend_labels, xlogscale=False, savefig=savefig)

# %%
C_l = [0.01]
models = ["GCN","SGC","GCN_coll","SGC_coll" ]
legend_labels = ["GCN", "SGC", "GCN collective", "SGC collective"]
n_adv_plot = 120
# n_adv_l = [1, 2, 6, 12, 24, 60, 120]
delta_ll = [0.1, 0.2, 0.5, 1]
savefig = None #f'gnn_certificate_C{C_l[0]}_adv{n_adv_plot}_linf.png'
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, legend_labels=legend_labels, xlogscale=False, savefig=savefig)

# %% [markdown]
# ## old

# %%
C_l = [0.01]
experiment_manager.plot_robust_acc_delta_nadv(K, ["GCN"], C_l, attack_nodes, 
                                              n_adv_l=n_adv_l, delta_l=delta_l)

# %%
C_l = [0.01]
models = ["GCN","APPNP", "SGC", "GCN_skippc_relu"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.001]
models = ["GCN","APPNP", "SGC", "GCN_skippc_linear", "GCN_skippc_relu"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.01]
models = ["GCN", "APPNP", "APPNP_alpha0.1", "GCN_skippc", "SGC"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.01]
experiment_manager.plot_robust_acc_delta(K, ["GCN", "APPNP"], C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.01, 0.001]
experiment_manager.plot_robust_acc_delta(K, ["APPNP"], C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.01]
models = ["SGC", "SGC_depth2", "SGC_depth4"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=24, delta_l=delta_l)

# %%
C_l = [0.01]
models = ["SGC", "SGC_depth2", "SGC_depth4"]
n_adv_list = [12, 24]
experiment_manager.plot_robust_acc_delta_nadv(K, models, C_l, attack_nodes, 
                                              n_adv_l=n_adv_list, delta_l=delta_l)

# %%
C = 0.01
experiment_manager.plot_nadv_delta_heatmap(K, ["GCN"], C, 
                              attack_nodes, n_adv_l, delta_l[::-1],
                              width=1, ratio=1.5, cbar_normalized=True)

# %%
C = 0.01
experiment_manager.plot_nadv_delta_heatmap(K, ["APPNP"], C, 
                              attack_nodes, n_adv_l, delta_l[::-1],
                              width=1, ratio=1.5, cbar_normalized=True)

# %%
C = 0.01
experiment_manager.plot_nadv_delta_heatmap(K, ["SGC"], C, 
                              attack_nodes, n_adv_l, delta_l[::-1],
                              width=1, ratio=1.5, cbar_normalized=True)

# %%
C = 0.01
experiment_manager.plot_nadv_delta_heatmap(K, ["GCN_skippc"], C, 
                              attack_nodes, n_adv_l, delta_l[::-1],
                              width=1, ratio=1.5, cbar_normalized=True)
