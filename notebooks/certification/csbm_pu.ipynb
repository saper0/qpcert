# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})

# %%
label_fontsize = 29
legend_fontsize = 16 #18
ticks_fontsize = 16 #18
use_custom_legend = True
linewidth = 1.5
markersize = 6
capsize = 6
framealpha = 0.5

# %% [markdown]
# # L1

# %%
gcn_l1_exp = dict(
    label = "GCN",
    collection = "m_sbm_cert_pu",
    start_id = 1,
    end_id = 245,
    n_seeds = 5,
)
appnp_l1_exp = dict(
    label = "APPNP_0.2",
    relabel = "APPNP",
    collection = "m_sbm_cert_pu",
    start_id = 736,
    end_id = 980,
    n_seeds = 5,
)
sgc_l1_exp = dict(
    label = "SGC",
    collection = "m_sbm_cert_pu",
    start_id = 246,
    end_id = 490,
    n_seeds = 5,
)
mlp_l1_exp = dict(
    label = "MLP",
    collection = "m_sbm_cert_pu",
    start_id = 491,
    end_id = 735,
    n_seeds = 5,
)
gin_l1_exp = dict(
    label = "GIN",
    collection = "m_sbm_cert_pu",
    start_id = 981,
    end_id = 1225,
    n_seeds = 5,
)
graphsage_l1_exp = dict(
    label = "GraphSage",
    collection = "m_sbm_cert_pu",
    start_id = 1961,
    end_id = 2205,
    n_seeds = 5,
)
gcnskippc_l1_exp = dict(
    label = "GCN_skippc_linear",
    collection = "m_sbm_cert_pu",
    start_id = 2696,
    end_id = 2940,
    n_seeds = 5,
)
gcnskipalp_l1_exp = dict(
    label = "GCN_skipalpha_linear_alpha0.2",
    collection = "m_sbm_cert_pu",
    start_id = 2451,
    end_id = 2695,
    n_seeds = 5,
)
K = 1.5
attack_nodes = "test"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 6, 12, 24, 60, 120]

# %%
experiments = [gcn_l1_exp, appnp_l1_exp, sgc_l1_exp, mlp_l1_exp,
               gin_l1_exp, graphsage_l1_exp, gcnskippc_l1_exp, gcnskipalp_l1_exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN No. of experiments 49
# APPNP_0.2 No. of experiments 49
# SGC No. of experiments 49
# MLP No. of experiments 49
# GIN No. of experiments 49
# GraphSage No. of experiments 49
# GCN_skippc_linear No. of experiments 49
# GCN_skipalpha_linear_alpha0.2 No. of experiments 49

# %%
C_l = [0.01]
models = [
            "GCN","APPNP", "SGC", 
             "GIN", "GraphSage", 
            "GCN_skippc_linear", "GCN_skipalpha_linear_alpha0.2", 
            "MLP"]
legend_labels = ["GCN","APPNP", "SGC",
                 "GIN", "GraphSAGE",
                "GCN Skip-PC", "GCN Skip-$\\alpha$", 
                "MLP"]
n_adv_plot = 24
pert_model = "l1"
savefig = f'csbm_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_{pert_model}.pdf'
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              pert_model=pert_model)

# %%
C = 0.01
model = "GCN"
mlp = "MLP"
# title_label = "GIN"
pert = "l1"
savefig = f'{model}_graph_info_robust_gain_attack{attack_nodes}_C{C}_{pert}.pdf'
xticks_l = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
hm_label_fontsize=26 #20,
hm_ticks_fontsize=15 #10,
hm_cbar_fontsize=22
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.2, savefig=savefig,
                              label_fontsize=hm_label_fontsize, #20,
                              ticks_fontsize=hm_ticks_fontsize, #10,
                              cbar_fontsize=hm_cbar_fontsize,
                              pert=pert,
                              xticks_l=xticks_l
                            )

# %%
C = 0.01
model = "APPNP"
mlp = "MLP"
# title_label = "GIN"
pert = "l1"
savefig = f'{model}_graph_info_robust_gain_attack{attack_nodes}_C{C}_{pert}.pdf'
xticks_l = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
hm_label_fontsize=26 #20,
hm_ticks_fontsize=15 #10,
hm_cbar_fontsize=22
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.2, savefig=savefig,
                              label_fontsize=hm_label_fontsize, #20,
                              ticks_fontsize=hm_ticks_fontsize, #10,
                              cbar_fontsize=hm_cbar_fontsize,
                              pert=pert,
                              xticks_l=xticks_l
                            )

# %%
C = 0.01
model = "SGC"
mlp = "MLP"
# title_label = "GIN"
pert = "l1"
savefig = f'{model}_graph_info_robust_gain_attack{attack_nodes}_C{C}_{pert}.pdf'
xticks_l = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
hm_label_fontsize=26 #20,
hm_ticks_fontsize=15 #10,
hm_cbar_fontsize=22
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.2, savefig=savefig,
                              label_fontsize=hm_label_fontsize, #20,
                              ticks_fontsize=hm_ticks_fontsize, #10,
                              cbar_fontsize=hm_cbar_fontsize,
                              pert=pert,
                              xticks_l=xticks_l
                            )

# %%
C = 0.01
model = "GIN"
mlp = "MLP"
# title_label = "GIN"
pert = "l1"
savefig = f'{model}_graph_info_robust_gain_attack{attack_nodes}_C{C}_{pert}.pdf'
xticks_l = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
hm_label_fontsize=26 #20,
hm_ticks_fontsize=15 #10,
hm_cbar_fontsize=22
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.2, savefig=savefig,
                              label_fontsize=hm_label_fontsize, #20,
                              ticks_fontsize=hm_ticks_fontsize, #10,
                              cbar_fontsize=hm_cbar_fontsize,
                              pert=pert,
                              xticks_l=xticks_l
                            )

# %%
C = 0.01
model = "GraphSage"
mlp = "MLP"
# title_label = "GIN"
pert = "l1"
savefig = f'{model}_graph_info_robust_gain_attack{attack_nodes}_C{C}_{pert}.pdf'
xticks_l = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
hm_label_fontsize=26 #20,
hm_ticks_fontsize=15 #10,
hm_cbar_fontsize=22
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.2, savefig=savefig,
                              label_fontsize=hm_label_fontsize, #20,
                              ticks_fontsize=hm_ticks_fontsize, #10,
                              cbar_fontsize=hm_cbar_fontsize,
                              pert=pert,
                              xticks_l=xticks_l
                            )

# %%
C = 0.01
model = "GCN_skippc_linear"
mlp = "MLP"
# title_label = "GIN"
pert = "l1"
savefig = f'{model}_graph_info_robust_gain_attack{attack_nodes}_C{C}_{pert}.pdf'
xticks_l = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
hm_label_fontsize=26 #20,
hm_ticks_fontsize=15 #10,
hm_cbar_fontsize=22
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.2, savefig=savefig,
                              label_fontsize=hm_label_fontsize, #20,
                              ticks_fontsize=hm_ticks_fontsize, #10,
                              cbar_fontsize=hm_cbar_fontsize,
                              pert=pert,
                              xticks_l=xticks_l
                            )

# %%
C = 0.01
model = "GCN_skipalpha_linear_alpha0.2"
mlp = "MLP"
# title_label = "GIN"
pert = "l1"
savefig = f'{model}_graph_info_robust_gain_attack{attack_nodes}_C{C}_{pert}.pdf'
xticks_l = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
hm_label_fontsize=26 #20,
hm_ticks_fontsize=15 #10,
hm_cbar_fontsize=22
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.2, savefig=savefig,
                              label_fontsize=hm_label_fontsize, #20,
                              ticks_fontsize=hm_ticks_fontsize, #10,
                              cbar_fontsize=hm_cbar_fontsize,
                              pert=pert,
                              xticks_l=xticks_l
                            )

# %% [markdown]
# # Linf

# %%
gcn_exp = dict(
    label = "GCN",
    collection = "l_sbm_cert_gcn",
    start_id = 1,
    end_id = 735,
    n_seeds = 5,
)
appnp_exp = dict(
    label = "APPNP",
    collection = "l_sbm_cert_appnp",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
appnp_alpha1_exp = dict(
    label = "APPNP_alpha1",
    collection = "l_sbm_cert_appnp",
    start_id = 1471,
    end_id = 1715,
    n_seeds = 5,
)
sgc_exp = dict(
    label = "SGC",
    collection = "m_sbm_cert_sgc",
    start_id = 246,
    end_id = 490,
    n_seeds = 5,
)
gcn_skippc_linear_exp = dict(
    label = "GCN_skippc_linear",
    collection = "m_sbm_cert_gcn_skippc",
    start_id = [246, 736],
    end_id = [490, 980],
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha01_exp = dict(
    label = "GCN_skipalpha_linear_alpha0.1",
    collection = "m_sbm_cert_gcn_skipalpha",
    start_id = [491, 1471],
    end_id = [735, 1715],
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha02_exp = dict(
    label = "GCN_skipalpha_linear_alpha0.2",
    collection = "m_sbm_cert_gcn_skipalpha",
    start_id = [736, 1716],
    end_id = [980, 1960],
    n_seeds = 5,
)
gin_exp = dict(
    label = "GIN",
    collection = "m_sbm_cert_pu",
    start_id = 1226,
    end_id = 1470,
    n_seeds = 5,
)
graphsage_exp = dict(
    label = "GraphSage",
    collection = "m_sbm_cert_pu",
    start_id = 2206,
    end_id = 2450,
    n_seeds = 5,
)
K = 1.5
attack_nodes = "test"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 6, 12, 24, 60, 120]

# %%
experiments = [gcn_exp, appnp_exp, sgc_exp, appnp_alpha1_exp,
               gcn_skippc_linear_exp, 
               gcn_skipalpha_linear_alpha01_exp, gcn_skipalpha_linear_alpha02_exp,
               gin_exp, graphsage_exp
               ]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN No. of experiments 147
# APPNP No. of experiments 98
# SGC No. of experiments 49
# APPNP_alpha1 No. of experiments 49
# GCN_skippc_linear No. of experiments 49
# GCN_skippc_linear No. of experiments 49
# GCN_skipalpha_linear_alpha0.1 No. of experiments 49
# GCN_skipalpha_linear_alpha0.1 No. of experiments 49
# GCN_skipalpha_linear_alpha0.2 No. of experiments 49
# GCN_skipalpha_linear_alpha0.2 No. of experiments 49
# GIN No. of experiments 49
# GraphSage No. of experiments 49

# %%
C_l = [0.01]
models = [
          "GCN","APPNP", "SGC", 
          "GIN", "GraphSage", 
           "GCN_skippc_linear",
          "GCN_skipalpha_linear_alpha0.2", "APPNP_alpha1"]
legend_labels = [
                 "GCN","APPNP", "SGC", 
                "GIN",  "GraphSAGE", 
           "GCN Skip-PC",
          "GCN Skip-$\\alpha$", "MLP"]
n_adv_plot = 24
pert_model = "linf"
savefig = f'csbm_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_{pert_model}.pdf'
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              pert_model=pert_model)

# %%
C = 0.01
model = "GIN"
mlp = "APPNP_alpha1"
savefig = f'{model}_graph_info_robust_gain_attack{attack_nodes}_C{C}_linf.pdf'
# title_label = "GIN"
pert = "linf"
xticks_l = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
hm_label_fontsize=26 #20,
hm_ticks_fontsize=15 #10,
hm_cbar_fontsize=22
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.2, savefig=savefig,
                              label_fontsize=hm_label_fontsize, #20,
                              ticks_fontsize=hm_ticks_fontsize, #10,
                              cbar_fontsize=hm_cbar_fontsize,
                              pert=pert,
                              xticks_l=xticks_l
                            )

# %%
C = 0.01
model = "GraphSage"
mlp = "APPNP_alpha1"
savefig = f'{model}_graph_info_robust_gain_attack{attack_nodes}_C{C}_linf.pdf'
# title_label = "GIN"
pert = "linf"
xticks_l = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
hm_label_fontsize=26 #20,
hm_ticks_fontsize=15 #10,
hm_cbar_fontsize=22
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.2, savefig=savefig,
                              label_fontsize=hm_label_fontsize, #20,
                              ticks_fontsize=hm_ticks_fontsize, #10,
                              cbar_fontsize=hm_cbar_fontsize,
                              pert=pert,
                              xticks_l=xticks_l
                            )

# %%
C = 0.01
model = "GCN"
mlp = "APPNP_alpha1"
savefig = None #f'{model}_graph_info_robust_gain_attack{attack_nodes}_C{C}_linf.pdf'
# title_label = "GIN"
pert = "linf"
xticks_l = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
hm_label_fontsize=26 #20,
hm_ticks_fontsize=15 #10,
hm_cbar_fontsize=22
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.2, savefig=savefig,
                              label_fontsize=hm_label_fontsize, #20,
                              ticks_fontsize=hm_ticks_fontsize, #10,
                              cbar_fontsize=hm_cbar_fontsize,
                              pert=pert,
                              xticks_l=xticks_l
                            )

# %%
gcn_sparsity_1_exp = dict(
    label = "GCN_sparsity_1",
    collection = "m_sbm_cert_gcn",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
gcn_sparsity_2_exp = dict(
    label = "GCN_sparsity_2",
    collection = "m_sbm_cert_gcn",
    start_id = 491,
    end_id = 980,
    n_seeds = 5,
)
gcn_sparsity_3_exp = dict(
    label = "GCN_sparsity_3",
    collection = "m_sbm_cert_gcn",
    start_id = 981,
    end_id = 1470,
    n_seeds = 5,
)
sgc_sparsity_1_exp = dict(
    label = "SGC_sparsity_1",
    collection = "m_sbm_cert_sgc",
    start_id = 491,
    end_id = 980,
    n_seeds = 5,
)
sgc_sparsity_2_exp = dict(
    label = "SGC_sparsity_2",
    collection = "m_sbm_cert_sgc",
    start_id = 981,
    end_id = 1470,
    n_seeds = 5,
)
sgc_sparsity_3_exp = dict(
    label = "SGC_sparsity_3",
    collection = "m_sbm_cert_sgc",
    start_id = 1471,
    end_id = 1960,
    n_seeds = 5,
)
appnp_sparsity_1_exp = dict(
    label = "APPNP_sparsity_1",
    collection = "m_sbm_cert_pu", #"m_sbm_cert_appnp",
    start_id = 3676, #1
    end_id = 3920, #490,
    n_seeds = 5,
)
appnp_sparsity_2_exp = dict(
    label = "APPNP_sparsity_2",
    collection = "m_sbm_cert_appnp",
    start_id = 491,
    end_id = 980,
    n_seeds = 5,
)
appnp_sparsity_3_exp = dict(
    label = "APPNP_sparsity_3",
    collection = "m_sbm_cert_appnp",
    start_id = 981,
    end_id = 1470,
    n_seeds = 5,
)
appnp_alpha1_exp = dict(
    label = "APPNP_alpha1",
    collection = "l_sbm_cert_appnp",
    start_id = 1471,
    end_id = 1715,
    n_seeds = 5,
)
K = 1.5
attack_nodes = "test"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 6, 12, 24, 60, 120]

# %%
experiments = [#gcn_exp, sgc_exp, 
               appnp_exp,
            #    gcn_sparsity_1_exp, gcn_sparsity_2_exp, gcn_sparsity_3_exp,
            #    sgc_sparsity_1_exp, sgc_sparsity_2_exp, sgc_sparsity_3_exp,
               appnp_sparsity_1_exp, appnp_sparsity_2_exp, appnp_sparsity_3_exp,
               appnp_alpha1_exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# APPNP No. of experiments 98
# APPNP_sparsity_1 No. of experiments 49
# APPNP_sparsity_2 No. of experiments 98
# APPNP_sparsity_3 No. of experiments 98
# APPNP_alpha1 No. of experiments 49

# %%
C_l = [0.01]
models = ["APPNP_sparsity_1","APPNP",  "APPNP_sparsity_2", "APPNP_sparsity_3", "APPNP_alpha1"]
legend_labels = ["APPNP $2\\times$", "APPNP $1\\times$", "APPNP $0.5\\times$", "APPNP $0.25\\times$", "APPNP $0\\times$"]

n_adv_plot = 24
savefig = f'APPNP_sparsity_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_linf.pdf'
linf = True
label_fontsize = 29
legend_fontsize = 18
ticks_fontsize = 18
use_custom_legend = True
linewidth = 1.5
markersize = 6
capsize = 6
framealpha = 0.5
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              pert_model=pert_model)

# %% [markdown]
# # L2

# %%
gcn_exp = dict(
    label = "GCN_l2",
    relabel = "GCN",
    collection = "m_sbm_cert_gcn_depth1_l2",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
appnp_exp = dict(
    relabel = "APPNP",
    label = "APPNP_alpha0.2_l2",
    collection = "m_sbm_cert_appnp_depth1_l2",
    start_id = 1121,
    end_id = 1680,
    n_seeds = 5,
)
appnp_alpha1_exp = dict(
    label = "MLP", #"APPNP_alpha1_l2",
    # relabel = "MLP",
    collection = "m_sbm_cert_pu", #"m_sbm_cert_appnp_depth1_l2",
    start_id = 3431,
    end_id = 3675,
    n_seeds = 5,
)
sgc_exp = dict(
    relabel = "SGC",
    label = "SGC_l2",
    collection = "m_sbm_cert_sgc_depth1_l2",
    start_id = 1,
    end_id = 490,
    n_seeds = 5,
)
gcn_skippc_linear_exp = dict(
    label = "GCN_skippc_l2",
    relabel = "GCN_skippc",
    collection = "m_sbm_cert_gcn_skippc_depth1_l2",
    start_id = [246, 736],
    end_id = [490, 980],
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha01_exp = dict(
    relabel = "GCN_skipalpha",
    label = "GCN_skipalpha_l2",
    collection = "m_sbm_cert_gcn_skipalpha_depth1_l2",
    start_id = [491, 1471],
    end_id = [735, 1715],
    n_seeds = 5,
)
gcn_skipalpha_linear_alpha02_exp = dict(
    relabel = "GCN_skipalpha",
    label = "GCN_skipalpha_l2",
    collection = "m_sbm_cert_gcn_skipalpha_depth1_l2",
    start_id = [736, 1716],
    end_id = [980, 1960],
    n_seeds = 5,
)
gin_exp = dict(
    label = "GIN",
    collection = "m_sbm_cert_pu",
    start_id = 2941,
    end_id = 3185,
    n_seeds = 5,
)
graphsage_exp = dict(
    label = "GraphSAGE",
    collection = "m_sbm_cert_pu",
    start_id = 3186,
    end_id = 3430,
    n_seeds = 5,
)
K = 1.5
attack_nodes = "test"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 6, 12, 24, 60, 120]

# %%
experiments = [gcn_exp, appnp_exp, sgc_exp, appnp_alpha1_exp,
               gcn_skippc_linear_exp, 
                gcn_skipalpha_linear_alpha02_exp,
               gin_exp, graphsage_exp
               ]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN_l2 No. of experiments 98
# APPNP_alpha0.2_l2 No. of experiments 112
# SGC_l2 No. of experiments 98
# MLP No. of experiments 49
# GCN_skippc_l2 No. of experiments 49
# GCN_skippc_l2 No. of experiments 49
# GCN_skipalpha_l2 No. of experiments 49
# GCN_skipalpha_l2 No. of experiments 49
# GIN No. of experiments 49
# GraphSAGE No. of experiments 49

# %%
C_l = [0.01]
models = [
          "GCN","APPNP", "SGC", 
          "GIN", "GraphSAGE", 
           "GCN_skippc",
          "GCN_skipalpha", "MLP"]
legend_labels = [
                 "GCN","APPNP", "SGC", 
                "GIN",  "GraphSAGE", 
           "GCN Skip-PC",
          "GCN Skip-$\\alpha$", "MLP"]
n_adv_plot = 24
pert_model = "l2"
savefig = f'csbm_attack{attack_nodes}_C{C_l[0]}_adv{n_adv_plot}_{pert_model}.pdf'
experiment_manager.plot_robust_acc_delta(K, models, C_l, attack_nodes, 
                                         n_adv=n_adv_plot, delta_l=delta_l, 
                                         legend_labels=legend_labels, xlogscale=True, 
                                         savefig=savefig,
                                         label_fontsize=label_fontsize,
                              legend_fontsize=legend_fontsize,
                              ticks_fontsize=ticks_fontsize,
                              markersize=markersize,
                              capsize=capsize,
                              linewidth=linewidth,
                              framealpha=framealpha,
                              use_custom_legend=use_custom_legend,
                              pert_model=pert_model)

# %%
C = 0.01
model = "GraphSAGE"
mlp = "MLP"
savefig = f'{model}_graph_info_robust_gain_attack{attack_nodes}_C{C}_l2.pdf'
# title_label = "GIN"
pert = "l2"
xticks_l = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
hm_label_fontsize=26 #20,
hm_ticks_fontsize=15 #10,
hm_cbar_fontsize=22
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.2, savefig=savefig,
                              label_fontsize=hm_label_fontsize, #20,
                              ticks_fontsize=hm_ticks_fontsize, #10,
                              cbar_fontsize=hm_cbar_fontsize,
                              pert=pert,
                              xticks_l=xticks_l
                            )

# %%
C = 0.01
model = "GIN"
mlp = "MLP"
savefig = f'{model}_graph_info_robust_gain_attack{attack_nodes}_C{C}_l2.pdf'
# title_label = "GIN"
pert = "l2"
xticks_l = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
hm_label_fontsize=26 #20,
hm_ticks_fontsize=15 #10,
hm_cbar_fontsize=22
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(K, [model], C, 
                              attack_nodes, n_adv_l, delta_l[::-1], mlp=mlp,
                              width=1, ratio=1.2, savefig=savefig,
                              label_fontsize=hm_label_fontsize, #20,
                              ticks_fontsize=hm_ticks_fontsize, #10,
                              cbar_fontsize=hm_cbar_fontsize,
                              pert=pert,
                              xticks_l=xticks_l
                            )
