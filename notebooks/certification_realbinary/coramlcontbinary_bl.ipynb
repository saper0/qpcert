# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt
from pathlib import Path

# %%
exp = dict(
    collection = "l_coramlcontbinary_n5_cert_bl",
    start_id = 1,
    end_id = 6300,
    n_seeds = 5,
)
pert_model = "l2"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [1, 2, 4, 10, 20]
postfix = ""
savedir = Path("./figures")
attack_nodes = "train_val_backdoor"

experiments = [exp]
#experiments = [gcn_l2_exp]
#experiments = [gcn_exp, appnp_exp, appnp_alpha01_exp, sgc_exp, gcn_skip_exp, sgc_depth2_exp, sgc_depth4_exp]
#experiments = [gcn_exp, appnp_exp, sgc_exp]#, gcn_skip_exp]
experiment_manager = ExperimentManager(experiments)

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})

# %%
C_l = None
plt.close("all")
delta_l = [0, 0.01, 0.02, 0.05, 0.1]
models = ["GCN", "APPNP_alpha0.1", "SGC", "GraphSAGE", "GIN", "GCN_skippc", "GCN_skipalpha", "MLP"]
legend_labels = ["GCN", "APPNP", "SGC", "GraphSAGE", "GIN", "GCN Skip-PC", r"GCN Skip-$\alpha$", "MLP"]
pert_model = "l2"
label_fontsize = 29
legend_fontsize = 16
ticks_fontsize = 16
use_custom_legend=True
savefig = "coramlbin_bl_l2_nadv2" + postfix + ".pdf"
#savefig = None
linewidth = 1.5
markersize = 6
capsize = 6
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         legend_labels=legend_labels,
                                         n_adv=2, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=0.4,
                                         use_custom_legend=use_custom_legend)

# %%
C_l = None
plt.close("all")
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
models = ["APPNP_alpha0.1","APPNP_alpha0.2","APPNP_alpha0.3","APPNP_alpha0.5","MLP"]
legend_labels = [r"APPNP $\alpha=0.1$",r"APPNP $\alpha=0.2$",r"APPNP $\alpha=0.3$",r"APPNP $\alpha=0.5$","MLP"]
pert_model = "l2"
label_fontsize = 26
legend_fontsize = 16
ticks_fontsize = 16
savefig = "coramlbin_bl_l2_nadv1_appnp" + postfix + ".pdf"
linewidth = 1.5
markersize = 6
capsize = 6
framealpha = 0.5
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         legend_labels=legend_labels,
                                         n_adv=1, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=framealpha)

# %%
C_l = None
plt.close("all")
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5]
models = ["GCN", "APPNP_alpha0.1", "SGC", "GCN_skippc", "GCN_skipalpha", "MLP"]
legend_labels = ["GCN", "APPNP", "SGC", "GCN Skip-PC", r"GCN Skip-$\alpha$", "MLP"]
pert_model = "l2"
label_fontsize = 26
legend_fontsize = 16
ticks_fontsize = 16
use_custom_legend = True
savefig = "coramlbin_bl_l2_nadv2" + postfix + ".pdf"
linewidth = 1.5
markersize = 6
capsize = 6
framealpha = 0.5
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         legend_labels=legend_labels,
                                         n_adv=2, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=framealpha,
                                         use_custom_legend=use_custom_legend)

# %%
C_l = None
plt.close("all")
delta_l = [0, 0.01, 0.02, 0.05, 0.1]
models = ["GCN", "APPNP_alpha0.1", "SGC", "GCN_skippc", "GCN_skipalpha", "MLP"]
legend_labels = ["GCN", "APPNP", "SGC", "GCN Skip-PC", r"GCN Skip-$\alpha$", "MLP"]
pert_model = "l2"
label_fontsize = 26
legend_fontsize = 16
ticks_fontsize = 16
savefig = "coramlbin_bl_l2_nadv20" + postfix + ".pdf"
linewidth = 1.5
markersize = 6
capsize = 6
framealpha = 0.5
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         legend_labels=legend_labels,
                                         n_adv=20, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=framealpha)
