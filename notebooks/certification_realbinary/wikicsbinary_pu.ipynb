# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt
from pathlib import Path

# %%
exp = dict(
    collection = "l_wikicsbinary_n5_pu",
    start_id = 1,
    end_id = 1960,
    n_seeds = 5,
)
pert_model = "l2"
attack_nodes = "test"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [12, 24, 60, 121, 243, 607, 1215]
postfix = ""
savedir = Path("./figures")

experiments = [exp]
#experiments = [gcn_l2_exp]
#experiments = [gcn_exp, appnp_exp, appnp_alpha01_exp, sgc_exp, gcn_skip_exp, sgc_depth2_exp, sgc_depth4_exp]
#experiments = [gcn_exp, appnp_exp, sgc_exp]#, gcn_skip_exp]
experiment_manager = ExperimentManager(experiments)

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})
savedir = Path("./figures")

# %%
C_l = None
plt.close("all")
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5]
models = ["GCN", "APPNP", "SGC", "GraphSAGE", "GCN_skippc", "GCN_skipalpha", "MLP_v2"]
legend_labels = ["GCN", "APPNP", "SGC", "GraphSAGE", "GCN Skip-PC", r"GCN Skip-$\alpha$", "MLP"]
#models = ["GCN", "MLP"]
#legend_labels = ["GCN", "MLP"]
pert_model = "l2"
label_fontsize = 29
legend_fontsize = 16
ticks_fontsize = 16
use_custom_legend=True
savefig = "wikicsbinary_pu_l2_nadv232" + postfix + ".pdf"
#savefig = None
linewidth = 1.5
markersize = 6
capsize = 6
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         legend_labels=legend_labels,
                                         n_adv=232, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=0.4,
                                         use_custom_legend=use_custom_legend)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 18
#      16 markersize = 6
#      17 capsize = 6
# ---> 18 experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
#      19                                          legend_labels=legend_labels,
#      20                                          n_adv=232, delta_l=delta_l, xlogscale=True,
#      21                                          label_fontsize=label_fontsize,
#      22                                          legend_fontsize=legend_fontsize,
#      23                                          ticks_fontsize=ticks_fontsize,
#      24                                          savedir=savedir,
#      25                                          savefig=savefig,
#      26                                          markersize=markersize,
# ...

# %%
C_l = None
plt.close("all")
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5]
models = ["GCN", "APPNP", "SGC", "GraphSAGE", "GCN_skippc", "GCN_skipalpha", "MLP_v2"]
legend_labels = ["GCN", "APPNP", "SGC", "GraphSAGE", "GCN Skip-PC", r"GCN Skip-$\alpha$", "MLP"]
#models = ["GCN", "MLP"]
#legend_labels = ["GCN", "MLP"]
pert_model = "l2"
label_fontsize = 29
legend_fontsize = 16
ticks_fontsize = 16
use_custom_legend=True
savefig = "wikicsbinary_pu_l2_nadv92" + postfix + ".pdf"
#savefig = None
linewidth = 1.5
markersize = 6
capsize = 6
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         legend_labels=legend_labels,
                                         n_adv=92, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=0.4,
                                         use_custom_legend=use_custom_legend)

# %%
model_l = ["GCN", "APPNP", "SGC", "GraphSAGE", "GCN_skippc", "GCN_skipalpha"]
label_l = ["GCN", "APPNP", "SGC", "GraphSAGE", "GCN Skip-PC", r"GCN Skip-$\alpha$"]
C_l = [1, 5, 0.5, 0.175, 1, 1]
for C, model, title_label in zip(C_l, model_l, label_l):
    plt.close("all")
    C_mlp = 0.75
    delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
    n_adv_l = [46,92,232,464,928,2320,4640]
    models = [model]
    pert_model = "l2"
    savefig = "heatmap_wikics_pu_"+ model + postfix + ".pdf"
    colormap = "bwr_r"
    experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(
                    models, C, attack_nodes, pert_model=pert_model, delta_l=delta_l, 
                    n_adv_l=n_adv_l,
                    mlp="MLP_v2", C_mlp=C_mlp,
                    title_label=title_label,
                    colormap=colormap,
                    savefig=savefig,
                    savedir=savedir
    )

# %%
model_l = ["SGC"]
label_l = ["SGC"]
C_l = [0.5]
for C, model, title_label in zip(C_l, model_l, label_l):
    plt.close("all")
    C_mlp = 0.75
    delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
    n_adv_l = [46,92,232,464,928,2320,4640]
    models = [model]
    pert_model = "l2"
    savefig = "heatmap_wikics_pu_"+ model + postfix + ".pdf"
    colormap = "bwr_r"
    experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(
                    models, C, attack_nodes, pert_model=pert_model, delta_l=delta_l, 
                    n_adv_l=n_adv_l,
                    mlp="MLP_v2", C_mlp=C_mlp,
                    title_label=title_label,
                    colormap=colormap,
                    savefig=savefig,
                    savedir=savedir
    )
