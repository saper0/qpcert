# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt
from pathlib import Path

# %%
exp = dict(
    collection = "l_coramlcontbinary_n5_cert_pu",
    start_id = 1,
    end_id = 9310,
    n_seeds = 5,
)
pert_model = "l2"
attack_nodes = "test"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [12, 24, 60, 121, 243, 607, 1215]
postfix = ""
savedir = Path("./figures")

experiments = [exp]
#experiments = [gcn_l2_exp]
#experiments = [gcn_exp, appnp_exp, appnp_alpha01_exp, sgc_exp, gcn_skip_exp, sgc_depth2_exp, sgc_depth4_exp]
#experiments = [gcn_exp, appnp_exp, sgc_exp]#, gcn_skip_exp]
experiment_manager = ExperimentManager(experiments)

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})
postfix = ""
savedir = Path("./figures")
plt.close("all")

# %%
C_l = None
plt.close("all")
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5]
models = ["GCN", "APPNP_alpha0.1", "SGC", "GraphSAGE", "GIN", "GCN_skippc", "GCN_skipalpha", "MLP"]
legend_labels = ["GCN", "APPNP", "SGC", "GraphSAGE", "GIN", "GCN Skip-PC", r"GCN Skip-$\alpha$", "MLP"]
pert_model = "l2"
label_fontsize = 29
legend_fontsize = 16
ticks_fontsize = 16
use_custom_legend=True
savefig = "coramlbin_pu_l2_nadv121" + postfix + ".pdf"
#savefig = None
linewidth = 1.5
markersize = 6
capsize = 6
framealpha = 0.5
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         legend_labels=legend_labels,
                                         n_adv=121, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=framealpha,
                                         use_custom_legend=use_custom_legend)

# %%
C_l = None
plt.close("all")
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5]
models = ["GCN", "APPNP_alpha0.1", "SGC", "GCN_skippc", "GCN_skipalpha", "MLP"]
legend_labels = ["GCN", "APPNP", "SGC", "GCN Skip-PC", r"GCN Skip-$\alpha$", "MLP"]
pert_model = "l2"
label_fontsize = 26
legend_fontsize = 16
ticks_fontsize = 16
savefig = "coramlbin_pu_l2_nadv243" + postfix + ".pdf"
linewidth = 1.5
markersize = 6
capsize = 6
framealpha = 0.5
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         legend_labels=legend_labels,
                                         n_adv=243, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=framealpha)

# %%
C_l = None
plt.close("all")
delta_l = [0, 0.01, 0.02, 0.05, 0.1]
models = ["GCN", "APPNP_alpha0.1", "SGC", "GCN_skippc", "GCN_skipalpha", "MLP"]
legend_labels = ["GCN", "APPNP", "SGC", "GCN Skip-PC", r"GCN Skip-$\alpha$", "MLP"]
pert_model = "l2"
label_fontsize = 26
legend_fontsize = 16
ticks_fontsize = 16
savefig = "coramlbin_pu_l2_nadv1215" + postfix + ".pdf"
linewidth = 1.5
markersize = 6
capsize = 6
framealpha = 0.5
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         legend_labels=legend_labels,
                                         n_adv=1215, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=framealpha)

# %%
C_l = None
plt.close("all")
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5]
models = ["GCN", "APPNP_alpha0.1", "SGC", "GCN_skippc", "GCN_skipalpha", "MLP"]
legend_labels = ["GCN", "APPNP", "SGC", "GCN Skip-PC", r"GCN Skip-$\alpha$", "MLP"]
pert_model = "l2"
label_fontsize = 26
legend_fontsize = 16
ticks_fontsize = 16
savefig = "coramlbin_pu_l2_nadv60" + postfix + ".pdf"
linewidth = 1.5
markersize = 6
capsize = 6
framealpha = 0.5
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         legend_labels=legend_labels,
                                         n_adv=60, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=framealpha)

# %%
C_l = None
plt.close("all")
delta_l = [0, 0.01, 0.02, 0.05, 0.1]
models = ["GCN", "APPNP_alpha0.1", "SGC", "GCN_skippc", "GCN_skipalpha", "MLP"]
legend_labels = ["GCN", "APPNP", "SGC", "GCN Skip-PC", r"GCN Skip-$\alpha$", "MLP"]
pert_model = "linf"
label_fontsize = 26
legend_fontsize = 16
ticks_fontsize = 16
savefig = "coramlbin_pu_linf_nadv60" + postfix + ".pdf"
linewidth = 1.5
markersize = 6
capsize = 6
framealpha = 0.5
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         legend_labels=legend_labels,
                                         n_adv=60, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=framealpha)

# %%
C_l = None
delta_l = [0, 0.01, 0.02, 0.05, 0.1]
models = ["APPNP_alpha0","APPNP_alpha0.1","APPNP_alpha0.2","APPNP_alpha0.3","APPNP_alpha0.5","MLP"]
legend_labels = [r"APPNP $\alpha=0$", r"APPNP $\alpha=0.1$",r"APPNP $\alpha=0.2$",r"APPNP $\alpha=0.3$",r"APPNP $\alpha=0.5$","MLP"]
pert_model = "l2"
label_fontsize = 26
legend_fontsize = 16
ticks_fontsize = 16
savefig = "coramlbin_pu_l2_nadv121_appnp_withalpha0_cut0.1" + postfix + ".pdf"
linewidth = 1
markersize = 6
capsize = 6
framealpha = 0.5
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         legend_labels=legend_labels,
                                         n_adv=121, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=framealpha)

# %%
C_l = None
delta_l = [0, 0.01, 0.02, 0.05, 0.1]
models = ["APPNP_alpha0","APPNP_alpha0.1","APPNP_alpha0.2","APPNP_alpha0.3","APPNP_alpha0.5","MLP"]
legend_labels = [r"APPNP $\alpha=0$", r"APPNP $\alpha=0.1$",r"APPNP $\alpha=0.2$",r"APPNP $\alpha=0.3$",r"APPNP $\alpha=0.5$","MLP"]
pert_model = "l2"
label_fontsize = 26
legend_fontsize = 16
ticks_fontsize = 16
savefig = "coramlbin_pu_l2_nadv121_appnp_withalpha0_cut0.1" + postfix + ".pdf"
linewidth = 1
markersize = 6
capsize = 6
framealpha = 0.5
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         legend_labels=legend_labels,
                                         n_adv=121, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=framealpha)

# %%
C_l = None
delta_l = [0.02, 0.05, 0.1, 0.2]
models = ["APPNP_alpha0","APPNP_alpha0.1","APPNP_alpha0.2","APPNP_alpha0.3","APPNP_alpha0.5","MLP"]
legend_labels = [r"APPNP $\alpha=0$", r"APPNP $\alpha=0.1$",r"APPNP $\alpha=0.2$",r"APPNP $\alpha=0.3$",r"APPNP $\alpha=0.5$","MLP"]
pert_model = "l2"
label_fontsize = 26
legend_fontsize = 16
ticks_fontsize = 16
savefig = "coramlbin_pu_l2_nadv60_appnp_withalpha0_cut0.2" + postfix + ".pdf"
linewidth = 1
markersize = 6
capsize = 6
framealpha = 0.5
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         legend_labels=legend_labels,
                                         n_adv=60, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=framealpha)

# %%
C_l = None
delta_l = [0.02, 0.05, 0.1, 0.2]
models = ["APPNP_alpha0.1","APPNP_alpha0.2","APPNP_alpha0.3","APPNP_alpha0.5","MLP"]
legend_labels = [r"APPNP $\alpha=0.1$",r"APPNP $\alpha=0.2$",r"APPNP $\alpha=0.3$",r"APPNP $\alpha=0.5$",r"APPNP $\alpha=1.0$ (MLP)"]
pert_model = "l2"
label_fontsize = 29
legend_fontsize = 18
ticks_fontsize = 18
use_custom_legend=True
savefig = "coramlbin_pu_l2_nadv60_appnp_withalpha0_cut0.2_v2" + postfix + ".pdf"
linewidth = 1
markersize = 6
capsize = 6
framealpha = 0.5
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         legend_labels=legend_labels,
                                         n_adv=60, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=framealpha,
                                         use_custom_legend=use_custom_legend)

# %%
C_l = None
delta_l = [0, 0.01, 0.02, 0.05, 0.1]
models = ["APPNP_alpha0","APPNP_alpha0.1","APPNP_alpha0.2","APPNP_alpha0.3","APPNP_alpha0.5","MLP"]
legend_labels = [r"APPNP $\alpha=0$", r"APPNP $\alpha=0.1$",r"APPNP $\alpha=0.2$",r"APPNP $\alpha=0.3$",r"APPNP $\alpha=0.5$","MLP"]
pert_model = "l2"
label_fontsize = 26
legend_fontsize = 16
ticks_fontsize = 16
savefig = "coramlbin_pu_l2_nadv60_appnp_withalpha0_cut0.1" + postfix + ".pdf"
linewidth = 1
markersize = 6
capsize = 6
framealpha = 0.5
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         legend_labels=legend_labels,
                                         n_adv=60, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=framealpha)

# %%
C_l = None
plt.close("all")
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2]
models = ["GCN", "GCN_sym", "SGC", "SGC_sym", "MLP"]
legend_labels = ["GCN Row.", "GCN Sym.", "SGC Row.", "SGC Sym.","MLP"]
pert_model = "l2"
label_fontsize = 26
legend_fontsize = 16
ticks_fontsize = 16
savefig = "coramlbin_pl_l2_nadv121_gcn_sym" + postfix + ".pdf"
linewidth = 1.5
markersize = 6
capsize = 6
framealpha = 0.5
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         legend_labels=legend_labels,
                                         n_adv=121, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=framealpha)

# %%
model_l = ["GCN", "APPNP_alpha0.1", "SGC", "GraphSAGE", "GIN", "GCN_skippc", "GCN_skipalpha"]
label_l = ["GCN", "APPNP", "SGC", "GraphSAGE", "GIN", "GCN Skip-PC", r"GCN Skip-$\alpha$"]
C_l = [0.75, 1.0, 0.75, 0.1, 0.05, 0.5, 1]
for C, model, title_label in zip(C_l, model_l, label_l):
    plt.close("all")
    C_mlp = 0.5
    delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
    n_adv_l = [12, 24, 60, 121, 243, 607, 1215]
    models = [model]
    pert_model = "l2"
    savefig = "heatmap_coramlbin_pu_"+ model + postfix + ".pdf"
    colormap = "bwr_r"
    experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(
                    models, C, attack_nodes, pert_model=pert_model, delta_l=delta_l, 
                    n_adv_l=n_adv_l,
                    mlp="MLP", C_mlp=C_mlp,
                    title_label=title_label,
                    colormap=colormap,
                    savefig=savefig,
                    savedir=savedir
    )

# %%
plt.close("all")
C = 0.75
C_mlp = 0.5
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [12, 24, 60, 121, 243, 607, 1215]
model = "GCN"
models = [model]
pert_model = "l2"
savefig = "heatmap_coramlbin_pl_"+ model + postfix + ".pdf"
colormap = "bwr_r"
experiment_manager.plot_nadv_delta_robust_gain_wrt_mlp_heatmap(
                models, C, attack_nodes, pert_model=pert_model, delta_l=delta_l, 
                n_adv_l=n_adv_l,
                mlp="MLP", C_mlp=C_mlp,
                title_label=model,
                colormap=colormap,
                savefig=savefig,
                savedir=savedir
)
