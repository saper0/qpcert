# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt
from pathlib import Path

# %%
exp = dict(
    collection = "l_coramlcontbinary_n5_cert_bu",
    start_id = 1,
    end_id = 8330,
    n_seeds = 5,
)
pert_model = "l2"
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
n_adv_l = [12, 24, 60, 121, 243, 607, 1215]
postfix = ""
savedir = Path("/ceph/ssd/staff/gosl/src/ntk-robust/figures")
attack_nodes = "test_backdoor"

experiments = [exp]
#experiments = [gcn_l2_exp]
#experiments = [gcn_exp, appnp_exp, appnp_alpha01_exp, sgc_exp, gcn_skip_exp, sgc_depth2_exp, sgc_depth4_exp]
#experiments = [gcn_exp, appnp_exp, sgc_exp]#, gcn_skip_exp]
experiment_manager = ExperimentManager(experiments)

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})

# %%
C_l = None
plt.close("all")
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5]
models = ["GCN", "APPNP_alpha0.1", "SGC", "GCN_skippc", "GCN_skipalpha", "MLP"]
legend_labels = ["GCN", "APPNP", "SGC", "GCN Skip-PC", r"GCN Skip-$\alpha$", "MLP"]
pert_model = "l2"
label_fontsize = 29
legend_fontsize = 18
ticks_fontsize = 18
use_custom_legend=True
savefig = "coramlbin_bu_l2_nadv111" + postfix + ".pdf"
linewidth = 1.5
markersize = 6
capsize = 6
framealpha = 0.5
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         legend_labels=legend_labels,
                                         n_adv=111, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=framealpha,
                                         use_custom_legend=use_custom_legend)

# %%
C_l = None
delta_l = [0, 0.01, 0.02, 0.05, 0.1]
models = ["GCN", "MLP", "SGC", "APPNP_alpha0.1", "GCN_skipalpha", "GCN_skippc"]
pert_model = "l2"
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         n_adv=20, delta_l=delta_l, xlogscale=True)

# %%
C_l = None
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5]
models = ["GCN", "MLP", "SGC", "APPNP_alpha0.1", "GCN_skipalpha", "GCN_skippc"]
pert_model = "l2"
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         n_adv=2, delta_l=delta_l, xlogscale=True)

# %%
C_l = None
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
models = ["GCN", "MLP", "SGC", "APPNP_alpha0.1", "GCN_skipalpha", "GCN_skippc"]
pert_model = "l2"
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         n_adv=1, delta_l=delta_l, xlogscale=True)

# %%
C_l = None
delta_l = [0, 0.01, 0.02, 0.05, 0.1]
models = ["GCN", "MLP", "SGC", "APPNP_alpha0.1", "GCN_skipalpha", "GCN_skippc"]
pert_model = "linf"
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         n_adv=2, delta_l=delta_l, xlogscale=True)

# %%
C_l = None
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
models = ["APPNP_alpha0.1","APPNP_alpha0.2","APPNP_alpha0.3","APPNP_alpha0.5","MLP"]
pert_model = "l2"
label_fontsize = 29
legend_fontsize = 18
ticks_fontsize = 18
use_custom_legend=True
savefig = "coramlbin_bu_l2_nadv111" + postfix + ".pdf"
linewidth = 1.5
markersize = 6
capsize = 6
framealpha = 0.5
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         legend_labels=legend_labels,
                                         n_adv=2, delta_l=delta_l, xlogscale=True,
                                         label_fontsize=label_fontsize,
                                         legend_fontsize=legend_fontsize,
                                         ticks_fontsize=ticks_fontsize,
                                         savedir=savedir,
                                         savefig=savefig,
                                         markersize=markersize,
                                         capsize=capsize,
                                         linewidth=linewidth,
                                         framealpha=framealpha,
                                         use_custom_legend=use_custom_legend)

# %%
C_l = None
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
models = ["APPNP_alpha0","APPNP_alpha0.1","APPNP_alpha0.2","APPNP_alpha0.3","APPNP_alpha0.5","MLP"]
pert_model = "l2"
#savefig = "coramlcontbin_pl_appnp.pdf"
#savedir = 
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         n_adv=2, delta_l=delta_l, xlogscale=True, 
                                         ylogscale=False)

# %%
C_l = None
delta_l = [0, 0.01, 0.02, 0.05]
models = ["APPNP_alpha0.1","APPNP_alpha0.2","APPNP_alpha0.3","APPNP_alpha0.5","MLP"]
pert_model = "linf"
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         n_adv=2, delta_l=delta_l, xlogscale=True)

# %%
C_l = None
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
models = ["GCN", "GCN_sym", "MLP", "SGC", "SGC_sym"]
pert_model = "l2"
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         n_adv=2, delta_l=delta_l, xlogscale=True)

# %%
C_l = None
delta_l = [0, 0.01, 0.02, 0.05, 0.1]
models = ["GCN", "GCN_sym", "MLP", "SGC", "SGC_sym"]
pert_model = "linf"
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         n_adv=2, delta_l=delta_l, xlogscale=True)

# %%
C_l = None
delta_l = [0, 0.01, 0.02, 0.05, 0.1, 0.2]
models = ["APPNP_alpha0.1","APPNP_alpha0.1_row","APPNP_alpha0.3","APPNP_alpha0.3_row","MLP"]
pert_model = "l2"
#savefig = "coramlcontbin_pl_appnp.pdf"
#savedir = 
experiment_manager.plot_robust_acc_delta(models, C_l, attack_nodes, pert_model=pert_model,
                                         n_adv=2, delta_l=delta_l, xlogscale=True, 
                                         ylogscale=False)
