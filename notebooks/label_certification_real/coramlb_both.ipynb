# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt

# %%
exp_coll = dict(
    collection = "l_coramlb_cert_label_coll_50",
    start_id = 1,
    end_id = 1035,
    n_seeds = 5,
    postfix = "_coll"
)
exp_sample = dict(
    collection = "l_coramlb_cert_label",
    start_id = 1,
    end_id = 450,
    n_seeds = 5,
    postfix = "_samp"
)

delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.4, 0.5, 1]

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})

# %% [markdown]
# ## Label cert

# %%
experiments = [exp_coll, exp_sample]
experiment_manager = ExperimentManager(experiments)

# %%
models = ["SGC_coll", "APPNP_coll", "GCN_skippc_coll", "MLP_coll",
          "SGC_samp", "APPNP_samp", "GCN_skippc_samp", "MLP_samp",]
legend_labels = ["SGC", "APPNP", "GCN Skip-PC", "MLP",
                 "SGC", "APPNP", "GCN Skip-PC", "MLP"]
delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.5, 1]
legend_y = "Certified Ratio"
legend_x = r"Perturbation budget $\epsilon$"
savefig = "coramlb_both.pdf"
linewidth = 1.5
markersize = 6
capsize = 6
label_fontsize = 24
legend_fontsize = 16
ticks_fontsize = 16
use_custom_legend = True
y_lim_ticks = 1
legend_args = dict(
    framealpha = 0.5,
    handlelength = 1.5,
    handletextpad = 0.5,
    labelspacing = 0.3,
    loc="lower left",
    bbox_to_anchor=(0.32,.665),
    ncol=2,
    columnspacing=0.5,
)

experiment_manager.plot_robust_acc_delta(models, delta_l=delta_l,
                                        legend_labels=legend_labels,
                                        certified_ratio=True,
                                        use_style=True,
                                        savefig=savefig,
                                        legend_y=legend_y,
                                        legend_x=legend_x,
                                        label_fontsize=label_fontsize,
                                        legend_fontsize=legend_fontsize,
                                        ticks_fontsize=ticks_fontsize,
                                        markersize=markersize,
                                        capsize=capsize,
                                        linewidth=linewidth,
                                        use_custom_legend=True,
                                        legend_args=legend_args,
                                        plot_coll_and_sample=True)

# %%
models = ["GCN_coll", "SGC_coll", "APPNP_coll", "GIN_coll", "GraphSAGE_coll", 
          "GCN_skipalpha_coll", "GCN_skippc_coll", "MLP_coll",
          "GCN_samp", "SGC_samp", "APPNP_samp", "GIN_samp", "GraphSAGE_samp", 
          "GCN_skipalpha_samp", "GCN_skippc_samp", "MLP_samp",]
legend_labels = ["GCN", "SGC", "APPNP", "GIN", "GraphSAGE", 
                 r"GCN Skip-$\alpha$", "GCN Skip-PC", "MLP",
                 "GCN", "SGC", "APPNP", "GIN", "GraphSAGE", 
                 r"GCN Skip-$\alpha$", "GCN Skip-PC", "MLP"]
delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.5, 1]
legend_y = "Certified Ratio"
legend_x = r"Perturbation budget $\epsilon$"
savefig = "citeseerb_coll.pdf"
linewidth = 1.2
markersize = 4
capsize = 4
label_fontsize = 24
legend_fontsize = 16
ticks_fontsize = 16
use_custom_legend = True
legend_args = dict(
    framealpha = 0.5,
    handlelength = 1.5,
    handletextpad = 0.5,
    labelspacing = 0.3,
    loc="lower left",
    bbox_to_anchor=(0.33,.585),
    ncol=2,
    columnspacing=0.3,
)

experiment_manager.plot_robust_acc_delta(models, delta_l=delta_l,
                                        legend_labels=legend_labels,
                                        certified_ratio=True,
                                        use_style=True,
                                        savefig=savefig,
                                        legend_y=legend_y,
                                        legend_x=legend_x,
                                        label_fontsize=label_fontsize,
                                        legend_fontsize=legend_fontsize,
                                        ticks_fontsize=ticks_fontsize,
                                        markersize=markersize,
                                        capsize=capsize,
                                        linewidth=linewidth,
                                        use_custom_legend=True,
                                        legend_args=legend_args)

# %%
models = ["GCN", "SGC", "APPNP", "GIN", "GraphSAGE", "GCN_skipalpha", "GCN_skippc","MLP"]
legend_labels = ["GCN", "SGC", "APPNP", "GIN", "GraphSAGE", "GCN Skip-$\\alpha$", "GCN Skip-PC","MLP"]
delta_l = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.5]
#delta_l = [0.2, 0.25]
df = experiment_manager.models_delta(models, delta_l, legend_labels)
print(df.to_latex(index=False, escape=False))
# Out:
# [['\\textbf{GCN}' '\\textbf{SGC}' '\\textbf{APPNP}' '\\textbf{GIN}'
#   '\\textbf{GraphSAGE}' '\\textbf{GCN Skip-$\\alpha$}'
#   '\\textbf{GCN Skip-PC}' '\\textbf{MLP}']]
# ['$\\mathbf{0.05}$', '$\\mathbf{0.10}$', '$\\mathbf{0.15}$', '$\\mathbf{0.20}$', '$\\mathbf{0.25}$', '$\\mathbf{0.30}$', '$\\mathbf{0.50}$']
# \begin{tabular}{llllllll}
# \toprule
# $\epsilon$ & $\mathbf{0.05}$ & $\mathbf{0.10}$ & $\mathbf{0.15}$ & $\mathbf{0.20}$ & $\mathbf{0.25}$ & $\mathbf{0.30}$ & $\mathbf{0.50}$ \\
# \midrule
# \textbf{GCN} & 65.6 $\pm$ 12.5 & 50.0 $\pm$ 9.7 & 41.6 $\pm$ 7.1 & 35.6 $\pm$ 5.4 & 29.2 $\pm$ 5.2 & 21.6 $\pm$ 4.1 & 6.8 $\pm$ 3.0 \\
# \textbf{SGC} & +3.6 $\pm$ 9.9 & +0.4 $\pm$ 10.8 & -0.4 $\pm$ 10.5 & -0.8 $\pm$ 10.0 & -0.0 $\pm$ 9.7 & +3.6 $\pm$ 7.0 & +2.8 $\pm$ 3.2 \\
# \textbf{APPNP} & +4.0 $\pm$ 4.5 & +0.8 $\pm$ 5.9 & -2.4 $\pm$ 7.1 & +1.2 $\pm$ 8.1 & +1.6 $\pm$ 8.0 & +4.8 $\pm$ 7.9 & +2.0 $\pm$ 2.7 \\
# \textbf{GIN} & +6.8 $\pm$ 6.6 & +0.8 $\pm$ 8.6 & +1.2 $\pm$ 6.1 & \textbf{+6.0}$\mathbf{\pm}$\textbf{6.4} & \textbf{+9.6}$\mathbf{\pm}$\textbf{6.8} & \textbf{+11.6}$\mathbf{\pm}$\textbf{4.5} & +4.0 $\pm$ 3.2 \\
# \textbf{GraphSAGE} & +9.6 $\pm$ 5.6 & +5.2 $\pm$ 5.3 & +2.4 $\pm$ 5.2 & +4.4 $\pm$ 4.9 & +7.6 $\pm$ 4.7 & +8.8 $\pm$ 6.6 & +4.8 $\pm$ 2.9 \\
# \textbf{GCN Skip-$\alpha$} & +10.0 $\pm$ 6.5 & +3.2 $\pm$ 7.0 & +2.0 $\pm$ 5.4 & +3.2 $\pm$ 4.7 & +5.2 $\pm$ 5.1 & +6.0 $\pm$ 6.6 & +3.6 $\pm$ 3.2 \\
# \textbf{GCN Skip-PC} & \textbf{+15.6}$\mathbf{\pm}$\textbf{3.9} & \textbf{+9.2}$\mathbf{\pm}$\textbf{5.9} & \textbf{+3.6}$\mathbf{\pm}$\textbf{6.0} & +4.8 $\pm$ 4.5 & +4.0 $\pm$ 5.5 & +7.6 $\pm$ 7.7 & +1.6 $\pm$ 3.2 \\
# \textbf{MLP} & -0.4 $\pm$ 3.2 & -6.8 $\pm$ 5.3 & -0.4 $\pm$ 6.5 & +3.2 $\pm$ 5.5 & +6.8 $\pm$ 3.6 & +11.2 $\pm$ 3.7 & \textbf{+11.6}$\mathbf{\pm}$\textbf{2.9} \\
# \bottomrule
# \end{tabular}

# %%
models = ["GCN", "SGC", "APPNP", "GIN", "GraphSAGE", "GCN_skipalpha", "GCN_skippc","MLP"]
delta_l = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.5]
#delta_l = [0.2, 0.25]
df = experiment_manager.rank_models(models, delta_l=delta_l,
                                    include_model_rank=False)
df
print(df.to_latex(index=False, escape=False))
# Out:
# \begin{tabular}{lllll}
# \toprule
# model & weak & intermediate & strong & total \\
# \midrule
# GCN & 7.0 & 6.75 & 8.0 & 7.0 \\
# SGC & 6.0 & 7.5 & 5.0 & 6.71 \\
# APPNP & 4.5 & 6.5 & 6.0 & 5.86 \\
# GIN & 4.0 & 1.75 & 3.0 & 2.57 \\
# GraphSAGE & 2.5 & 2.5 & 2.0 & 2.43 \\
# GCN_skipalpha & 2.5 & 4.0 & 4.0 & 3.57 \\
# GCN_skippc & 1.0 & 3.0 & 7.0 & 3.0 \\
# MLP & 8.0 & 3.75 & 1.0 & 4.57 \\
# \bottomrule
# \end{tabular}

# %%
models = ["GCN", "SGC", "APPNP", "GCN_skippc", "GCN_skipalpha", "GIN", "GraphSAGE", "MLP"]
delta_l = [0, 0.05, 0.1, 0.15, 0.2,0.25, 0.3, 0.5, 1]
savefig = "citeseerb_coll.pdf"
experiment_manager.plot_certified_ratio_delta(models, delta_l=delta_l, use_style=True,
                                              savefig=savefig)

# %%
models = ["GCN", "SGC"]
delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.4, 0.5, 1]
experiment_manager.plot_certified_ratio_delta(models, delta_l=delta_l, use_style=True)
# Out:
# delta: 0.05 racc: 0.656 std: 0.12
# delta: 0.10 racc: 0.500 std: 0.10
# delta: 0.15 racc: 0.416 std: 0.07
# delta: 0.20 racc: 0.356 std: 0.05
# delta: 0.25 racc: 0.292 std: 0.05
# delta: 0.30 racc: 0.216 std: 0.04
# delta: 0.40 racc: 0.128 std: 0.06
# delta: 0.50 racc: 0.068 std: 0.03
# delta: 1.00 racc: 0.000 std: 0.00
# delta: 0.05 racc: 0.692 std: 0.10
# delta: 0.10 racc: 0.504 std: 0.11
# delta: 0.15 racc: 0.412 std: 0.10
# delta: 0.20 racc: 0.348 std: 0.10
# delta: 0.25 racc: 0.292 std: 0.10
# delta: 0.30 racc: 0.252 std: 0.07
# delta: 0.40 racc: 0.168 std: 0.06
# delta: 0.50 racc: 0.096 std: 0.03
# delta: 1.00 racc: 0.000 std: 0.00

# %%
models = ["MLP", "APPNP", "GraphSAGE", "GCN_skippc"]
delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.5, 1]
experiment_manager.plot_certified_ratio_delta(models, delta_l=delta_l, use_style=True)

# %%
models = ["GIN"]
delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.5, 1]
experiment_manager.plot_certified_ratio_delta(models, delta_l=delta_l, use_style=True)

# %%
models = ["GCN", "SGC", "APPNP", "GIN", "GraphSAGE", "GCN_skipalpha", "GCN_skippc", "MLP"]
delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.5, 1]
savefig = "citeseerb_coll.pdf"
experiment_manager.plot_certified_ratio_delta(models, delta_l=delta_l, use_style=True, 
                                         savefig=savefig)

# %%
models = ["GCN", "MLP", "APPNP", "GCN_skipalpha", "GCN_skippc"]
delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.5, 1]
experiment_manager.plot_certified_ratio_delta(models, delta_l=delta_l, use_style=True)

# %%
models = ["GCN", "GCN_skipalpha", "GCN_skippc", "MLP"]
delta_l = [0, 0.05, 0.1, 0.15]
experiment_manager.plot_robust_acc_delta(models, delta_l=delta_l, use_style=True)

# %%
models = ["GCN", "GCN_sym", "SGC", "SGC_sym", "MLP"]
delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.4, 0.5, 1]
savefig = "citeseerb_coll_sym.pdf"
experiment_manager.plot_certified_ratio_delta(models, delta_l=delta_l, use_style=True,
                                         savefig=savefig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.4, 0.5, 1]
#       3 savefig = "citeseerb_coll_sym.pdf"
# ----> 4 experiment_manager.plot_certified_ratio_delta(models, delta_l=delta_l, use_style=True,
#       5                                          savefig=savefig)
#
# NameError: name 'experiment_manager' is not defined

# %%
models = ["GCN_sym", "GCN_skipalpha", "GCN_skippc", "MLP"]
delta_l = [0, 0.05, 0.1, 0.15]
experiment_manager.plot_robust_acc_delta(models, delta_l=delta_l, use_style=True)

# %%
models = ["GCN_L"GCN_L2", "GCN_skipalpha", "GCN_skippc"]
delta_l = [0, 0.05, 0.1, 0.15]
experiment_manager.plot_robust_acc_delta(models, delta_l=delta_l, use_style=True)
