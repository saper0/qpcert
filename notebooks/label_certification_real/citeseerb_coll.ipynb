# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt

# %%
exp_d = dict(
    collection = "l_citeseerb_cert_label_coll_50",
    start_id = 1,
    end_id = 450,
    n_seeds = 5,
)
delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.4, 0.5, 1]

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})

# %% [markdown]
# ## Label cert

# %%
experiments = [exp_d]
experiment_manager = ExperimentManager(experiments)
# Out:
# 77 SGC delta: 0.4 is NONE.
# 78 SGC delta: 0.4 is NONE.
# 79 SGC delta: 0.4 is NONE.
# 80 SGC delta: 0.4 is NONE.
# 438 SGC_sym delta: 0.4 has no result.

# %%
models = ["GCN", "SGC", "APPNP", "GIN", "GraphSAGE", "GCN_skipalpha", "GCN_skippc","MLP"]
legend_labels = ["GCN", "SGC", "APPNP", "GIN", "GraphSAGE", "GCN Skip-$\\alpha$", "GCN Skip-PC","MLP"]
delta_l = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.4, 0.5]
#delta_l = [0.2, 0.25]
experiment_manager.plot_robustness_delta(models, delta_l, legend_labels, 
                                          certified_ratio=True,
                                          bold=False, to_latex=False)
# Out:
# Model GCN has delta_m: 28.40 delta_s: 14.80
# Model SGC has delta_m: 25.20 delta_s: 15.60
# Model APPNP has delta_m: 24.40 delta_s: 17.60
# Model GIN has delta_m: 17.60 delta_s: 22.40
# Model GraphSAGE has delta_m: 24.80 delta_s: 18.80
# Model GCN_skipalpha has delta_m: 25.60 delta_s: 17.20
# Model GCN_skippc has delta_m: 30.00 delta_s: 20.80
# Model MLP has delta_m: 10.40 delta_s: 14.40

# %%
models = ["GCN", "SGC", "APPNP", "GIN", "GraphSAGE", "GCN_skipalpha", "GCN_skippc","MLP"]
legend_labels = ["GCN", "SGC", "APPNP", "GIN", "GraphSAGE", "GCN Skip-$\\alpha$", "GCN Skip-PC","MLP"]
delta_l = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.4, 0.5]
#delta_l = [0.2, 0.25]
df = experiment_manager.models_robustness(models, delta_l, legend_labels, 
                                          certified_ratio=True,
                                          bold=False, to_latex=False)
df
# Out:
#           $\epsilon$       0.05        0.1       0.15        0.2      0.25  \
# 0                GCN  65.6±12.5   50.0±9.7   41.6±7.1   35.6±5.4  29.2±5.2
# 1                SGC   69.2±9.9  50.4±10.8  41.2±10.5  34.8±10.0  29.2±9.7
# 2              APPNP   69.6±4.5   50.8±5.9   39.2±7.1   36.8±8.1  30.8±8.0
# 3                GIN   72.4±6.6   50.8±8.6   42.8±6.1   41.6±6.4  38.8±6.8
# 4          GraphSAGE   75.2±5.6   55.2±5.3   44.0±5.2   40.0±4.9  36.8±4.7
# 5  GCN Skip-$\alpha$   75.6±6.5   53.2±7.0   43.6±5.4   38.8±4.7  34.4±5.1
# 6        GCN Skip-PC   81.2±3.9   59.2±5.9   45.2±6.0   40.4±4.5  33.2±5.5
# 7                MLP   65.2±3.2   43.2±5.3   41.2±6.5   38.8±5.5  36.0±3.6
#
#         0.3       0.4       0.5
# 0  21.6±4.1  12.8±5.7   6.8±3.0
# 1  25.2±7.0  14.0±0.0   9.6±3.2
# 2  26.4±7.9  16.0±3.8   8.8±2.7
# 3  33.2±4.5  21.2±4.5  10.8±3.2
# 4  30.4±6.6  18.4±5.0  11.6±2.9
# 5  27.6±6.6  17.2±3.9  10.4±3.2
# 6  29.2±7.7  16.0±4.6   8.4±3.2
# 7  32.8±3.7  26.4±2.3  18.4±2.9

# %%
models = ["GCN", "SGC", "APPNP", "GIN", "GraphSAGE", "GCN_skipalpha", "GCN_skippc","MLP"]
legend_labels = ["GCN", "SGC", "APPNP", "GIN", "GraphSAGE", "GCN Skip-$\\alpha$", "GCN Skip-PC","MLP"]
delta_l = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.5]
#delta_l = [0.2, 0.25]
df = experiment_manager.models_delta(models, delta_l, legend_labels)
print(df.to_latex(index=False, escape=False))
# Out:
# [['\\textbf{GCN}' '\\textbf{SGC}' '\\textbf{APPNP}' '\\textbf{GIN}'
#   '\\textbf{GraphSAGE}' '\\textbf{GCN Skip-$\\alpha$}'
#   '\\textbf{GCN Skip-PC}' '\\textbf{MLP}']]
# ['$\\mathbf{0.05}$', '$\\mathbf{0.10}$', '$\\mathbf{0.15}$', '$\\mathbf{0.20}$', '$\\mathbf{0.25}$', '$\\mathbf{0.30}$', '$\\mathbf{0.50}$']
# \begin{tabular}{llllllll}
# \toprule
# $\epsilon$ & $\mathbf{0.05}$ & $\mathbf{0.10}$ & $\mathbf{0.15}$ & $\mathbf{0.20}$ & $\mathbf{0.25}$ & $\mathbf{0.30}$ & $\mathbf{0.50}$ \\
# \midrule
# \textbf{GCN} & 65.6 $\pm$ 12.5 & 50.0 $\pm$ 9.7 & 41.6 $\pm$ 7.1 & 35.6 $\pm$ 5.4 & 29.2 $\pm$ 5.2 & 21.6 $\pm$ 4.1 & 6.8 $\pm$ 3.0 \\
# \textbf{SGC} & +3.6 $\pm$ 9.9 & +0.4 $\pm$ 10.8 & -0.4 $\pm$ 10.5 & -0.8 $\pm$ 10.0 & -0.0 $\pm$ 9.7 & +3.6 $\pm$ 7.0 & +2.8 $\pm$ 3.2 \\
# \textbf{APPNP} & +4.0 $\pm$ 4.5 & +0.8 $\pm$ 5.9 & -2.4 $\pm$ 7.1 & +1.2 $\pm$ 8.1 & +1.6 $\pm$ 8.0 & +4.8 $\pm$ 7.9 & +2.0 $\pm$ 2.7 \\
# \textbf{GIN} & +6.8 $\pm$ 6.6 & +0.8 $\pm$ 8.6 & +1.2 $\pm$ 6.1 & \textbf{+6.0}$\mathbf{\pm}$\textbf{6.4} & \textbf{+9.6}$\mathbf{\pm}$\textbf{6.8} & \textbf{+11.6}$\mathbf{\pm}$\textbf{4.5} & +4.0 $\pm$ 3.2 \\
# \textbf{GraphSAGE} & +9.6 $\pm$ 5.6 & +5.2 $\pm$ 5.3 & +2.4 $\pm$ 5.2 & +4.4 $\pm$ 4.9 & +7.6 $\pm$ 4.7 & +8.8 $\pm$ 6.6 & +4.8 $\pm$ 2.9 \\
# \textbf{GCN Skip-$\alpha$} & +10.0 $\pm$ 6.5 & +3.2 $\pm$ 7.0 & +2.0 $\pm$ 5.4 & +3.2 $\pm$ 4.7 & +5.2 $\pm$ 5.1 & +6.0 $\pm$ 6.6 & +3.6 $\pm$ 3.2 \\
# \textbf{GCN Skip-PC} & \textbf{+15.6}$\mathbf{\pm}$\textbf{3.9} & \textbf{+9.2}$\mathbf{\pm}$\textbf{5.9} & \textbf{+3.6}$\mathbf{\pm}$\textbf{6.0} & +4.8 $\pm$ 4.5 & +4.0 $\pm$ 5.5 & +7.6 $\pm$ 7.7 & +1.6 $\pm$ 3.2 \\
# \textbf{MLP} & -0.4 $\pm$ 3.2 & -6.8 $\pm$ 5.3 & -0.4 $\pm$ 6.5 & +3.2 $\pm$ 5.5 & +6.8 $\pm$ 3.6 & +11.2 $\pm$ 3.7 & \textbf{+11.6}$\mathbf{\pm}$\textbf{2.9} \\
# \bottomrule
# \end{tabular}

# %%
models = ["GCN", "SGC", "APPNP", "GIN", "GraphSAGE", "GCN_skipalpha", "GCN_skippc","MLP"]
delta_l = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.5]
#delta_l = [0.2, 0.25]
df = experiment_manager.rank_models(models, delta_l=delta_l,
                                    include_model_rank=False)
df
print(df.to_latex(index=False, escape=False))
# Out:
# \begin{tabular}{lllll}
# \toprule
# model & weak & intermediate & strong & total \\
# \midrule
# GCN & 7.0 & 6.75 & 8.0 & 7.0 \\
# SGC & 6.0 & 7.5 & 5.0 & 6.71 \\
# APPNP & 4.5 & 6.5 & 6.0 & 5.86 \\
# GIN & 4.0 & 1.75 & 3.0 & 2.57 \\
# GraphSAGE & 2.5 & 2.5 & 2.0 & 2.43 \\
# GCN_skipalpha & 2.5 & 4.0 & 4.0 & 3.57 \\
# GCN_skippc & 1.0 & 3.0 & 7.0 & 3.0 \\
# MLP & 8.0 & 3.75 & 1.0 & 4.57 \\
# \bottomrule
# \end{tabular}

# %%
models = ["GCN", "SGC", "APPNP", "GCN_skippc", "GCN_skipalpha", "GIN", "GraphSAGE", "MLP"]
legend_labels = ["GCN", "SGC", "APPNP", "GIN", "GraphSAGE", r"GCN Skip-$\alpha$", "GCN Skip-PC", "MLP"]
delta_l = [0, 0.05, 0.1, 0.15, 0.2,0.25, 0.3, 0.5, 1]
savefig = "citeseerb_coll.pdf"
legend_y = "Certified Ratio"
legend_x = r"Perturbation budget $\epsilon$"
linewidth = 1.2
markersize = 5
capsize = 5
label_fontsize = 24
legend_fontsize = 16
ticks_fontsize = 16
use_custom_legend = True
legend_args = dict(
    framealpha = 0.5,
    handlelength = 1.5,
    handletextpad = 0.5,
    labelspacing = 0.3,
    loc="lower left",
    #bbox_to_anchor=(0.60,.49),
    bbox_to_anchor=(0.33,.58),
    ncol=2,
    columnspacing=0.3,
    #columnspacing=1
)

experiment_manager.plot_robust_acc_delta(models, delta_l=delta_l,
                                            legend_labels=legend_labels,
                                            certified_ratio=True,
                                            use_style=True,
                                            savefig=savefig,
                                            legend_y=legend_y,
                                            legend_x=legend_x,
                                            label_fontsize=label_fontsize,
                                            legend_fontsize=legend_fontsize,
                                            ticks_fontsize=ticks_fontsize,
                                            markersize=markersize,
                                            capsize=capsize,
                                            linewidth=linewidth,
                                            use_custom_legend=True,
                                            legend_args=legend_args)

# %%
models = ["GCN", "GCN_sym", "SGC", "SGC_sym", "MLP"]
legend_labels = [r"GCN", r"GCN $\mathbf{S}_{sym}$", "SGC", r"SGC $\mathbf{S}_{sym}$", "MLP"]
savefig = "citeseerb_coll_sym.pdf"
legend_y = "Certified Ratio"
legend_x = r"Perturbation budget $\epsilon$"
linewidth = 1.5
markersize = 6
capsize = 6
label_fontsize = 24
legend_fontsize = 16
ticks_fontsize = 16
use_custom_legend = True
legend_args = dict(
    framealpha = 0.5,
    handlelength = 1.5,
    handletextpad = 0.5,
    labelspacing = 0.3,
    loc="lower left",
    bbox_to_anchor=(0.655,.483),
    #bbox_to_anchor=(0.33,.585),
    ncol=1,
    #columnspacing=0.3,
    columnspacing=1
)

experiment_manager.plot_robust_acc_delta(models, delta_l=delta_l,
                                            legend_labels=legend_labels,
                                            certified_ratio=True,
                                            use_style=True,
                                            savefig=savefig,
                                            legend_y=legend_y,
                                            legend_x=legend_x,
                                            label_fontsize=label_fontsize,
                                            legend_fontsize=legend_fontsize,
                                            ticks_fontsize=ticks_fontsize,
                                            markersize=markersize,
                                            capsize=capsize,
                                            linewidth=linewidth,
                                            use_custom_legend=True,
                                            legend_args=legend_args)
