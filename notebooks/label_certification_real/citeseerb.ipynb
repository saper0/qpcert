# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt

# %%
exp_d = dict(
    collection = "l_citeseerb_cert_label",
    start_id = 1,
    end_id = 450,
    n_seeds = 5,
)
delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.4, 0.5, 1]

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})

# %% [markdown]
# ## Label cert

# %%
experiments = [exp_d]
experiment_manager = ExperimentManager(experiments)

# %%
models = ["GCN", "SGC", "APPNP", "GIN", "GraphSAGE", "GCN_skipalpha", "GCN_skippc", "MLP"]
legend_labels = ["GCN", "SGC", "APPNP", "GIN", "GraphSAGE", r"GCN Skip-$\alpha$", "GCN Skip-PC", "MLP"]
delta_l = [0, 0.05, 0.1, 0.15]
savefig = "citeseerb_sample.pdf"
legend_y = "Certified Accuracy"
legend_x = r"Perturbation budget $\epsilon$"
savefig = "citeseerb_sample.pdf"
linewidth = 1.8
markersize = 6
capsize = 6
label_fontsize = 24
legend_fontsize = 16
ticks_fontsize = 16
use_custom_legend = True
legend_args = dict(
    framealpha = 0.5,
    handlelength = 1.5,
    handletextpad = 0.5,
    labelspacing = 0.3,
    loc="lower left",
    bbox_to_anchor=(0.585,.238),
    #bbox_to_anchor=(0.33,.585),
    ncol=1,
    #columnspacing=0.3,
    columnspacing=1
)

experiment_manager.plot_robust_acc_delta(models, delta_l=delta_l,
                                            legend_labels=legend_labels,
                                            certified_ratio=False,
                                            use_style=True,
                                            savefig=savefig,
                                            legend_y=legend_y,
                                            legend_x=legend_x,
                                            label_fontsize=label_fontsize,
                                            legend_fontsize=legend_fontsize,
                                            ticks_fontsize=ticks_fontsize,
                                            markersize=markersize,
                                            capsize=capsize,
                                            linewidth=linewidth,
                                            use_custom_legend=True,
                                            legend_args=legend_args)

# %%
models = ["GCN", "SGC", "MLP", "APPNP", "GIN", "GraphSAGE", "GCN_skipalpha", "GCN_skippc"]
delta_l = [0, 0.05, 0.1, 0.15]
savefig = "citeseerb_sample.pdf"
experiment_manager.plot_robust_acc_delta(models, delta_l=delta_l, use_style=True,
                                         savefig=savefig)
# Out:
# delta: 0.05 racc: 0.246 std: 0.09
# delta: 0.10 racc: 0.025 std: 0.03
# delta: 0.15 racc: 0.002 std: 0.00
# delta: 0.05 racc: 0.257 std: 0.09
# delta: 0.10 racc: 0.040 std: 0.05
# delta: 0.15 racc: 0.003 std: 0.00
# delta: 0.05 racc: 0.138 std: 0.05
# delta: 0.10 racc: 0.002 std: 0.00
# delta: 0.15 racc: 0.000 std: 0.00
# delta: 0.05 racc: 0.268 std: 0.11
# delta: 0.10 racc: 0.028 std: 0.03
# delta: 0.15 racc: 0.002 std: 0.00
# delta: 0.05 racc: 0.255 std: 0.09
# delta: 0.10 racc: 0.010 std: 0.01
# delta: 0.15 racc: 0.000 std: 0.00
# delta: 0.05 racc: 0.284 std: 0.09
# delta: 0.10 racc: 0.025 std: 0.03
# delta: 0.15 racc: 0.000 std: 0.00
# delta: 0.05 racc: 0.354 std: 0.09
# delta: 0.10 racc: 0.041 std: 0.05
# delta: 0.15 racc: 0.001 std: 0.00
# delta: 0.05 racc: 0.425 std: 0.11
# delta: 0.10 racc: 0.051 std: 0.05
# delta: 0.15 racc: 0.000 std: 0.00

# %%
models = ["GCN", "MLP", "APPNP", "GCN_skipalpha", "GCN_skippc", "GIN"]
delta_l = [0, 0.05, 0.1, 0.15]
experiment_manager.plot_robust_acc_delta(models, delta_l=delta_l, use_style=True)

# %%
models = ["GCN", "GCN_sym", "SGC", "SGC_sym"]
delta_l = [0, 0.05, 0.1, 0.15]
experiment_manager.plot_robust_acc_delta(models, delta_l=delta_l, use_style=True)

# %%
models = ["GCN", "GCN_skipalpha", "GCN_skippc"]
delta_l = [0, 0.05, 0.1, 0.15]
experiment_manager.plot_robust_acc_delta(models, delta_l=delta_l, use_style=False)
