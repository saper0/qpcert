# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2
# Set up mongo db
import copy

import matplotlib.pyplot as plt
import numpy as np
from pymongo import MongoClient 
from seml.sources import delete_orphaned_sources

# %%
# Assume always delete whole batches of experiments
client = MongoClient("mongodb://sabanaya:bAvQwbOp@fs.kdd.in.tum.de:27017/sabanaya?authMechanism=SCRAM-SHA-1")
db = client.gosl
collection = db["l_sbm_cert_ntk_gcn"]
metrics_collection = db.metrics
for id in range(148, 294+1):
    exp = collection.find_one({'_id': id})
    collection.delete_one({"_id" : id})
    #metrics_collection.delete_many({"run_id": id})
    if exp is not None:
        batch_ids_in_del = set([exp['batch_id']])
        delete_orphaned_sources(collection, batch_ids_in_del)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[3], line 7
#       5 metrics_collection = db.metrics
#       6 for id in range(148, 294+1):
# ----> 7     exp = collection.find_one({'_id': id})
#       8     collection.delete_one({"_id" : id})
#       9     #metrics_collection.delete_many({"run_id": id})
#
# File /ceph/ssd/staff/gosl/.conda/envs/py311_ntk/lib/python3.11/site-packages/pymongo/collection.py:1506, in Collection.find_one(self, filter, *args, **kwargs)
#    1504     filter = {"_id": filter}
#    1505 cursor = self.find(filter, *args, **kwargs)
# -> 1506 for result in cursor.limit(-1):
#    1507     return result
#    1508 return None
#
# File /ceph/ssd/staff/gosl/.conda/envs/py311_ntk/lib/python3.11/site-packages/pymongo/cursor.py:1264, in Cursor.next(self)
#    1262 if self.__empty:
#    1263     raise StopIteration
# -> 1264 if len(self.__data) or self._refresh():
#    1265     return self.__data.popleft()
#    1266 else:
#
# File /ceph/ssd/staff/gosl/.conda/envs/py311_ntk/lib/python3.11/site-packages/pymongo/cursor.py:1181, in Cursor._refresh(self)
#    1159         raise InvalidOperation(
#    1160             "Passing a 'hint' is required when using the min/max query"
#    1161             " option to ensure the query utilizes the correct index"
#    1162         )
#    1163     q = self._query_class(
#    1164         self.__query_flags,
#    1165         self.__collection.database.name,
#    (...)
#    1179         self.__exhaust,
#    1180     )
# -> 1181     self.__send_message(q)
#    1182 elif self.__id:  # Get More
#    1183     if self.__limit:
#
# File /ceph/ssd/staff/gosl/.conda/envs/py311_ntk/lib/python3.11/site-packages/pymongo/cursor.py:1060, in Cursor.__send_message(self, operation)
#    1057     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1059 try:
# -> 1060     response = client._run_operation(
#    1061         operation, self._unpack_response, address=self.__address
#    1062     )
#    1063 except OperationFailure as exc:
#    1064     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1065         # Don't send killCursors because the cursor is already closed.
#
# File /ceph/ssd/staff/gosl/.conda/envs/py311_ntk/lib/python3.11/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File /ceph/ssd/staff/gosl/.conda/envs/py311_ntk/lib/python3.11/site-packages/pymongo/mongo_client.py:1394, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1389     operation.reset()  # Reset op in case of retry.
#    1390     return server.run_operation(
#    1391         conn, operation, read_preference, self._event_listeners, unpack_res
#    1392     )
# -> 1394 return self._retryable_read(
#    1395     _cmd,
#    1396     operation.read_preference,
#    1397     operation.session,
#    1398     address=address,
#    1399     retryable=isinstance(operation, message._Query),
#    1400 )
#
# File /ceph/ssd/staff/gosl/.conda/envs/py311_ntk/lib/python3.11/site-packages/pymongo/mongo_client.py:1492, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1487 # Ensure that the client supports retrying on reads and there is no session in
#    1488 # transaction, otherwise, we will not support retry behavior for this call.
#    1489 retryable = bool(
#    1490     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1491 )
# -> 1492 return self._retry_internal(
#    1493     func,
#    1494     session,
#    1495     None,
#    1496     is_read=True,
#    1497     address=address,
#    1498     read_pref=read_pref,
#    1499     retryable=retryable,
#    1500 )
#
# File /ceph/ssd/staff/gosl/.conda/envs/py311_ntk/lib/python3.11/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File /ceph/ssd/staff/gosl/.conda/envs/py311_ntk/lib/python3.11/site-packages/pymongo/mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
#    1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
# -> 1462     ).run()
#
# File /ceph/ssd/staff/gosl/.conda/envs/py311_ntk/lib/python3.11/site-packages/pymongo/mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File /ceph/ssd/staff/gosl/.conda/envs/py311_ntk/lib/python3.11/site-packages/pymongo/mongo_client.py:2444, in _ClientConnectionRetryable._read(self)
#    2442 if self._retrying and not self._retryable:
#    2443     self._check_last_error()
# -> 2444 return self._func(self._session, self._server, conn, read_pref)
#
# File /ceph/ssd/staff/gosl/.conda/envs/py311_ntk/lib/python3.11/site-packages/pymongo/mongo_client.py:1390, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1383 def _cmd(
#    1384     _session: Optional[ClientSession],
#    1385     server: Server,
#    1386     conn: Connection,
#    1387     read_preference: _ServerMode,
#    1388 ) -> Response:
#    1389     operation.reset()  # Reset op in case of retry.
# -> 1390     return server.run_operation(
#    1391         conn, operation, read_preference, self._event_listeners, unpack_res
#    1392     )
#
# File /ceph/ssd/staff/gosl/.conda/envs/py311_ntk/lib/python3.11/site-packages/pymongo/helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File /ceph/ssd/staff/gosl/.conda/envs/py311_ntk/lib/python3.11/site-packages/pymongo/server.py:167, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res)
#     165         first = docs[0]
#     166         operation.client._process_response(first, operation.session)
# --> 167         _check_command_response(first, conn.max_wire_version)
#     168 except Exception as exc:
#     169     if publish:
#
# File /ceph/ssd/staff/gosl/.conda/envs/py311_ntk/lib/python3.11/site-packages/pymongo/helpers.py:230, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     227 elif code == 43:
#     228     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 230 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: not authorized on gosl to execute command { find: "l_sbm_cert_ntk_gcn", filter: { _id: 148 }, limit: 1, singleBatch: true, lsid: { id: UUID("cbecf444-86aa-4059-acfb-0306ac299a79") }, $clusterTime: { clusterTime: Timestamp(1713110674, 4), signature: { hash: BinData(0, 828CE14987EEB21F6FBB78D1057BB7890D1FD325), keyId: 7307256881225924610 } }, $db: "gosl" }, full error: {'ok': 0.0, 'errmsg': 'not authorized on gosl to execute command { find: "l_sbm_cert_ntk_gcn", filter: { _id: 148 }, limit: 1, singleBatch: true, lsid: { id: UUID("cbecf444-86aa-4059-acfb-0306ac299a79") }, $clusterTime: { clusterTime: Timestamp(1713110674, 4), signature: { hash: BinData(0, 828CE14987EEB21F6FBB78D1057BB7890D1FD325), keyId: 7307256881225924610 } }, $db: "gosl" }', 'code': 13, 'codeName': 'Unauthorized', '$clusterTime': {'clusterTime': Timestamp(1713110674, 4), 'signature': {'hash': b'\x82\x8c\xe1I\x87\xee\xb2\x1fo\xbbx\xd1\x05{\xb7\x89\r\x1f\xd3%', 'keyId': 7307256881225924610}}, 'operationTime': Timestamp(1713110674, 4)}
