# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt

# %%
gcn_exp = dict(
    label = "GCN",
    collection = "m_label_sbm_besthp_gcn",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
# gcn_depth2_exp = dict(
#     label = "GCN_depth2",
#     collection = "m_label_sbm_gcn",
#     start_id = 151,
#     end_id = 250,
#     n_seeds = 5,
# )
# gcn_depth4_exp = dict(
#     label = "GCN_depth4",
#     collection = "m_label_sbm_gcn",
#     start_id = 301,
#     end_id = 400,
#     n_seeds = 5,
# )
sgc_exp = dict(
    label = "SGC",
    collection = "m_label_sbm_besthp_sgc",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
# sgc_depth2_exp = dict(
#     label = "SGC_depth2",
#     collection = "m_label_sbm_sgc",
#     start_id = 151,
#     end_id = 250,
#     n_seeds = 5,
# )
# sgc_depth4_exp = dict(
#     label = "SGC_depth4",
#     collection = "m_label_sbm_sgc",
#     start_id = 301,
#     end_id = 400,
#     n_seeds = 5,
# )
# appnp_alp0_exp = dict(
#     label = "APPNP_alpha0",
#     collection = "m_label_sbm_appnp",
#     start_id = 1,
#     end_id = 100,
#     n_seeds = 5,
# )
# appnp_alp01_exp = dict(
#     label = "APPNP_alpha0.1",
#     collection = "m_label_sbm_appnp",
#     start_id = 101,
#     end_id = 200,
#     n_seeds = 5,
# )
# appnp_alp02_exp = dict(
#     label = "APPNP_alpha0.2",
#     collection = "m_label_sbm_appnp",
#     start_id = 201,
#     end_id = 300,
#     n_seeds = 5,
# )
appnp_alp03_exp = dict(
    label = "APPNP_0.3",
    collection = "m_label_sbm_besthp_appnp03",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
appnp_alp05_exp = dict(
    label = "APPNP_0.5",
    collection = "m_label_sbm_besthp_appnp05",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
mlp_exp = dict(
    label = "MLP",
    collection = "m_label_sbm_besthp_mlp",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
gin_exp = dict(
    label = "GIN",
    collection = "m_label_sbm_besthp_gin",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
gsage_exp = dict(
    label = "GraphSAGE",
    collection = "m_label_sbm_besthp_graphsage",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
skippc_exp = dict(
    label = "GCN_skippc_linear",
    collection = "m_label_sbm_besthp_gcn_skippc",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
skipalpha_exp = dict(
    label = "GCN_skipalpha_linear_alpha0.1",
    collection = "m_label_sbm_besthp_gcn_skipalpha",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
K = 1.5
delta_l = [0,0.03, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.5, 1]

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})

# %% [markdown]
# ## Label cert

# %%
experiments = [gcn_exp, sgc_exp, mlp_exp, appnp_alp03_exp, appnp_alp05_exp,
               gin_exp, gsage_exp, skippc_exp, skipalpha_exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# 1
# 801
# Loading 1000th experiment...
# 1601
# Loading 2000th experiment...
# 2401
# Loading 3000th experiment...
# 3201
# Loading 4000th experiment...
# 4001
# 4801
# Loading 5000th experiment...
# 5601
# Loading 6000th experiment...
# 6401
# Loading 7000th experiment...
# 1
# 801
# Loading 1000th experiment...
# 1601
# Loading 2000th experiment...
# 2401
# Loading 3000th experiment...
# 3201
# Loading 4000th experiment...
# 4001
# 4801
# Loading 5000th experiment...
# 5601
# Loading 6000th experiment...
# 6401
# Loading 7000th experiment...
# 1
# 801
# Loading 1000th experiment...
# 1601
# Loading 2000th experiment...
# 2401
# Loading 3000th experiment...
# 3201
# Loading 4000th experiment...
# 4001
# 4801
# Loading 5000th experiment...
# 5601
# Loading 6000th experiment...
# 6401
# Loading 7000th experiment...
# 1
# 801
# Loading 1000th experiment...
# 1601
# Loading 2000th experiment...
# 2401
# Loading 3000th experiment...
# 3201
# Loading 4000th experiment...
# 4001
# 4801
# ...

# %%
C_l = None 
models = ["GCN", "SGC", "APPNP_0.3", "APPNP_0.5" ,"MLP"]
experiment_manager.plot_robust_acc_delta_v2(models, C_l, 
                                         delta_l=delta_l)

# %%
C_l = None 
models = ["GCN", "SGC", "APPNP_0.3", "APPNP_0.5" ,
          "GIN", "GraphSAGE", 
          "GCN_skipalpha_linear_alpha0.1", "GCN_skippc_linear",
          "MLP"]
legend_labels = ["GCN", "SGC", "APPNP $\\alpha=0.3$", "APPNP $\\alpha=0.5$" ,
          "GIN", "GraphSAGE", 
          "GCN Skip-$\\alpha$", "GCN Skip-PC",
          "MLP"]
experiment_manager.plot_robust_acc_delta_v2(models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels)

# %%
C_l = None 
models = ["GCN", "SGC", "APPNP_0.3", "APPNP_0.5" ,
          "GIN", "GraphSAGE", 
        #   "GCN_skipalpha_linear_alpha0.1", "GCN_skippc_linear",
          "MLP"]
legend_labels = ["GCN", "SGC", "APPNP $\\alpha=0.3$", "APPNP $\\alpha=0.5$" ,
          "GIN", "GraphSAGE", 
        #   "GCN Skip-$\\alpha$", "GCN Skip-PC",
          "MLP"]
experiment_manager.plot_robust_acc_delta_v2(models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels)

# %%
C_l = [0.01]
models = ["GCN", #"GCN_depth2", "GCN_depth4", 
          "SGC", #"SGC_depth2", "SGC_depth4"
          "APPNP_alpha0", "APPNP_alpha0.1", "APPNP_alpha0.2",
          "APPNP_alpha0.3", "APPNP_alpha0.5", "APPNP_alpha1",  
          ]
experiment_manager.plot_robust_acc_delta(K, models, C_l, 
                                         delta_l=delta_l, use_style=False)

# %%
C_l = [0.01]
models = ["GCN", #"GCN_depth2", "GCN_depth4", 
          "SGC", #"SGC_depth2", "SGC_depth4"
          "APPNP_linear_alpha0", "APPNP_linear_alpha0.1", "APPNP_linear_alpha0.2",
          "APPNP_linear_alpha0.3", "APPNP_linear_alpha0.5", "APPNP_linear_alpha1",  
          ]
experiment_manager.plot_robust_acc_delta(K, models, C_l, 
                                         delta_l=delta_l, use_style=False)

# %%
C_l = [0.001]
models = ["GCN", "GCN_depth2", "GCN_depth4", 
          "SGC", "SGC_depth2", "SGC_depth4"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, 
                                         delta_l=delta_l, use_style=False)

# %%
C_l = [0.01]
models = ["GCN", #"GCN_depth2", "GCN_depth4", 
          "SGC", #"SGC_depth2", "SGC_depth4"
          "GCN_sym",
          "SGC_sym"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, 
                                         delta_l=delta_l, use_style=False)

# %%
C_l = [0.01]
models = ["GCN", "GCN_depth2", #"GCN_depth4", 
          "SGC", #"SGC_depth2", "SGC_depth4"
          "GCN_data2x", "GCN_data2x_depth2",
          "SGC_data2x"]
experiment_manager.plot_robust_acc_delta(K, models, C_l, 
                                         delta_l=delta_l, use_style=False)

# %% [markdown]
# ## Collective cert

# %%
gcn_coll_exp = dict(
    label = "GCN",
    relabel = "GCN_coll",
    collection = "m_label_collect_sbm_gcn",
    start_id = 1,
    end_id = 100,
    n_seeds = 5,
)
gcn_depth2_coll_exp = dict(
    label = "GCN_depth2",
    relabel = "GCN_depth2_coll",
    collection = "m_label_collect_sbm_gcn",
    start_id = 101,
    end_id = 200,
    n_seeds = 5,
)
gcn_depth4_coll_exp = dict(
    label = "GCN_depth4",
    relabel = "GCN_depth4_coll",
    collection = "m_label_collect_sbm_gcn",
    start_id = 201,
    end_id = 300,
    n_seeds = 5,
)
sgc_coll_exp = dict(
    label = "SGC",
    relabel = "SGC_coll",
    collection = "m_label_collect_sbm_sgc",
    start_id = 1,
    end_id = 100,
    n_seeds = 5,
)
sgc_depth2_coll_exp = dict(
    label = "SGC_depth2",
    relabel = "SGC_depth2_coll",
    collection = "m_label_collect_sbm_sgc",
    start_id = 101,
    end_id = 200,
    n_seeds = 5,
)
sgc_depth4_coll_exp = dict(
    label = "SGC_depth4",
    relabel = "SGC_depth4_coll",
    collection = "m_label_collect_sbm_sgc",
    start_id = 201,
    end_id = 300,
    n_seeds = 5,
)
appnp_alp0_coll_exp = dict(
    label = "APPNP_linear_alpha0",
    relabel = "APPNP_linear_alpha0_coll",
    collection = "m_label_collect_sbm_appnp",
    start_id = 1,
    end_id = 100,
    n_seeds = 5,
)
appnp_alp01_coll_exp = dict(
    label = "APPNP_linear_alpha0.1",
    relabel = "APPNP_linear_alpha0.1_coll",
    collection = "m_label_collect_sbm_appnp",
    start_id = 101,
    end_id = 200,
    n_seeds = 5,
)
appnp_alp02_coll_exp = dict(
    label = "APPNP_linear_alpha0.2",
    relabel = "APPNP_linear_alpha0.2_coll",
    collection = "m_label_collect_sbm_appnp",
    start_id = 201,
    end_id = 300,
    n_seeds = 5,
)
appnp_alp03_coll_exp = dict(
    label = "APPNP_linear_alpha0.3",
    relabel = "APPNP_linear_alpha0.3_coll",
    collection = "m_label_collect_sbm_appnp",
    start_id = 301,
    end_id = 400,
    n_seeds = 5,
)
appnp_alp05_coll_exp = dict(
    label = "APPNP_linear_alpha0.5",
    relabel = "APPNP_linear_alpha0.5_coll",
    collection = "m_label_collect_sbm_appnp",
    start_id = 401,
    end_id = 500,
    n_seeds = 5,
)
appnp_alp10_coll_exp = dict(
    label = "APPNP_linear_alpha1",
    relabel = "APPNP_linear_alpha1_coll",
    collection = "m_label_collect_sbm_appnp",
    start_id = 501,
    end_id = 600,
    n_seeds = 5,
)
K = 1.5
delta_l = [0,0.03, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.4, 0.5, 1]

# %%
experiments = [gcn_exp, gcn_depth2_exp, gcn_depth4_exp,
                sgc_exp, sgc_depth2_exp, sgc_depth4_exp,
                gcn_coll_exp, gcn_depth2_coll_exp, gcn_depth4_coll_exp,
                sgc_coll_exp, sgc_depth2_coll_exp, sgc_depth4_coll_exp,
                # gcn_sym_exp, gcn_sym_depth2_exp, gcn_sym_depth4_exp,
                # sgc_sym_exp, sgc_sym_depth2_exp, sgc_sym_depth4_exp,
                # gcn_2x_exp, gcn_2x_depth2_exp, gcn_2x_depth4_exp,
                # sgc_2x_exp, sgc_2x_depth2_exp, sgc_2x_depth4_exp,
                # appnp_alp0_exp, appnp_alp01_exp, appnp_alp02_exp, 
                # appnp_alp03_exp, appnp_alp05_exp, appnp_alp10_exp, 
                appnp_alp0_coll_exp, appnp_alp01_coll_exp, appnp_alp02_coll_exp, 
                appnp_alp03_coll_exp, appnp_alp05_coll_exp, appnp_alp10_coll_exp, 
                # appnp_alp0_coll_exp, appnp_alp01_coll_exp, appnp_alp02_coll_exp, 
                # appnp_alp03_coll_exp, appnp_alp05_coll_exp, appnp_alp10_coll_exp, 
                appnp_linear_alp0_exp, appnp_linear_alp01_exp, appnp_linear_alp02_exp, 
                appnp_linear_alp03_exp, appnp_linear_alp05_exp, appnp_linear_alp10_exp, 
                ]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN No. of experiments 20
# GCN_depth2 No. of experiments 20
# GCN_depth4 No. of experiments 20
# SGC No. of experiments 20
# SGC_depth2 No. of experiments 20
# SGC_depth4 No. of experiments 20
# GCN No. of experiments 20
# GCN_depth2 No. of experiments 20
# GCN_depth4 No. of experiments 20
# SGC No. of experiments 20
# SGC_depth2 No. of experiments 20
# SGC_depth4 No. of experiments 20
# APPNP_linear_alpha0 No. of experiments 20
# APPNP_linear_alpha0.1 No. of experiments 20
# APPNP_linear_alpha0.2 No. of experiments 20
# APPNP_linear_alpha0.3 No. of experiments 20
# APPNP_linear_alpha0.5 No. of experiments 20
# APPNP_linear_alpha1 No. of experiments 20
# APPNP_linear_alpha0 No. of experiments 20
# APPNP_linear_alpha0.1 No. of experiments 20
# APPNP_linear_alpha0.2 No. of experiments 20
# APPNP_linear_alpha0.3 No. of experiments 20
# APPNP_linear_alpha0.5 No. of experiments 20
# APPNP_linear_alpha1 No. of experiments 20

# %%
C_l = [0.01]
models = ["GCN", "GCN_depth2", 
          "GCN_depth4", 
          "GCN_coll", "GCN_depth2_coll", 
          "GCN_depth4_coll", 
          ]
experiment_manager.plot_robust_acc_delta(K, models, C_l, 
                                         delta_l=delta_l, use_style=False)

# %%
# plot with y_is_robust instead of y_worst_obj for m_label_coll_sbm_sgc
C_l = [0.01]
models = ["SGC", 
          "SGC_depth2", 
          "SGC_depth4", 
          "SGC_coll", 
          "SGC_depth2_coll", 
          "SGC_depth4_coll", 
          ]
experiment_manager.plot_robust_acc_delta(K, models, C_l, 
                                         delta_l=delta_l, use_style=False)

# %%
C_l = [0.01]
models = ["SGC", "SGC_depth2", "SGC_depth4", 
          "SGC_coll", "SGC_depth2_coll", "SGC_depth4_coll", 
          ]
experiment_manager.plot_robust_acc_delta(K, models, C_l, 
                                         delta_l=delta_l, use_style=False)

# %%
C_l = [0.01]
models = [
          "GCN_coll", "GCN_depth2_coll", 
          "GCN_depth4_coll", 
          "SGC_coll", "SGC_depth2_coll", "SGC_depth4_coll", 
          ]
experiment_manager.plot_robust_acc_delta(K, models, C_l, 
                                         delta_l=delta_l, use_style=False)

# %%
C_l = [0.01]
models = ["GCN", "GCN_depth2", #"GCN_depth4", 
          "GCN_coll", "GCN_depth2_coll",  #"GCN_depth4_coll", 
        "SGC", "SGC_depth2", #"SGC_depth4", 
          "SGC_coll", "SGC_depth2_coll", #"SGC_depth4_coll", 
          ]
experiment_manager.plot_robust_acc_delta(K, models, C_l, 
                                         delta_l=delta_l, use_style=False)

# %%
C_l = [0.01]
models = ["APPNP_linear_alpha0", 
          # "APPNP_linear_alpha0.1", 
          "APPNP_linear_alpha0.2", 
          # "APPNP_linear_alpha0.3", 
          # "APPNP_linear_alpha0.5",  
          "APPNP_linear_alpha1", 
        "APPNP_linear_alpha0_coll", 
        # "APPNP_linear_alpha0.1_coll",
          "APPNP_linear_alpha0.2_coll", 
          # "APPNP_linear_alpha0.3_coll", 
          # "APPNP_linear_alpha0.5_coll",  
          "APPNP_linear_alpha1_coll", 
          ]
experiment_manager.plot_robust_acc_delta(K, models, C_l, 
                                         delta_l=delta_l, use_style=False)

# %%
C_l = [0.01]
models = ["GCN", 
        "SGC", 
        # "APPNP_linear_alpha0", 
          "APPNP_linear_alpha0.2", 
          "APPNP_linear_alpha1", 
          "GCN_coll",
          "SGC_coll", 
          # "APPNP_linear_alpha0_coll", 
          "APPNP_linear_alpha0.2_coll", 
          "APPNP_linear_alpha1_coll",
          ]
experiment_manager.plot_robust_acc_delta(K, models, C_l, 
                                         delta_l=delta_l, use_style=False)
