# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt

# %%
label_fontsize = 24 #20 #29
legend_fontsize = 14 #12 #14
ticks_fontsize = 14 #12 #14
use_custom_legend = True
linewidth = 1.3 #1.2 #1.5
markersize = 4 #6
capsize = 4 #6
framealpha = 0.5

# %%
gcn_exp = dict(
    label = "GCN",
    collection = "m_label_sbm_n10_gcn",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
sgc_exp = dict(
    label = "SGC",
    collection = "m_label_sbm_n10_sgc",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
appnp_exp = dict(
    label = "APPNP_0.1",
    collection = "m_label_sbm_n10_appnp",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
mlp_exp = dict(
    label = "MLP",
    collection = "m_label_sbm_n10_mlp",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
gin_exp = dict(
    label = "GIN",
    collection = "m_label_sbm_n10_gin",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
gsage_exp = dict(
    label = "GraphSAGE",
    collection = "m_label_sbm_n10_graphsage",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
skippc_exp = dict(
    label = "GCN_skippc_linear",
    collection = "m_label_sbm_n10_gcn_skippc",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
skipalpha_exp = dict(
    label = "GCN_skipalpha_linear",
    collection = "m_label_sbm_n10_gcn_skipalpha",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
K = 1.5
delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.5, 1]

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})

# %% [markdown]
# ## Label cert

# %%
experiments = [gcn_exp, sgc_exp, mlp_exp, appnp_exp,
               gin_exp, gsage_exp, skippc_exp, skipalpha_exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# 1
# 901
# Loading 1000th experiment...
# 1801
# Loading 2000th experiment...
# 2701
# Loading 3000th experiment...
# 3601
# Loading 4000th experiment...
# 4501
# Loading 5000th experiment...
# 5401
# Loading 6000th experiment...
# 6301
# Loading 7000th experiment...
# 1
# 901
# Loading 1000th experiment...
# 1801
# Loading 2000th experiment...
# 2701
# Loading 3000th experiment...
# 3601
# Loading 4000th experiment...
# 4501
# Loading 5000th experiment...
# 5401
# Loading 6000th experiment...
# 6301
# Loading 7000th experiment...
# 1
# 901
# Loading 1000th experiment...
# 1801
# Loading 2000th experiment...
# 2701
# Loading 3000th experiment...
# 3601
# Loading 4000th experiment...
# 4501
# Loading 5000th experiment...
# 5401
# Loading 6000th experiment...
# 6301
# Loading 7000th experiment...
# 1
# 901
# Loading 1000th experiment...
# 1801
# Loading 2000th experiment...
# 2701
# Loading 3000th experiment...
# 3601
# Loading 4000th experiment...
# 4501
# Loading 5000th experiment...
# 5401
# Loading 6000th experiment...
# 6301
# Loading 7000th experiment...
# 1
# 901
# Loading 1000th experiment...
# 1801
# Loading 2000th experiment...
# 2701
# Loading 3000th experiment...
# 3601
# Loading 4000th experiment...
# 4501
# Loading 5000th experiment...
# 5401
# Loading 6000th experiment...
# 6301
# Loading 7000th experiment...
# 1
# 901
# Loading 1000th experiment...
# 1801
# Loading 2000th experiment...
# 2701
# Loading 3000th experiment...
# 3601
# Loading 4000th experiment...
# 4501
# Loading 5000th experiment...
# 5401
# Loading 6000th experiment...
# 6301
# Loading 7000th experiment...
# 1
# 901
# Loading 1000th experiment...
# 1801
# Loading 2000th experiment...
# 2701
# Loading 3000th experiment...
# 3601
# Loading 4000th experiment...
# 4501
# Loading 5000th experiment...
# 5401
# Loading 6000th experiment...
# 6301
# Loading 7000th experiment...
# 1
# 901
# Loading 1000th experiment...
# 1801
# Loading 2000th experiment...
# 2701
# Loading 3000th experiment...
# 3601
# Loading 4000th experiment...
# 4501
# Loading 5000th experiment...
# 5401
# Loading 6000th experiment...
# 6301
# Loading 7000th experiment...

# %%
C_l = None 
models = ["GCN", "SGC", "APPNP_0.1", 
          "GIN", "GraphSAGE", 
          "GCN_skipalpha_linear", "GCN_skippc_linear",
          "MLP"]
legend_labels = ["GCN", "SGC", "APPNP", 
          "GIN", "GraphSAGE", 
          "GCN Skip-$\\alpha$", "GCN Skip-PC",
          "MLP"]
delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.5]
savefig = "sbm_n10_samplewise.pdf"
experiment_manager.plot_robust_acc_delta_v2(models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels,
                                        label_fontsize=label_fontsize,
                                        legend_fontsize=legend_fontsize,
                                        ticks_fontsize=ticks_fontsize,
                                        markersize=markersize,
                                        capsize=capsize,
                                        linewidth=linewidth,
                                        framealpha=framealpha,
                                         savefig=savefig)

# %%
label_fontsize = 24 #20 #29
legend_fontsize = 14 #12 #14
ticks_fontsize = 14 #12 #14
use_custom_legend = True
linewidth = 1.3 #1.2 #1.5
markersize = 4 #6
capsize = 4 #6
framealpha = 0.5

# %%
C_l = None 
models = ["GCN", "SGC", "APPNP_0.1", 
          "GIN", "GraphSAGE", 
          "GCN_skipalpha_linear", "GCN_skippc_linear",
          "MLP"]
legend_labels = ["GCN", "SGC", "APPNP", 
          "GIN", "GraphSAGE", 
          "GCN Skip-$\\alpha$", "GCN Skip-PC",
          "MLP"]
delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3]
savefig = "sbm_n10_samplewise_b03.pdf"
linewidth = 1.8
markersize = 6
capsize = 6
label_fontsize = 24
legend_fontsize = 16
ticks_fontsize = 16
use_custom_legend = True
legend_args = dict(
    framealpha = 0.5,
    handlelength = 1.5,
    handletextpad = 0.5,
    labelspacing = 0.3,
    loc="lower left",
    bbox_to_anchor=(0.585,.238),
    #bbox_to_anchor=(0.33,.585),
    ncol=1,
    #columnspacing=0.3,
    columnspacing=1
)
experiment_manager.plot_robust_acc_delta_v2(models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels,
                                        label_fontsize=label_fontsize,
                                        legend_fontsize=legend_fontsize,
                                        ticks_fontsize=ticks_fontsize,
                                        markersize=markersize,
                                        capsize=capsize,
                                        linewidth=linewidth,
                                        legend_args=legend_args,
                                         savefig=savefig,
                                         use_custom_legend=True
                                        )

# %%
C_l = None 
models = ["GCN", "SGC", "APPNP_0.1", 
          "GIN", "GraphSAGE", 
          "MLP"]
legend_labels = ["GCN", "SGC", "APPNP",
          "GIN", "GraphSAGE", 
          "MLP"]
delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.5]
experiment_manager.plot_robust_acc_delta_v2(models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels,
                                         savefig="sbm_label_pt_woskip.pdf")

# %% [markdown]
# ## save for collective

# %%
C_l = None 
models = ["GCN", "SGC", "APPNP_0.1", 
          "GIN", "GraphSAGE", 
          "GCN_skipalpha_linear", "GCN_skippc_linear",
          "MLP"]
legend_labels = ["GCN", "SGC", "APPNP", 
          "GIN", "GraphSAGE", 
          "GCN Skip-$\\alpha$", "GCN Skip-PC",
          "MLP"]
delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.5, 1]
df = experiment_manager.save_results(models, C_l, delta_l,legend_labels,
savefile="sbm_sample_results.csv")

# %%
import pandas as pd
pd.set_option('display.max_rows', 100)
df.head(100)
# Out:
#                 model delta     certified_acc_mean      certified_acc_std  \
# 0                 GCN   0.0     0.8577777777777778    0.34927791474468445
# 1                 GCN   0.0     0.6455555555555555    0.10531551654286922
# 2                 GCN   0.0    0.27888888888888885    0.13655370218433083
# 3                 GCN   0.0   0.012222222222222223   0.017356110390903675
# 4                 GCN   0.0                    0.0                    0.0
# 5                 GCN   0.0                    0.0                    0.0
# 6                 GCN   0.0                    0.0                    0.0
# 7                 GCN   0.0                    0.0                    0.0
# 8                 GCN  0.05                    0.0                    0.0
# 9                 SGC  0.05     0.8711111111111111     0.3350769213328136
# 10                SGC  0.05     0.7866666666666667    0.04747969026493664
# 11                SGC  0.05     0.6722222222222223    0.10674765443978175
# 12                SGC  0.05     0.4866666666666667     0.1632463865329012
# 13                SGC  0.05     0.2977777777777778    0.19240517946879643
# 14                SGC  0.05     0.1322222222222222     0.1403434939578472
# 15                SGC  0.05    0.01888888888888889    0.03777777777777778
# 16                SGC   0.1                    0.0                    0.0
# 17                SGC   0.1                    0.0                    0.0
# 18              APPNP   0.1     0.8766666666666667    0.32881943711134565
# 19              APPNP   0.1     0.6311111111111112    0.09458159975569073
# 20              APPNP   0.1     0.2011111111111111    0.14817407180595246
# 21              APPNP   0.1   0.006666666666666666   0.010772621905369617
# 22              APPNP   0.1  0.0011111111111111111  0.0022222222222222222
# 23              APPNP   0.1  0.0022222222222222222  0.0044444444444444444
# 24              APPNP  0.15   0.003333333333333333   0.002721655269759087
# 25              APPNP  0.15  0.0011111111111111111  0.0022222222222222222
# 26              APPNP  0.15                    0.0                    0.0
# 27                GIN  0.15     0.8033333333333333     0.3974781615244904
# 28                GIN  0.15     0.5199999999999999    0.15625240738886176
# 29                GIN  0.15    0.21000000000000002    0.14034349395784723
# 30                GIN  0.15    0.03111111111111111    0.04076430295076476
# 31                GIN  0.15  0.0011111111111111111  0.0022222222222222222
# 32                GIN   0.2                    0.0                    0.0
# 33                GIN   0.2                    0.0                    0.0
# 34                GIN   0.2                    0.0                    0.0
# 35                GIN   0.2                    0.0                    0.0
# 36          GraphSAGE   0.2     0.8455555555555555     0.3613742630911772
# 37          GraphSAGE   0.2     0.5588888888888889    0.14429907214608909
# 38          GraphSAGE   0.2    0.19333333333333336    0.12374805148734094
# 39          GraphSAGE   0.2   0.012222222222222223   0.017356110390903675
# 40          GraphSAGE  0.25                    0.0                    0.0
# 41          GraphSAGE  0.25                    0.0                    0.0
# 42          GraphSAGE  0.25                    0.0                    0.0
# 43          GraphSAGE  0.25                    0.0                    0.0
# 44          GraphSAGE  0.25                    0.0                    0.0
# 45  GCN Skip-$\alpha$  0.25     0.8533333333333334     0.3537733109712427
# 46  GCN Skip-$\alpha$  0.25     0.6388888888888888    0.08992452253465914
# 47  GCN Skip-$\alpha$  0.25    0.30111111111111116    0.13541887462587435
# 48  GCN Skip-$\alpha$   0.3    0.04555555555555556    0.05402331458285875
# 49  GCN Skip-$\alpha$   0.3                    0.0                    0.0
# 50  GCN Skip-$\alpha$   0.3                    0.0                    0.0
# 51  GCN Skip-$\alpha$   0.3                    0.0                    0.0
# 52  GCN Skip-$\alpha$   0.3                    0.0                    0.0
# 53  GCN Skip-$\alpha$   0.3                    0.0                    0.0
# 54        GCN Skip-PC   0.3                   0.85     0.3570714214271425
# 55        GCN Skip-PC   0.3     0.6944444444444444    0.08663817195385747
# 56        GCN Skip-PC   0.5     0.4922222222222222     0.1258354795009522
# 57        GCN Skip-PC   0.5    0.25222222222222224    0.16966197330334568
# 58        GCN Skip-PC   0.5    0.08222222222222222    0.07992280225935308
# 59        GCN Skip-PC   0.5  0.0011111111111111111  0.0022222222222222222
# 60        GCN Skip-PC   0.5                    0.0                    0.0
# 61        GCN Skip-PC   0.5                    0.0                    0.0
# 62        GCN Skip-PC   0.5                    0.0                    0.0
# 63                MLP   0.5     0.7455555555555555     0.4355484693301108
# 64                MLP   1.0     0.3044444444444444    0.08038487665638189
# 65                MLP   1.0   0.015555555555555555   0.015071844406945043
# 66                MLP   1.0                    0.0                    0.0
# 67                MLP   1.0                    0.0                    0.0
# 68                MLP   1.0                    0.0                    0.0
# 69                MLP   1.0                    0.0                    0.0
# 70                MLP   1.0                    0.0                    0.0
# 71                MLP   1.0                    0.0                    0.0
#
#      certified_ratio_mean    certified_ratio_std
# 0                     1.0                    0.0
# 1      0.6888888888888889    0.11434191739722607
# 2     0.28888888888888886     0.1397970310004587
# 3    0.012222222222222223   0.017356110390903675
# 4                     0.0                    0.0
# 5                     0.0                    0.0
# 6                     0.0                    0.0
# 7                     0.0                    0.0
# 8                     0.0                    0.0
# 9                     1.0                    0.0
# 10     0.8666666666666666    0.05687326174253213
# 11     0.7266666666666666    0.11829028951098479
# 12     0.5155555555555555    0.16918103387266026
# 13     0.3088888888888889    0.19778401987652722
# 14    0.13666666666666666    0.14339791826579268
# 15    0.01888888888888889    0.03777777777777778
# 16                    0.0                    0.0
# 17                    0.0                    0.0
# 18                    1.0                    0.0
# 19     0.6677777777777777     0.0903627804948776
# 20    0.21222222222222217    0.15703266940117672
# 21  0.0077777777777777776   0.010886621079036346
# 22  0.0011111111111111111  0.0022222222222222222
# 23  0.0022222222222222222  0.0044444444444444444
# 24   0.003333333333333333   0.002721655269759087
# 25  0.0011111111111111111  0.0022222222222222222
# 26                    0.0                    0.0
# 27                    1.0                    0.0
# 28     0.5955555555555556    0.18353187902183085
# 29    0.23222222222222225    0.15122544694088075
# 30    0.03666666666666667    0.04494166314701486
# 31  0.0011111111111111111  0.0022222222222222222
# 32                    0.0                    0.0
# 33                    0.0                    0.0
# 34                    0.0                    0.0
# 35                    0.0                    0.0
# 36                    1.0                    0.0
# 37     0.6077777777777779    0.15976835082683283
# 38    0.20222222222222222    0.12903248705674622
# 39   0.013333333333333332   0.017777777777777778
# 40                    0.0                    0.0
# 41                    0.0                    0.0
# 42                    0.0                    0.0
# 43                    0.0                    0.0
# 44                    0.0                    0.0
# 45                    1.0                    0.0
# 46     0.6911111111111111    0.10355412493050895
# 47    0.31444444444444447    0.14048417159643217
# 48    0.04666666666666667   0.055622182270150346
# 49                    0.0                    0.0
# 50                    0.0                    0.0
# 51                    0.0                    0.0
# 52                    0.0                    0.0
# 53                    0.0                    0.0
# 54                    1.0                    0.0
# 55      0.768888888888889    0.09549093422162398
# 56     0.5311111111111111    0.13261845392322913
# 57     0.2633333333333333     0.1764044175141839
# 58    0.08333333333333333    0.08073734277593311
# 59  0.0011111111111111111  0.0022222222222222222
# 60                    0.0                    0.0
# 61                    0.0                    0.0
# 62                    0.0                    0.0
# 63                    1.0                    0.0
# 64    0.35888888888888887    0.07549016778428012
# 65   0.016666666666666666   0.014487116456005887
# 66                    0.0                    0.0
# 67                    0.0                    0.0
# 68                    0.0                    0.0
# 69                    0.0                    0.0
# 70                    0.0                    0.0
# 71                    0.0                    0.0
