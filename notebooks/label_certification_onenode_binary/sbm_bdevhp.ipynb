# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt

# %%
label_fontsize = 24 #20 #29
legend_fontsize = 14 #12 #14
ticks_fontsize = 14 #12 #14
use_custom_legend = True
linewidth = 1.3 #1.2 #1.5
markersize = 4 #6
capsize = 4 #6
framealpha = 0.5

# %%
gcn_exp = dict(
    label = "GCN",
    collection = "m_label_sbm_bdevhp_gcn",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
sgc_exp = dict(
    label = "SGC",
    collection = "m_label_sbm_bdevhp_sgc",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
appnp_alp03_exp = dict(
    label = "APPNP_0.3",
    collection = "m_label_sbm_besthp_appnp03",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
mlp_exp = dict(
    label = "MLP",
    collection = "m_label_sbm_bdevhp_mlp",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
gin_exp = dict(
    label = "GIN",
    collection = "m_label_sbm_besthp_gin",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
gsage_exp = dict(
    label = "GraphSAGE",
    collection = "m_label_sbm_bdevhp_graphsage",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
skippc_exp = dict(
    label = "GCN_skippc_linear",
    collection = "m_label_sbm_bdevhp_gcn_skippc",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
skipalpha_exp = dict(
    label = "GCN_skipalpha_linear_alpha0.1",
    collection = "m_label_sbm_bdevhp_gcn_skipalpha",
    start_id = 1,
    end_id = 7200,
    n_seeds = 5,
)
K = 1.5
delta_l = [0,0.03, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.5, 1]

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})

# %% [markdown]
# ## Label cert

# %%
experiments = [gcn_exp, sgc_exp, mlp_exp, appnp_alp03_exp,
               gin_exp, gsage_exp, skippc_exp, skipalpha_exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# 1
# 801
# Loading 1000th experiment...
# 1601
# Loading 2000th experiment...
# 2401
# Loading 3000th experiment...
# 3201
# Loading 4000th experiment...
# 4001
# 4801
# Loading 5000th experiment...
# 5601
# Loading 6000th experiment...
# 6401
# Loading 7000th experiment...
# 1
# 801
# Loading 1000th experiment...
# 1601
# Loading 2000th experiment...
# 2401
# Loading 3000th experiment...
# 3201
# Loading 4000th experiment...
# 4001
# 4801
# Loading 5000th experiment...
# 5601
# Loading 6000th experiment...
# 6401
# Loading 7000th experiment...
# 1
# 801
# Loading 1000th experiment...
# 1601
# Loading 2000th experiment...
# 2401
# Loading 3000th experiment...
# 3201
# Loading 4000th experiment...
# 4001
# 4801
# Loading 5000th experiment...
# 5601
# Loading 6000th experiment...
# 6401
# Loading 7000th experiment...
# 1
# 801
# Loading 1000th experiment...
# 1601
# Loading 2000th experiment...
# 2401
# Loading 3000th experiment...
# 3201
# Loading 4000th experiment...
# 4001
# 4801
# ...

# %%
C_l = None 
models = ["GCN", "SGC", "APPNP_0.3", 
          "GIN", "GraphSAGE", 
          "GCN_skipalpha_linear_alpha0.1", "GCN_skippc_linear",
          "MLP"]
legend_labels = ["GCN", "SGC", "APPNP", 
          "GIN", "GraphSAGE", 
          "GCN Skip-$\\alpha$", "GCN Skip-PC",
          "MLP"]
delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.5]
savefig = "sbm_samplewise.pdf"
experiment_manager.plot_robust_acc_delta_v2(models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels,
                                        label_fontsize=label_fontsize,
                                        legend_fontsize=legend_fontsize,
                                        ticks_fontsize=ticks_fontsize,
                                        markersize=markersize,
                                        capsize=capsize,
                                        linewidth=linewidth,
                                        framealpha=framealpha,
                                         savefig=savefig)

# %%
C_l = None 
models = ["GCN", "SGC", "APPNP_0.3", 
          "GIN", "GraphSAGE", 
          "GCN_skipalpha_linear_alpha0.1", "GCN_skippc_linear",
          "MLP"]
legend_labels = ["GCN", "SGC", "APPNP", 
          "GIN", "GraphSAGE", 
          "GCN Skip-$\\alpha$", "GCN Skip-PC",
          "MLP"]
delta_l = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3]
savefig = "sbm_samplewise_b03.pdf"
linewidth = 1.8
markersize = 6
capsize = 6
label_fontsize = 24
legend_fontsize = 16
ticks_fontsize = 16
use_custom_legend = True
legend_args = dict(
    framealpha = 0.5,
    handlelength = 1.5,
    handletextpad = 0.5,
    labelspacing = 0.3,
    loc="lower left",
    bbox_to_anchor=(0.585,.238),
    #bbox_to_anchor=(0.33,.585),
    ncol=1,
    #columnspacing=0.3,
    columnspacing=1
)
experiment_manager.plot_robust_acc_delta_v2(models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels,
                                        label_fontsize=label_fontsize,
                                        legend_fontsize=legend_fontsize,
                                        ticks_fontsize=ticks_fontsize,
                                        markersize=markersize,
                                        capsize=capsize,
                                        linewidth=linewidth,
                                        legend_args=legend_args,
                                         savefig=savefig,
                                         use_custom_legend=True
                                        )

# %%
C_l = None 
models = ["GCN", "SGC", "APPNP_0.3", 
          "GIN", "GraphSAGE", 
          "MLP"]
legend_labels = ["GCN", "SGC", "APPNP",
          "GIN", "GraphSAGE", 
          "MLP"]
experiment_manager.plot_robust_acc_delta_v2(models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels,
                                         savefig="sbm_label_pt_woskip.pdf")

# %%
C_l = None 
models = ["GCN", "SGC", "APPNP_0.3", 
          "GIN", "GraphSAGE", 
          "MLP"]
legend_labels = ["GCN", "SGC", "APPNP",
          "GIN", "GraphSAGE", 
          "MLP"]
experiment_manager.plot_robust_acc_delta_v3(models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels,
                                         savefig="sbm_label_pt_woskip.pdf")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
