# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt

# %%
exp = dict(
    collection = "l_citeseer_n10_cert_label",
    start_id = 1,
    end_id = 3000,
    n_seeds = 3,
)
delta_l = [0,0.01,0.02,0.03,0.05,0.1]

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})

# %%
experiments = [exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# 1
# 151
# 301
# 451
# 601
# 751
# 901
# Loading 1000th experiment...
# 1051
# 1201
# 1351
# 1501
# 1651
# 1801
# 1951
# Loading 2000th experiment...
# 2101
# 2251
# 2401
# 2551
# 2701
# 2851
# Loading 3000th experiment...
# {'GCN': {0.0001: {0.01: <utils.Experiment object at 0x7ff1785fe8d0>, 0.02: <utils.Experiment object at 0x7ff1785c3590>, 0.03: <utils.Experiment object at 0x7ff175c91290>, 0.05: <utils.Experiment object at 0x7ff175b8c310>, 0.1: <utils.Experiment object at 0x7ff175a7a0d0>}}, 'SGC': {0.0001: {0.01: <utils.Experiment object at 0x7ff17594f810>, 0.02: <utils.Experiment object at 0x7ff17582e710>, 0.03: <utils.Experiment object at 0x7ff17572f210>, 0.05: <utils.Experiment object at 0x7ff175616d90>, 0.1: <utils.Experiment object at 0x7ff17550c510>}}, 'GCN_skipalpha': {0.0001: {0.01: <utils.Experiment object at 0x7ff1755e0c90>, 0.02: <utils.Experiment object at 0x7ff1754dee90>, 0.03: <utils.Experiment object at 0x7ff1753be490>, 0.05: <utils.Experiment object at 0x7ff1752a2d10>, 0.1: <utils.Experiment object at 0x7ff17519b010>}}, 'GCN_skippc': {0.0001: {0.01: <utils.Experiment object at 0x7ff17508fb10>, 0.02: <utils.Experiment object at 0x7ff174f64610>, 0.03: <utils.Experiment object at 0x7ff174e589d0>, 0.05: <utils.Experiment object at 0x7ff174d38b90>, 0.1: <utils.Experiment object at 0x7ff174c04c90>}}}

# %%
C_l = None 
models = ["GCN", "SGC", "GCN_skipalpha", "GCN_skippc"]
experiment_manager.plot_robust_auc(models, C_l, delta_l=delta_l, scale=True,
                                   barwidth=0.3)

# %%
C_l = None 
models = ["GCN", "SGC", "GCN_skipalpha", "GCN_skippc"]
delta_l = [0,0.01,0.02,0.03,0.05]
savefig = "citeseer_sample.pdf"
experiment_manager.plot_robust_acc_delta_v2(models, C_l, delta_l=delta_l,
                                            savefig=savefig)

# %%
C_l = None 
models = ["GCN", "GCN_skipalpha", "GCN_skippc"]
experiment_manager.plot_robust_acc_delta_v2(models, C_l, delta_l=delta_l)
