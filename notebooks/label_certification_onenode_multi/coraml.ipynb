# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
from utils import ExperimentManager
import matplotlib.pyplot as plt

# %%
gcn_exp = dict(
    label = "GCN",
    collection = "l_coraml_n10_cert_label",
    start_id = 1,
    end_id = 150,
    n_seeds = 3,
)
delta_l = [0,0.01]

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times New Roman"
})

# %% [markdown]
# ## Label cert

# %%
experiments = [gcn_exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# 1

# %%
C_l = None 
models = ["GCN"]
experiment_manager.plot_robust_acc_delta_v2(models, C_l, delta_l=delta_l)

# %%
C_l = None 
models = ["GCN", "SGC", "APPNP_0.3", 
          "GIN", "GraphSAGE", 
          "MLP"]
legend_labels = ["GCN", "SGC", "APPNP $\\alpha=0.3$",
          "GIN", "GraphSAGE", 
          "MLP"]
experiment_manager.plot_robust_acc_delta_v2(models, C_l, 
                                         delta_l=delta_l, legend_labels=legend_labels)
