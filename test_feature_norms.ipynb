# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import numpy as np
from exp_feature_norms import run

# %%
seed = 0

data_params = dict(
    dataset = "cora",
    learning_setting = "transductive", # or "transdructive"
    specification = dict(
        n_per_class = 10,
        fraction_test = 0.01,
        data_dir = "./data",
        make_undirected = True,
        binary_attr = False,
        balance_test = True,
    )
)

model_params = dict(
    label = "GCN",
    model = "GCN",
    normalization = "row_normalization",
    depth = 1,
    #regularizer = 1e-8
    regularizer = 1,
    pred_method = "svm",
    activation = "relu"
)

certificate_params = dict(
    n_adversarial = 1, # number adversarial nodes
    perturbation_model = "linf",
    delta = 0.01 # l0: local budget = delta * feature_dim
)

verbosity_params = dict(
    debug_lvl = "warning"
)  

other_params = dict(
    device = "cpu",
    dtype = torch.float64,
    allow_tf32 = False
)

# %%
# MIP foucs = 3
#model_params["cache_size"] = 10000
data_params["dataset"] = "cora_ml_cont"
other_params["device"] = "cpu"
other_params["debug"] = False
certificate_params["n_adversarial"] = 270
certificate_params["delta"] = 0.01
certificate_params["delta_absolute"] = False
certificate_params["method"] = "XXT"
certificate_params["perturbation_model"] = "l2"
certificate_params["attack_nodes"] = "test"
#certificate_params["MIPGap"] = 0
other_params["path_gurobi_license"] = "/ceph/ssd/staff/gosl/app/gurobi.lic"
verbosity_params["debug_lvl"] = "info"
model_params["regularizer"] = 0.005
model_params["solver"] = "qplayer_one_vs_all"
model_params["alpha_tol"] = 1e-4
model_params["bias"] = False
data_params["learning_setting"] = "transductive"
run(data_params, model_params, certificate_params, verbosity_params, other_params, seed)
# Out:
# 2024-04-25 21:40:08 (INFO): Starting experiment exp_feature_norms with configuration:
# 2024-04-25 21:40:08 (INFO): data_params: {'dataset': 'cora_ml_cont', 'learning_setting': 'transductive', 'specification': {'n_per_class': 10, 'fraction_test': 0.01, 'data_dir': './data', 'make_undirected': True, 'binary_attr': False, 'balance_test': True}}
# 2024-04-25 21:40:08 (INFO): model_params: {'label': 'GCN', 'model': 'GCN', 'normalization': 'row_normalization', 'depth': 1, 'regularizer': 0.005, 'pred_method': 'svm', 'activation': 'relu', 'solver': 'qplayer_one_vs_all', 'alpha_tol': 0.0001, 'bias': False}
# 2024-04-25 21:40:08 (INFO): certification_params: {'n_adversarial': 270, 'perturbation_model': 'l2', 'delta': 0.01, 'delta_absolute': False, 'method': 'XXT', 'attack_nodes': 'test'}
# 2024-04-25 21:40:08 (INFO): verbosity_params: {'debug_lvl': 'info'}
# 2024-04-25 21:40:08 (INFO): other_params: {'device': 'cpu', 'dtype': torch.float64, 'allow_tf32': False, 'debug': False, 'path_gurobi_license': '/ceph/ssd/staff/gosl/app/gurobi.lic'}
# 2024-04-25 21:40:08 (INFO): seed: 0
# 2024-04-25 21:40:09 (INFO): number of samples
#  - labeled: 70
#  - val: 70
#  - test: 304
#  - unlabeled: 2551
# l2 mean: 7.7197
# l2 std: 0.3571
# l2 min: 6.9548
# l2 max: 10.7235
# linf mean: 5.3808
# linf std: 0.6293
# linf min: 2.3617
# linf max: 6.5545
# l2_pair mean: 3.9473
# l2_pair std: 1.1661
# l2_pair min: 0.0000
# l2_pair max: 11.7527
# Class 0 Details:
# l2_pair to class 0 mean: 3.6487
# l2_pair to class 0 std: 1.1621
# l2_pair to class 0 min: 0.0000
# l2_pair to class 0 max: 11.5476
# l2_pair to class 1 mean: 3.9749
# l2_pair to class 1 std: 1.1681
# l2_pair to class 1 min: 1.8149
# l2_pair to class 1 max: 11.7459
# l2_pair to class 2 mean: 3.9277
# l2_pair to class 2 std: 1.1318
# l2_pair to class 2 min: 1.7210
# l2_pair to class 2 max: 11.7527
# l2_pair to class 3 mean: 3.9665
# l2_pair to class 3 std: 1.1166
# l2_pair to class 3 min: 1.5642
# l2_pair to class 3 max: 11.6044
# l2_pair to class 4 mean: 4.0364
# l2_pair to class 4 std: 1.1675
# l2_pair to class 4 min: 1.8099
# l2_pair to class 4 max: 11.5699
# l2_pair to class 5 mean: 3.6891
# l2_pair to class 5 std: 0.9621
# l2_pair to class 5 min: 1.9551
# l2_pair to class 5 max: 11.2461
# l2_pair to class 6 mean: 3.7785
# l2_pair to class 6 std: 1.0940
# l2_pair to class 6 min: 1.9689
# l2_pair to class 6 max: 11.2280
# Class 1 Details:
# l2_pair to class 0 mean: 3.9749
# l2_pair to class 0 std: 1.1681
# l2_pair to class 0 min: 1.8149
# l2_pair to class 0 max: 11.7459
# l2_pair to class 1 mean: 3.8037
# l2_pair to class 1 std: 1.2351
# l2_pair to class 1 min: 0.0000
# l2_pair to class 1 max: 11.5049
# l2_pair to class 2 mean: 4.0304
# l2_pair to class 2 std: 1.1912
# l2_pair to class 2 min: 1.8958
# l2_pair to class 2 max: 11.5713
# l2_pair to class 3 mean: 3.9133
# l2_pair to class 3 std: 1.1939
# l2_pair to class 3 min: 1.5637
# l2_pair to class 3 max: 11.5916
# l2_pair to class 4 mean: 4.0301
# l2_pair to class 4 std: 1.2274
# l2_pair to class 4 min: 1.6816
# l2_pair to class 4 max: 11.3151
# l2_pair to class 5 mean: 3.7393
# l2_pair to class 5 std: 1.0052
# l2_pair to class 5 min: 1.8793
# l2_pair to class 5 max: 10.8830
# l2_pair to class 6 mean: 3.8638
# l2_pair to class 6 std: 1.1482
# l2_pair to class 6 min: 1.9018
# l2_pair to class 6 max: 11.0665
# Class 2 Details:
# l2_pair to class 0 mean: 3.9277
# l2_pair to class 0 std: 1.1318
# l2_pair to class 0 min: 1.7210
# l2_pair to class 0 max: 11.7527
# l2_pair to class 1 mean: 4.0304
# l2_pair to class 1 std: 1.1912
# l2_pair to class 1 min: 1.8958
# l2_pair to class 1 max: 11.5713
# l2_pair to class 2 mean: 3.8827
# l2_pair to class 2 std: 1.1930
# l2_pair to class 2 min: 0.0000
# l2_pair to class 2 max: 10.8111
# l2_pair to class 3 mean: 4.0374
# l2_pair to class 3 std: 1.1379
# l2_pair to class 3 min: 1.9863
# l2_pair to class 3 max: 11.6437
# l2_pair to class 4 mean: 4.0741
# l2_pair to class 4 std: 1.1960
# l2_pair to class 4 min: 1.7888
# l2_pair to class 4 max: 11.4454
# l2_pair to class 5 mean: 3.8083
# l2_pair to class 5 std: 0.9845
# l2_pair to class 5 min: 1.9904
# l2_pair to class 5 max: 10.1633
# l2_pair to class 6 mean: 3.8727
# l2_pair to class 6 std: 1.1261
# l2_pair to class 6 min: 1.9482
# l2_pair to class 6 max: 10.8251
# Class 3 Details:
# l2_pair to class 0 mean: 3.9665
# l2_pair to class 0 std: 1.1166
# l2_pair to class 0 min: 1.5642
# l2_pair to class 0 max: 11.6044
# l2_pair to class 1 mean: 3.9133
# l2_pair to class 1 std: 1.1939
# l2_pair to class 1 min: 1.5637
# l2_pair to class 1 max: 11.5916
# l2_pair to class 2 mean: 4.0374
# l2_pair to class 2 std: 1.1379
# l2_pair to class 2 min: 1.9863
# l2_pair to class 2 max: 11.6437
# l2_pair to class 3 mean: 3.8506
# l2_pair to class 3 std: 1.2065
# l2_pair to class 3 min: 0.0000
# l2_pair to class 3 max: 11.4706
# l2_pair to class 4 mean: 4.0339
# l2_pair to class 4 std: 1.2016
# l2_pair to class 4 min: 1.6273
# l2_pair to class 4 max: 11.3852
# l2_pair to class 5 mean: 3.7968
# l2_pair to class 5 std: 0.9690
# l2_pair to class 5 min: 1.9255
# l2_pair to class 5 max: 11.0396
# l2_pair to class 6 mean: 3.8999
# l2_pair to class 6 std: 1.1090
# l2_pair to class 6 min: 1.2625
# l2_pair to class 6 max: 11.2104
# Class 4 Details:
# l2_pair to class 0 mean: 4.0364
# l2_pair to class 0 std: 1.1675
# l2_pair to class 0 min: 1.8099
# l2_pair to class 0 max: 11.5699
# l2_pair to class 1 mean: 4.0301
# l2_pair to class 1 std: 1.2274
# l2_pair to class 1 min: 1.6816
# l2_pair to class 1 max: 11.3151
# l2_pair to class 2 mean: 4.0741
# l2_pair to class 2 std: 1.1960
# l2_pair to class 2 min: 1.7888
# l2_pair to class 2 max: 11.4454
# l2_pair to class 3 mean: 4.0339
# l2_pair to class 3 std: 1.2016
# l2_pair to class 3 min: 1.6273
# l2_pair to class 3 max: 11.3852
# l2_pair to class 4 mean: 4.0417
# l2_pair to class 4 std: 1.2738
# l2_pair to class 4 min: 0.0000
# l2_pair to class 4 max: 11.1465
# l2_pair to class 5 mean: 3.8684
# l2_pair to class 5 std: 1.0256
# l2_pair to class 5 min: 1.8951
# l2_pair to class 5 max: 10.8198
# l2_pair to class 6 mean: 3.9392
# l2_pair to class 6 std: 1.1699
# l2_pair to class 6 min: 1.6956
# l2_pair to class 6 max: 10.9595
# Class 5 Details:
# l2_pair to class 0 mean: 3.6891
# l2_pair to class 0 std: 0.9621
# l2_pair to class 0 min: 1.9551
# l2_pair to class 0 max: 11.2461
# l2_pair to class 1 mean: 3.7393
# l2_pair to class 1 std: 1.0052
# l2_pair to class 1 min: 1.8793
# l2_pair to class 1 max: 10.8830
# l2_pair to class 2 mean: 3.8083
# l2_pair to class 2 std: 0.9845
# l2_pair to class 2 min: 1.9904
# l2_pair to class 2 max: 10.1633
# l2_pair to class 3 mean: 3.7968
# l2_pair to class 3 std: 0.9690
# l2_pair to class 3 min: 1.9255
# l2_pair to class 3 max: 11.0396
# l2_pair to class 4 mean: 3.8684
# l2_pair to class 4 std: 1.0256
# l2_pair to class 4 min: 1.8951
# l2_pair to class 4 max: 10.8198
# l2_pair to class 5 mean: 3.4545
# l2_pair to class 5 std: 0.7893
# l2_pair to class 5 min: 0.0000
# l2_pair to class 5 max: 8.0602
# l2_pair to class 6 mean: 3.6719
# l2_pair to class 6 std: 0.9031
# l2_pair to class 6 min: 1.8935
# l2_pair to class 6 max: 10.2262
# Class 6 Details:
# l2_pair to class 0 mean: 3.7785
# l2_pair to class 0 std: 1.0940
# l2_pair to class 0 min: 1.9689
# l2_pair to class 0 max: 11.2280
# l2_pair to class 1 mean: 3.8638
# l2_pair to class 1 std: 1.1482
# l2_pair to class 1 min: 1.9018
# l2_pair to class 1 max: 11.0665
# l2_pair to class 2 mean: 3.8727
# l2_pair to class 2 std: 1.1261
# l2_pair to class 2 min: 1.9482
# l2_pair to class 2 max: 10.8251
# l2_pair to class 3 mean: 3.8999
# l2_pair to class 3 std: 1.1090
# l2_pair to class 3 min: 1.2625
# l2_pair to class 3 max: 11.2104
# l2_pair to class 4 mean: 3.9392
# l2_pair to class 4 std: 1.1699
# l2_pair to class 4 min: 1.6956
# l2_pair to class 4 max: 10.9595
# l2_pair to class 5 mean: 3.6719
# l2_pair to class 5 std: 0.9031
# l2_pair to class 5 min: 1.8935
# l2_pair to class 5 max: 10.2262
# l2_pair to class 6 mean: 3.6173
# l2_pair to class 6 std: 1.1198
# l2_pair to class 6 min: 0.0000
# l2_pair to class 6 max: 10.3639
# linf_pair mean: 0.7590
# linf_pair std: 0.5387
# linf_pair min: 0.0000
# linf_pair max: 4.1928
# Class 0 Details:
# linf_pair to class 0 mean: 0.6686
# linf_pair to class 0 std: 0.5102
# linf_pair to class 0 min: 0.0000
# linf_pair to class 0 max: 3.9798
# linf_pair to class 1 mean: 0.7770
# linf_pair to class 1 std: 0.5695
# linf_pair to class 1 min: 0.2059
# linf_pair to class 1 max: 3.9907
# linf_pair to class 2 mean: 0.6965
# linf_pair to class 2 std: 0.4963
# linf_pair to class 2 min: 0.2096
# linf_pair to class 2 max: 4.1819
# linf_pair to class 3 mean: 0.7126
# linf_pair to class 3 std: 0.4773
# linf_pair to class 3 min: 0.2055
# linf_pair to class 3 max: 3.8558
# linf_pair to class 4 mean: 0.7561
# linf_pair to class 4 std: 0.5516
# linf_pair to class 4 min: 0.2005
# linf_pair to class 4 max: 4.1163
# linf_pair to class 5 mean: 0.6707
# linf_pair to class 5 std: 0.4877
# linf_pair to class 5 min: 0.2210
# linf_pair to class 5 max: 4.0235
# linf_pair to class 6 mean: 0.7076
# linf_pair to class 6 std: 0.5024
# linf_pair to class 6 min: 0.2236
# linf_pair to class 6 max: 3.8174
# Class 1 Details:
# linf_pair to class 0 mean: 0.7770
# linf_pair to class 0 std: 0.5695
# linf_pair to class 0 min: 0.2059
# linf_pair to class 0 max: 3.9907
# linf_pair to class 1 mean: 0.8215
# linf_pair to class 1 std: 0.6038
# linf_pair to class 1 min: 0.0000
# linf_pair to class 1 max: 3.8961
# linf_pair to class 2 mean: 0.8014
# linf_pair to class 2 std: 0.5754
# linf_pair to class 2 min: 0.2154
# linf_pair to class 2 max: 4.1928
# linf_pair to class 3 mean: 0.7813
# linf_pair to class 3 std: 0.5403
# linf_pair to class 3 min: 0.1893
# linf_pair to class 3 max: 3.8431
# linf_pair to class 4 mean: 0.8266
# linf_pair to class 4 std: 0.5957
# linf_pair to class 4 min: 0.2025
# linf_pair to class 4 max: 4.1272
# linf_pair to class 5 mean: 0.7533
# linf_pair to class 5 std: 0.5522
# linf_pair to class 5 min: 0.2086
# linf_pair to class 5 max: 4.0344
# linf_pair to class 6 mean: 0.7938
# linf_pair to class 6 std: 0.5638
# linf_pair to class 6 min: 0.2083
# linf_pair to class 6 max: 3.7929
# Class 2 Details:
# linf_pair to class 0 mean: 0.6965
# linf_pair to class 0 std: 0.4963
# linf_pair to class 0 min: 0.2096
# linf_pair to class 0 max: 4.1819
# linf_pair to class 1 mean: 0.8014
# linf_pair to class 1 std: 0.5754
# linf_pair to class 1 min: 0.2154
# linf_pair to class 1 max: 4.1928
# linf_pair to class 2 mean: 0.6975
# linf_pair to class 2 std: 0.4928
# linf_pair to class 2 min: 0.0000
# linf_pair to class 2 max: 4.1722
# linf_pair to class 3 mean: 0.7345
# linf_pair to class 3 std: 0.4744
# linf_pair to class 3 min: 0.2196
# linf_pair to class 3 max: 4.0580
# linf_pair to class 4 mean: 0.7724
# linf_pair to class 4 std: 0.5554
# linf_pair to class 4 min: 0.2072
# linf_pair to class 4 max: 4.1310
# linf_pair to class 5 mean: 0.6913
# linf_pair to class 5 std: 0.4823
# linf_pair to class 5 min: 0.2265
# linf_pair to class 5 max: 4.0138
# linf_pair to class 6 mean: 0.7250
# linf_pair to class 6 std: 0.4995
# linf_pair to class 6 min: 0.2022
# linf_pair to class 6 max: 4.0195
# Class 3 Details:
# linf_pair to class 0 mean: 0.7126
# linf_pair to class 0 std: 0.4773
# linf_pair to class 0 min: 0.2055
# linf_pair to class 0 max: 3.8558
# linf_pair to class 1 mean: 0.7813
# linf_pair to class 1 std: 0.5403
# linf_pair to class 1 min: 0.1893
# linf_pair to class 1 max: 3.8431
# linf_pair to class 2 mean: 0.7345
# linf_pair to class 2 std: 0.4744
# linf_pair to class 2 min: 0.2196
# linf_pair to class 2 max: 4.0580
# linf_pair to class 3 mean: 0.7214
# linf_pair to class 3 std: 0.4574
# linf_pair to class 3 min: 0.0000
# linf_pair to class 3 max: 3.7082
# linf_pair to class 4 mean: 0.7723
# linf_pair to class 4 std: 0.5247
# linf_pair to class 4 min: 0.1955
# linf_pair to class 4 max: 3.9923
# linf_pair to class 5 mean: 0.6972
# linf_pair to class 5 std: 0.4595
# linf_pair to class 5 min: 0.2150
# linf_pair to class 5 max: 3.8996
# linf_pair to class 6 mean: 0.7349
# linf_pair to class 6 std: 0.4754
# linf_pair to class 6 min: 0.1449
# linf_pair to class 6 max: 3.6698
# Class 4 Details:
# linf_pair to class 0 mean: 0.7561
# linf_pair to class 0 std: 0.5516
# linf_pair to class 0 min: 0.2005
# linf_pair to class 0 max: 4.1163
# linf_pair to class 1 mean: 0.8266
# linf_pair to class 1 std: 0.5957
# linf_pair to class 1 min: 0.2025
# linf_pair to class 1 max: 4.1272
# linf_pair to class 2 mean: 0.7724
# linf_pair to class 2 std: 0.5554
# linf_pair to class 2 min: 0.2072
# linf_pair to class 2 max: 4.1310
# linf_pair to class 3 mean: 0.7723
# linf_pair to class 3 std: 0.5247
# linf_pair to class 3 min: 0.1955
# linf_pair to class 3 max: 3.9923
# linf_pair to class 4 mean: 0.8095
# linf_pair to class 4 std: 0.5913
# linf_pair to class 4 min: 0.0000
# linf_pair to class 4 max: 4.0653
# linf_pair to class 5 mean: 0.7400
# linf_pair to class 5 std: 0.5347
# linf_pair to class 5 min: 0.2080
# linf_pair to class 5 max: 3.9726
# linf_pair to class 6 mean: 0.7751
# linf_pair to class 6 std: 0.5499
# linf_pair to class 6 min: 0.1964
# linf_pair to class 6 max: 3.9539
# Class 5 Details:
# linf_pair to class 0 mean: 0.6707
# linf_pair to class 0 std: 0.4877
# linf_pair to class 0 min: 0.2210
# linf_pair to class 0 max: 4.0235
# linf_pair to class 1 mean: 0.7533
# linf_pair to class 1 std: 0.5522
# linf_pair to class 1 min: 0.2086
# linf_pair to class 1 max: 4.0344
# linf_pair to class 2 mean: 0.6913
# linf_pair to class 2 std: 0.4823
# linf_pair to class 2 min: 0.2265
# linf_pair to class 2 max: 4.0138
# linf_pair to class 3 mean: 0.6972
# linf_pair to class 3 std: 0.4595
# linf_pair to class 3 min: 0.2150
# linf_pair to class 3 max: 3.8996
# linf_pair to class 4 mean: 0.7400
# linf_pair to class 4 std: 0.5347
# linf_pair to class 4 min: 0.2080
# linf_pair to class 4 max: 3.9726
# linf_pair to class 5 mean: 0.6494
# linf_pair to class 5 std: 0.4747
# linf_pair to class 5 min: 0.0000
# linf_pair to class 5 max: 3.7062
# linf_pair to class 6 mean: 0.6976
# linf_pair to class 6 std: 0.4842
# linf_pair to class 6 min: 0.2154
# linf_pair to class 6 max: 3.8611
# Class 6 Details:
# linf_pair to class 0 mean: 0.7076
# linf_pair to class 0 std: 0.5024
# linf_pair to class 0 min: 0.2236
# linf_pair to class 0 max: 3.8174
# linf_pair to class 1 mean: 0.7938
# linf_pair to class 1 std: 0.5638
# linf_pair to class 1 min: 0.2083
# linf_pair to class 1 max: 3.7929
# linf_pair to class 2 mean: 0.7250
# linf_pair to class 2 std: 0.4995
# linf_pair to class 2 min: 0.2022
# linf_pair to class 2 max: 4.0195
# linf_pair to class 3 mean: 0.7349
# linf_pair to class 3 std: 0.4754
# linf_pair to class 3 min: 0.1449
# linf_pair to class 3 max: 3.6698
# linf_pair to class 4 mean: 0.7751
# linf_pair to class 4 std: 0.5499
# linf_pair to class 4 min: 0.1964
# linf_pair to class 4 max: 3.9539
# linf_pair to class 5 mean: 0.6976
# linf_pair to class 5 std: 0.4842
# linf_pair to class 5 min: 0.2154
# linf_pair to class 5 max: 3.8611
# linf_pair to class 6 mean: 0.7246
# linf_pair to class 6 std: 0.5075
# linf_pair to class 6 min: 0.0000
# linf_pair to class 6 max: 3.6196
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[14], line 20
#      18 model_params["bias"] = False
#      19 data_params["learning_setting"] = "transductive"
# ---> 20 run(data_params, model_params, certificate_params, verbosity_params, other_params, seed)
#
# File /ceph/ssd/staff/gosl/.conda/envs/py311_ntk/lib/python3.11/site-packages/sacred/config/captured_function.py:42, in captured_function(wrapped, instance, args, kwargs)
#      40 # =================== run actual function =================================
#      41 with ConfigError.track(wrapped.config, wrapped.prefix):
# ---> 42     result = wrapped(*args, **kwargs)
#      43 # =========================================================================
#      44 if wrapped.logger is not None:
#
# File /ceph/ssd/staff/gosl/src/ntk-robust/exp_feature_norms.py:275, in run(data_params, model_params, certificate_params, verbosity_params, other_params, seed, _run)
#     272         print(f"linf_pair to class {j} min: {linf_pair_thisclass.min():.4f}")
#     273         print(f"linf_pair to class {j} max: {linf_pair_thisclass.max():.4f}")
# --> 275 assert False
#     277 idx_labeled = np.concatenate((idx_trn, idx_val))
#     278 idx_unlabeled = np.concatenate((idx_unlabeled, idx_test))
#
# AssertionError:

# %%
# MIP foucs = 3
#model_params["cache_size"] = 10000
other_params["device"] = "cpu"
other_params["debug"] = False
certificate_params["n_adversarial"] = 270
certificate_params["delta"] = 0.01
certificate_params["delta_absolute"] = False
certificate_params["method"] = "XXT"
certificate_params["perturbation_model"] = "l2"
certificate_params["attack_nodes"] = "test"
#certificate_params["MIPGap"] = 0
other_params["path_gurobi_license"] = "/ceph/ssd/staff/gosl/app/gurobi.lic"
verbosity_params["debug_lvl"] = "info"
model_params["regularizer"] = 0.005
model_params["solver"] = "qplayer_one_vs_all"
model_params["alpha_tol"] = 1e-4
model_params["bias"] = False
data_params["learning_setting"] = "transductive"
run(data_params, model_params, certificate_params, verbosity_params, other_params, seed)
# Out:
# 2024-04-25 21:38:21 (INFO): Starting experiment exp_feature_norms with configuration:
# 2024-04-25 21:38:21 (INFO): data_params: {'dataset': 'cora', 'learning_setting': 'transductive', 'specification': {'n_per_class': 10, 'fraction_test': 0.01, 'data_dir': './data', 'make_undirected': True, 'binary_attr': False, 'balance_test': True}}
# 2024-04-25 21:38:21 (INFO): model_params: {'label': 'GCN', 'model': 'GCN', 'normalization': 'row_normalization', 'depth': 1, 'regularizer': 0.005, 'pred_method': 'svm', 'activation': 'relu', 'solver': 'qplayer_one_vs_all', 'alpha_tol': 0.0001, 'bias': False}
# 2024-04-25 21:38:21 (INFO): certification_params: {'n_adversarial': 270, 'perturbation_model': 'l2', 'delta': 0.01, 'delta_absolute': False, 'method': 'XXT', 'attack_nodes': 'test'}
# 2024-04-25 21:38:21 (INFO): verbosity_params: {'debug_lvl': 'info'}
# 2024-04-25 21:38:21 (INFO): other_params: {'device': 'cpu', 'dtype': torch.float64, 'allow_tf32': False, 'debug': False, 'path_gurobi_license': '/ceph/ssd/staff/gosl/app/gurobi.lic'}
# 2024-04-25 21:38:21 (INFO): seed: 0
# 2024-04-25 21:38:21 (INFO): number of samples
#  - labeled: 70
#  - val: 70
#  - test: 273
#  - unlabeled: 2295
# l2 mean: 4.1836
# l2 std: 0.8197
# l2 min: 1.0000
# l2 max: 5.4772
# linf mean: 1.0000
# linf std: 0.0000
# linf min: 1.0000
# linf max: 1.0000
# l2_pair mean: 5.8100
# l2_pair std: 0.7105
# l2_pair min: 0.0000
# l2_pair max: 7.5498
# Class 0 Details:
# l2_pair to class 0 mean: 5.7482
# l2_pair to class 0 std: 0.7001
# l2_pair to class 0 min: 0.0000
# l2_pair to class 0 max: 7.2111
# l2_pair to class 1 mean: 5.8606
# l2_pair to class 1 std: 0.6229
# l2_pair to class 1 min: 1.0000
# l2_pair to class 1 max: 7.1414
# l2_pair to class 2 mean: 5.7905
# l2_pair to class 2 std: 0.7134
# l2_pair to class 2 min: 1.7321
# l2_pair to class 2 max: 7.2801
# l2_pair to class 3 mean: 5.7974
# l2_pair to class 3 std: 0.6758
# l2_pair to class 3 min: 1.4142
# l2_pair to class 3 max: 7.2801
# l2_pair to class 4 mean: 5.8567
# l2_pair to class 4 std: 0.6819
# l2_pair to class 4 min: 1.7321
# l2_pair to class 4 max: 7.4162
# l2_pair to class 5 mean: 5.8580
# l2_pair to class 5 std: 0.6412
# l2_pair to class 5 min: 1.7321
# l2_pair to class 5 max: 7.2801
# l2_pair to class 6 mean: 5.8623
# l2_pair to class 6 std: 0.6080
# l2_pair to class 6 min: 1.4142
# l2_pair to class 6 max: 7.2801
# Class 1 Details:
# l2_pair to class 0 mean: 5.8606
# l2_pair to class 0 std: 0.6229
# l2_pair to class 0 min: 1.0000
# l2_pair to class 0 max: 7.1414
# l2_pair to class 1 mean: 5.7811
# l2_pair to class 1 std: 0.7292
# l2_pair to class 1 min: 0.0000
# l2_pair to class 1 max: 7.1414
# l2_pair to class 2 mean: 5.8371
# l2_pair to class 2 std: 0.6980
# l2_pair to class 2 min: 2.0000
# l2_pair to class 2 max: 7.2111
# l2_pair to class 3 mean: 5.8473
# l2_pair to class 3 std: 0.6660
# l2_pair to class 3 min: 1.4142
# l2_pair to class 3 max: 7.2801
# l2_pair to class 4 mean: 5.9290
# l2_pair to class 4 std: 0.6674
# l2_pair to class 4 min: 1.7321
# l2_pair to class 4 max: 7.4833
# l2_pair to class 5 mean: 5.9027
# l2_pair to class 5 std: 0.6294
# l2_pair to class 5 min: 1.7321
# l2_pair to class 5 max: 7.2801
# l2_pair to class 6 mean: 5.9285
# l2_pair to class 6 std: 0.6009
# l2_pair to class 6 min: 1.4142
# l2_pair to class 6 max: 7.2111
# Class 2 Details:
# l2_pair to class 0 mean: 5.7905
# l2_pair to class 0 std: 0.7134
# l2_pair to class 0 min: 1.7321
# l2_pair to class 0 max: 7.2801
# l2_pair to class 1 mean: 5.8371
# l2_pair to class 1 std: 0.6980
# l2_pair to class 1 min: 2.0000
# l2_pair to class 1 max: 7.2111
# l2_pair to class 2 mean: 5.6082
# l2_pair to class 2 std: 0.8364
# l2_pair to class 2 min: 0.0000
# l2_pair to class 2 max: 7.2801
# l2_pair to class 3 mean: 5.7480
# l2_pair to class 3 std: 0.7631
# l2_pair to class 3 min: 1.4142
# l2_pair to class 3 max: 7.3485
# l2_pair to class 4 mean: 5.8176
# l2_pair to class 4 std: 0.7643
# l2_pair to class 4 min: 1.7321
# l2_pair to class 4 max: 7.5498
# l2_pair to class 5 mean: 5.8245
# l2_pair to class 5 std: 0.7182
# l2_pair to class 5 min: 2.0000
# l2_pair to class 5 max: 7.2111
# l2_pair to class 6 mean: 5.8449
# l2_pair to class 6 std: 0.6818
# l2_pair to class 6 min: 2.0000
# l2_pair to class 6 max: 7.3485
# Class 3 Details:
# l2_pair to class 0 mean: 5.7974
# l2_pair to class 0 std: 0.6758
# l2_pair to class 0 min: 1.4142
# l2_pair to class 0 max: 7.2801
# l2_pair to class 1 mean: 5.8473
# l2_pair to class 1 std: 0.6660
# l2_pair to class 1 min: 1.4142
# l2_pair to class 1 max: 7.2801
# l2_pair to class 2 mean: 5.7480
# l2_pair to class 2 std: 0.7631
# l2_pair to class 2 min: 1.4142
# l2_pair to class 2 max: 7.3485
# l2_pair to class 3 mean: 5.6896
# l2_pair to class 3 std: 0.7491
# l2_pair to class 3 min: 0.0000
# l2_pair to class 3 max: 7.2111
# l2_pair to class 4 mean: 5.8027
# l2_pair to class 4 std: 0.7298
# l2_pair to class 4 min: 1.4142
# l2_pair to class 4 max: 7.5498
# l2_pair to class 5 mean: 5.8354
# l2_pair to class 5 std: 0.6875
# l2_pair to class 5 min: 1.7321
# l2_pair to class 5 max: 7.3485
# l2_pair to class 6 mean: 5.8671
# l2_pair to class 6 std: 0.6507
# l2_pair to class 6 min: 1.4142
# l2_pair to class 6 max: 7.2801
# Class 4 Details:
# l2_pair to class 0 mean: 5.8567
# l2_pair to class 0 std: 0.6819
# l2_pair to class 0 min: 1.7321
# l2_pair to class 0 max: 7.4162
# l2_pair to class 1 mean: 5.9290
# l2_pair to class 1 std: 0.6674
# l2_pair to class 1 min: 1.7321
# l2_pair to class 1 max: 7.4833
# l2_pair to class 2 mean: 5.8176
# l2_pair to class 2 std: 0.7643
# l2_pair to class 2 min: 1.7321
# l2_pair to class 2 max: 7.5498
# l2_pair to class 3 mean: 5.8027
# l2_pair to class 3 std: 0.7298
# l2_pair to class 3 min: 1.4142
# l2_pair to class 3 max: 7.5498
# l2_pair to class 4 mean: 5.7906
# l2_pair to class 4 std: 0.7812
# l2_pair to class 4 min: 0.0000
# l2_pair to class 4 max: 7.5498
# l2_pair to class 5 mean: 5.8951
# l2_pair to class 5 std: 0.6918
# l2_pair to class 5 min: 1.7321
# l2_pair to class 5 max: 7.4162
# l2_pair to class 6 mean: 5.9327
# l2_pair to class 6 std: 0.6568
# l2_pair to class 6 min: 1.7321
# l2_pair to class 6 max: 7.4833
# Class 5 Details:
# l2_pair to class 0 mean: 5.8580
# l2_pair to class 0 std: 0.6412
# l2_pair to class 0 min: 1.7321
# l2_pair to class 0 max: 7.2801
# l2_pair to class 1 mean: 5.9027
# l2_pair to class 1 std: 0.6294
# l2_pair to class 1 min: 1.7321
# l2_pair to class 1 max: 7.2801
# l2_pair to class 2 mean: 5.8245
# l2_pair to class 2 std: 0.7182
# l2_pair to class 2 min: 2.0000
# l2_pair to class 2 max: 7.2111
# l2_pair to class 3 mean: 5.8354
# l2_pair to class 3 std: 0.6875
# l2_pair to class 3 min: 1.7321
# l2_pair to class 3 max: 7.3485
# l2_pair to class 4 mean: 5.8951
# l2_pair to class 4 std: 0.6918
# l2_pair to class 4 min: 1.7321
# l2_pair to class 4 max: 7.4162
# l2_pair to class 5 mean: 5.7831
# l2_pair to class 5 std: 0.7310
# l2_pair to class 5 min: 0.0000
# l2_pair to class 5 max: 7.2111
# l2_pair to class 6 mean: 5.9026
# l2_pair to class 6 std: 0.6157
# l2_pair to class 6 min: 1.7321
# l2_pair to class 6 max: 7.3485
# Class 6 Details:
# l2_pair to class 0 mean: 5.8623
# l2_pair to class 0 std: 0.6080
# l2_pair to class 0 min: 1.4142
# l2_pair to class 0 max: 7.2801
# l2_pair to class 1 mean: 5.9285
# l2_pair to class 1 std: 0.6009
# l2_pair to class 1 min: 1.4142
# l2_pair to class 1 max: 7.2111
# l2_pair to class 2 mean: 5.8449
# l2_pair to class 2 std: 0.6818
# l2_pair to class 2 min: 2.0000
# l2_pair to class 2 max: 7.3485
# l2_pair to class 3 mean: 5.8671
# l2_pair to class 3 std: 0.6507
# l2_pair to class 3 min: 1.4142
# l2_pair to class 3 max: 7.2801
# l2_pair to class 4 mean: 5.9327
# l2_pair to class 4 std: 0.6568
# l2_pair to class 4 min: 1.7321
# l2_pair to class 4 max: 7.4833
# l2_pair to class 5 mean: 5.9026
# l2_pair to class 5 std: 0.6157
# l2_pair to class 5 min: 1.7321
# l2_pair to class 5 max: 7.3485
# l2_pair to class 6 mean: 5.8225
# l2_pair to class 6 std: 0.7249
# l2_pair to class 6 min: 0.0000
# l2_pair to class 6 max: 7.2111
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[13], line 19
#      17 model_params["bias"] = False
#      18 data_params["learning_setting"] = "transductive"
# ---> 19 run(data_params, model_params, certificate_params, verbosity_params, other_params, seed)
#
# File /ceph/ssd/staff/gosl/.conda/envs/py311_ntk/lib/python3.11/site-packages/sacred/config/captured_function.py:42, in captured_function(wrapped, instance, args, kwargs)
#      40 # =================== run actual function =================================
#      41 with ConfigError.track(wrapped.config, wrapped.prefix):
# ---> 42     result = wrapped(*args, **kwargs)
#      43 # =========================================================================
#      44 if wrapped.logger is not None:
#
# File /ceph/ssd/staff/gosl/src/ntk-robust/exp_feature_norms.py:258, in run(data_params, model_params, certificate_params, verbosity_params, other_params, seed, _run)
#     255         print(f"l2_pair to class {j} min: {l2_pair_thisclass.min():.4f}")
#     256         print(f"l2_pair to class {j} max: {l2_pair_thisclass.max():.4f}")
# --> 258 assert False
#     260 idx_labeled = np.concatenate((idx_trn, idx_val))
#     261 idx_unlabeled = np.concatenate((idx_unlabeled, idx_test))
#
# AssertionError:
