# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import numpy as np
from exp_ntk_attack import run

# %%
seed = 4

data_params = dict(
    dataset = "csbm",
    learning_setting = "transductive", # or "transdructive"
    specification = dict(
        classes = 2,
        n_trn_labeled = 40, 
        n_trn_unlabeled = 0,
        n_val = 40,
        n_test = 120,
        sigma = 1,
        avg_within_class_degree = 1.58 * 2,
        avg_between_class_degree = 0.37 * 2,
        K = 1.5,
        seed = 4 # used to generate the dataset & data split
    )
)

model_params = dict(
    label = "GCN",
    model = "GCN",
    normalization = "row_normalization",
    depth = 4,
    #regularizer = 1e-8
    regularizer = 1,
    pred_method = "svm",
    activation = "relu"
)

attack_params = dict(
    attack = "apgd",
    n_adversarial = 1, # number adversarial nodes
    perturbation_model = "linf",
    delta = 0.01 # l0: local budget = delta * feature_dim
)

verbosity_params = dict(
    debug_lvl = "warning"
)  

other_params = dict(
    device = "cpu",
    dtype = torch.float64,
    allow_tf32 = False,
    store_attack_curve = True, # If the "learning curve" of the attack should be saved to mongodb
    store_first_iter = 100, # Always save first 100 iterations of attack a particular node
    store_every_X_iter = 10, # Afterwards, save every 10th iteration of attack
)

# %%
# %reload_ext autoreload
#model_params["cache_size"] = 10000
other_params["device"] = "0"
other_params["debug"] = False
attack_params["n_adversarial"] = 12
attack_params["delta"] = 0.5
attack_params["max_iter"] = 20
attack_params["eta"] = 100
attack_params["n_restarts"] = 0
attack_params["attack"] = "apgd"
attack_params["delta_absolute"] = False
attack_params["perturbation_model"] = "linf"
attack_params["attack_nodes"] = "test"
verbosity_params["debug_lvl"] = "info"
model_params["regularizer"] = 0.001
model_params["solver"] = "qplayer"
model_params["alpha_tol"] = 1e-4
model_params["bias"] = False
data_params["learning_setting"] = "transductive"
other_params["max_logging_iters"] = 10
other_params["store_attack_curve"] = False
run(data_params, model_params, attack_params, verbosity_params, other_params, seed)
# Out:
# 2024-04-21 17:44:28 (INFO): Starting experiment exp_ntk_attack with configuration:
# 2024-04-21 17:44:28 (INFO): data_params: {'dataset': 'csbm', 'learning_setting': 'transductive', 'specification': {'classes': 2, 'n_trn_labeled': 40, 'n_trn_unlabeled': 0, 'n_val': 40, 'n_test': 120, 'sigma': 1, 'avg_within_class_degree': 3.16, 'avg_between_class_degree': 0.74, 'K': 1.5, 'seed': 4}}
# 2024-04-21 17:44:28 (INFO): model_params: {'label': 'GCN', 'model': 'GCN', 'normalization': 'row_normalization', 'depth': 4, 'regularizer': 0.001, 'pred_method': 'svm', 'activation': 'relu', 'solver': 'qplayer', 'alpha_tol': 0.0001, 'bias': False}
# 2024-04-21 17:44:28 (INFO): certification_params: {'attack': 'apgd', 'n_adversarial': 12, 'perturbation_model': 'linf', 'delta': 0.5, 'max_iter': 20, 'eta': 100, 'n_restarts': 0, 'delta_absolute': False, 'attack_nodes': 'test'}
# 2024-04-21 17:44:28 (INFO): verbosity_params: {'debug_lvl': 'info'}
# 2024-04-21 17:44:28 (INFO): other_params: {'device': '0', 'dtype': torch.float64, 'allow_tf32': False, 'store_attack_curve': False, 'store_first_iter': 100, 'store_every_X_iter': 10, 'debug': False, 'max_logging_iters': 10}
# 2024-04-21 17:44:28 (INFO): seed: 4
# 2024-04-21 17:44:28 (INFO): Currently on gpu device cuda:0
# 2024-04-21 17:44:28 (INFO): CSBM(p=0.03176, q=0.00744)
# 2024-04-21 17:44:28 (INFO): Delta: 0.2835
# CSBM mu:
# [0.28347334 0.28347334 0.28347334 0.28347334 0.28347334 0.28347334
#  0.28347334]
# W: [0, 5, 9, 12, 15, 16, 18, 19, 20]
# 2024-04-21 17:44:28 (INFO): k 5, W: 5, y_pred_worst: 0.0012860560816584897, eta: 28.349999999999998
# 2024-04-21 17:44:28 (INFO): k 9, W: 9, y_pred_worst: 0.0006305998108359842, eta: 28.349999999999998
# 2024-04-21 17:44:28 (INFO): k 12, W: 12, y_pred_worst: 0.00014493820955965853, eta: 28.349999999999998
# 2024-04-21 17:44:28 (INFO): k 15, W: 15, y_pred_worst: -0.0002570572422216817, eta: 28.349999999999998
# 2024-04-21 17:44:28 (INFO): k 16, W: 16, y_pred_worst: -0.0003735969023180574, eta: 28.349999999999998
# 2024-04-21 17:44:28 (INFO): k 18, W: 18, y_pred_worst: -0.0005955585978785795, eta: 28.349999999999998
# 2024-04-21 17:44:28 (INFO): y_pert: -0.00069270; y_clean: 0.00228679; Pert: True; Correct Clean: False; Total Pert: 1 Total Clean: 0.0; Total: 1
# 2024-04-21 17:44:29 (INFO): k 5, W: 5, y_pred_worst: -0.0034446473715709844, eta: 28.349999999999998
# 2024-04-21 17:44:29 (INFO): k 9, W: 9, y_pred_worst: -0.002619927713296378, eta: 28.349999999999998
# 2024-04-21 17:44:29 (INFO): k 12, W: 12, y_pred_worst: -0.002381735538251103, eta: 28.349999999999998
# 2024-04-21 17:44:29 (INFO): k 15, W: 15, y_pred_worst: -0.0022175757895415357, eta: 28.349999999999998
# 2024-04-21 17:44:29 (INFO): k 16, W: 16, y_pred_worst: -0.002163215099905689, eta: 14.174999999999999
# 2024-04-21 17:44:29 (INFO): k 18, W: 18, y_pred_worst: -0.002100557298584542, eta: 14.174999999999999
# 2024-04-21 17:44:29 (INFO): y_pert: -0.00207311; y_clean: -0.00483850; Pert: False; Correct Clean: True; Total Pert: 1 Total Clean: 1.0; Total: 2
# 2024-04-21 17:44:29 (INFO): k 5, W: 5, y_pred_worst: 0.005112347282240826, eta: 28.349999999999998
# 2024-04-21 17:44:29 (INFO): k 9, W: 9, y_pred_worst: 0.004853421408901368, eta: 28.349999999999998
# 2024-04-21 17:44:29 (INFO): k 12, W: 12, y_pred_worst: 0.004659051601814349, eta: 28.349999999999998
# 2024-04-21 17:44:29 (INFO): k 15, W: 15, y_pred_worst: 0.00446453450751203, eta: 28.349999999999998
# 2024-04-21 17:44:29 (INFO): k 16, W: 16, y_pred_worst: 0.004399663283148662, eta: 14.174999999999999
# 2024-04-21 17:44:29 (INFO): k 18, W: 18, y_pred_worst: 0.0043246349402019605, eta: 14.174999999999999
# 2024-04-21 17:44:29 (INFO): y_pert: 0.00429168; y_clean: 0.00550031; Pert: False; Correct Clean: False; Total Pert: 1 Total Clean: 1.0; Total: 3
# 2024-04-21 17:44:30 (INFO): k 5, W: 5, y_pred_worst: -0.006860104418297944, eta: 28.349999999999998
# 2024-04-21 17:44:30 (INFO): k 9, W: 9, y_pred_worst: -0.006538321759615032, eta: 28.349999999999998
# 2024-04-21 17:44:30 (INFO): k 12, W: 12, y_pred_worst: -0.00629943300562481, eta: 28.349999999999998
# 2024-04-21 17:44:30 (INFO): k 15, W: 15, y_pred_worst: -0.006062990791743, eta: 28.349999999999998
# 2024-04-21 17:44:30 (INFO): k 16, W: 16, y_pred_worst: -0.005984571660455891, eta: 14.174999999999999
# 2024-04-21 17:44:30 (INFO): k 18, W: 18, y_pred_worst: -0.005908013114677686, eta: 14.174999999999999
# 2024-04-21 17:44:30 (INFO): y_pert: -0.00587759; y_clean: -0.00734969; Pert: False; Correct Clean: True; Total Pert: 1 Total Clean: 2.0; Total: 4
# 2024-04-21 17:44:30 (INFO): k 5, W: 5, y_pred_worst: 0.0022433611669463935, eta: 28.349999999999998
# 2024-04-21 17:44:30 (INFO): k 9, W: 9, y_pred_worst: 0.002014067085414125, eta: 28.349999999999998
# 2024-04-21 17:44:30 (INFO): k 12, W: 12, y_pred_worst: 0.0018409677366555844, eta: 28.349999999999998
# 2024-04-21 17:44:30 (INFO): k 15, W: 15, y_pred_worst: 0.0016671850765142687, eta: 28.349999999999998
# 2024-04-21 17:44:30 (INFO): k 16, W: 16, y_pred_worst: 0.0016090787257931824, eta: 14.174999999999999
# 2024-04-21 17:44:30 (INFO): k 18, W: 18, y_pred_worst: 0.0015417785163179508, eta: 14.174999999999999
# 2024-04-21 17:44:30 (INFO): y_pert: 0.00151218; y_clean: 0.00258442; Pert: False; Correct Clean: False; Total Pert: 1 Total Clean: 2.0; Total: 5
# 2024-04-21 17:44:31 (INFO): k 5, W: 5, y_pred_worst: -0.032711767087110495, eta: 28.349999999999998
# 2024-04-21 17:44:31 (INFO): k 9, W: 9, y_pred_worst: -0.031882413239212704, eta: 28.349999999999998
# 2024-04-21 17:44:31 (INFO): k 12, W: 12, y_pred_worst: -0.031460302097005156, eta: 28.349999999999998
# 2024-04-21 17:44:31 (INFO): k 15, W: 15, y_pred_worst: -0.031122584764811483, eta: 28.349999999999998
# 2024-04-21 17:44:31 (INFO): k 16, W: 16, y_pred_worst: -0.031016307135008234, eta: 28.349999999999998
# 2024-04-21 17:44:31 (INFO): k 18, W: 18, y_pred_worst: -0.03082077094548633, eta: 28.349999999999998
# 2024-04-21 17:44:31 (INFO): y_pert: -0.03073653; y_clean: -0.03449053; Pert: False; Correct Clean: True; Total Pert: 1 Total Clean: 3.0; Total: 6
# 2024-04-21 17:44:31 (INFO): k 5, W: 5, y_pred_worst: -0.01315251245159637, eta: 28.349999999999998
# 2024-04-21 17:44:31 (INFO): k 9, W: 9, y_pred_worst: -0.012887702343074408, eta: 28.349999999999998
# 2024-04-21 17:44:31 (INFO): k 12, W: 12, y_pred_worst: -0.012692056591048256, eta: 28.349999999999998
# 2024-04-21 17:44:31 (INFO): k 15, W: 15, y_pred_worst: -0.01249898084487475, eta: 28.349999999999998
# 2024-04-21 17:44:31 (INFO): k 16, W: 16, y_pred_worst: -0.012435066127441705, eta: 14.174999999999999
# 2024-04-21 17:44:31 (INFO): k 18, W: 18, y_pred_worst: -0.012361709991598881, eta: 14.174999999999999
# 2024-04-21 17:44:32 (INFO): y_pert: -0.01232963; y_clean: -0.01355798; Pert: False; Correct Clean: True; Total Pert: 1 Total Clean: 4.0; Total: 7
# 2024-04-21 17:44:32 (INFO): k 5, W: 5, y_pred_worst: -0.009618867112607957, eta: 28.349999999999998
# 2024-04-21 17:44:32 (INFO): k 9, W: 9, y_pred_worst: -0.009403618532986813, eta: 28.349999999999998
# 2024-04-21 17:44:32 (INFO): k 12, W: 12, y_pred_worst: -0.009244308331217026, eta: 28.349999999999998
# 2024-04-21 17:44:32 (INFO): k 15, W: 15, y_pred_worst: -0.009086820285488203, eta: 28.349999999999998
# 2024-04-21 17:44:32 (INFO): k 16, W: 16, y_pred_worst: -0.009036885166933874, eta: 14.174999999999999
# 2024-04-21 17:44:32 (INFO): k 18, W: 18, y_pred_worst: -0.008988020746430181, eta: 14.174999999999999
# 2024-04-21 17:44:32 (INFO): y_pert: -0.00896663; y_clean: -0.00994784; Pert: False; Correct Clean: True; Total Pert: 1 Total Clean: 5.0; Total: 8
# 2024-04-21 17:44:32 (INFO): k 5, W: 5, y_pred_worst: 0.005759161514995323, eta: 28.349999999999998
# 2024-04-21 17:44:32 (INFO): k 9, W: 9, y_pred_worst: 0.005151177930846877, eta: 28.349999999999998
# 2024-04-21 17:44:32 (INFO): k 12, W: 12, y_pred_worst: 0.004785772585603828, eta: 28.349999999999998
# 2024-04-21 17:44:32 (INFO): k 15, W: 15, y_pred_worst: 0.0045386527172149565, eta: 28.349999999999998
# 2024-04-21 17:44:32 (INFO): k 16, W: 16, y_pred_worst: 0.0044799587758674875, eta: 14.174999999999999
# 2024-04-21 17:44:33 (INFO): k 18, W: 18, y_pred_worst: 0.004417663010247154, eta: 14.174999999999999
# 2024-04-21 17:44:33 (INFO): y_pert: 0.00439029; y_clean: 0.00667990; Pert: False; Correct Clean: False; Total Pert: 1 Total Clean: 5.0; Total: 9
# 2024-04-21 17:44:33 (INFO): k 5, W: 5, y_pred_worst: 0.0136587884619017, eta: 28.349999999999998
# 2024-04-21 17:44:33 (INFO): k 9, W: 9, y_pred_worst: 0.012716146182456492, eta: 28.349999999999998
# 2024-04-21 17:44:33 (INFO): k 12, W: 12, y_pred_worst: 0.012334382148010225, eta: 28.349999999999998
# 2024-04-21 17:44:33 (INFO): k 15, W: 15, y_pred_worst: 0.012050402893653535, eta: 28.349999999999998
# 2024-04-21 17:44:33 (INFO): k 16, W: 16, y_pred_worst: 0.011955814792001395, eta: 14.174999999999999
# 2024-04-21 17:44:33 (INFO): k 18, W: 18, y_pred_worst: 0.011848650770670557, eta: 14.174999999999999
# 2024-04-21 17:44:33 (INFO): y_pert: 0.01180531; y_clean: 0.01528245; Pert: False; Correct Clean: False; Total Pert: 1 Total Clean: 5.0; Total: 10
# 2024-04-21 17:44:33 (INFO): k 5, W: 5, y_pred_worst: -0.0003860062179750802, eta: 28.349999999999998
# 2024-04-21 17:44:33 (INFO): k 9, W: 9, y_pred_worst: 0.00018304775756145322, eta: 28.349999999999998
# 2024-04-21 17:44:33 (INFO): k 12, W: 12, y_pred_worst: 0.0006054522786403949, eta: 28.349999999999998
# 2024-04-21 17:44:33 (INFO): k 15, W: 15, y_pred_worst: 0.0009375533523541257, eta: 28.349999999999998
# 2024-04-21 17:44:33 (INFO): k 16, W: 16, y_pred_worst: 0.0009905082459071343, eta: 14.174999999999999
# 2024-04-21 17:44:34 (INFO): k 18, W: 18, y_pred_worst: 0.0010515780296735146, eta: 14.174999999999999
# 2024-04-21 17:44:34 (INFO): y_pert: 0.00107470; y_clean: -0.00125106; Pert: True; Correct Clean: True; Total Pert: 2 Total Clean: 6.0; Total: 11
# 2024-04-21 17:44:34 (INFO): y_pert: 0.00148624; y_clean: 0.00224961; Pert: False; Correct Clean: False; Total Pert: 2 Total Clean: 6.0; Total: 12
# 2024-04-21 17:44:35 (INFO): y_pert: 0.00175409; y_clean: 0.00327338; Pert: False; Correct Clean: False; Total Pert: 2 Total Clean: 6.0; Total: 13
# 2024-04-21 17:44:35 (INFO): y_pert: -0.00086403; y_clean: 0.00113153; Pert: True; Correct Clean: False; Total Pert: 3 Total Clean: 6.0; Total: 14
# 2024-04-21 17:44:36 (INFO): y_pert: -0.00606803; y_clean: -0.00733960; Pert: False; Correct Clean: True; Total Pert: 3 Total Clean: 7.0; Total: 15
# 2024-04-21 17:44:36 (INFO): y_pert: 0.00472114; y_clean: 0.00708474; Pert: False; Correct Clean: False; Total Pert: 3 Total Clean: 7.0; Total: 16
# 2024-04-21 17:44:37 (INFO): y_pert: -0.00077544; y_clean: -0.00191735; Pert: False; Correct Clean: True; Total Pert: 3 Total Clean: 8.0; Total: 17
# 2024-04-21 17:44:37 (INFO): y_pert: -0.00338763; y_clean: -0.00540239; Pert: False; Correct Clean: True; Total Pert: 3 Total Clean: 9.0; Total: 18
# 2024-04-21 17:44:38 (INFO): y_pert: -0.00918812; y_clean: -0.01357760; Pert: False; Correct Clean: True; Total Pert: 3 Total Clean: 10.0; Total: 19
# 2024-04-21 17:44:38 (INFO): y_pert: -0.01024479; y_clean: -0.01136567; Pert: False; Correct Clean: True; Total Pert: 3 Total Clean: 11.0; Total: 20
# 2024-04-21 17:44:39 (INFO): y_pert: 0.00132066; y_clean: -0.00052617; Pert: True; Correct Clean: True; Total Pert: 4 Total Clean: 12.0; Total: 21
# 2024-04-21 17:44:39 (INFO): y_pert: -0.00240820; y_clean: -0.00371221; Pert: False; Correct Clean: True; Total Pert: 4 Total Clean: 13.0; Total: 22
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 22
#      20 other_params["max_logging_iters"] = 10
#      21 other_params["store_attack_curve"] = False
# ---> 22 run(data_params, model_params, attack_params, verbosity_params, other_params, seed)
#
# File /ceph/ssd/staff/gosl/.conda/envs/py311_ntk/lib/python3.11/site-packages/sacred/config/captured_function.py:42, in captured_function(wrapped, instance, args, kwargs)
#      40 # =================== run actual function =================================
#      41 with ConfigError.track(wrapped.config, wrapped.prefix):
# ---> 42     result = wrapped(*args, **kwargs)
#      43 # =========================================================================
#      44 if wrapped.logger is not None:
#
# File /ceph/ssd/staff/gosl/src/ntk-robust/exp_ntk_attack.py:264, in run(data_params, model_params, attack_params, verbosity_params, other_params, seed, _run)
#     262 if i > other_params["max_logging_iters"]:
#     263     do_logging = False
# --> 264 _, y_pert_l, y_pert = attack.attack(idx_target, do_logging)
#     265 # Statistics
#     266 y_pert_t = torch.tensor(y_pert, dtype=dtype, device=device)
#
# File /ceph/ssd/staff/gosl/src/ntk-robust/src/attacks/apgd.py:210, in APGD.attack(self, idx_target, do_logging)
#     199 def attack(self, idx_target: Integer[torch.Tensor, "1 1"], do_logging=True) \
#     200     -> Tuple[torch.Tensor, List[float], float]:
#     201     """ Attack idx_target.
#     202
#     203     do_logging=True enables occasionally outputting progress of attack.
#    (...)
#     208         - Logits of most successfull attack
#     209     """
# --> 210     X_pert, y_pert_l, sgn, y_pert = self._attack(idx_target, self.X,
#     211                                                  do_logging=do_logging)
#     212     if self.n_restarts > 0:
#     213         y_best = y_pert
#
# File /ceph/ssd/staff/gosl/src/ntk-robust/src/attacks/apgd.py:151, in APGD._attack(self, idx_target, X_start, sgn, do_logging)
#     149 X_pert_prev = torch.clone(X_pert) #x0
#     150 y_pred_l = []
# --> 151 gradient, y_pred = self._gradient(idx_target, X_pert)
#     152 if sgn is None:
#     153     # First prediction assumed to be unperturbed
#     154     sgn = int(y_pred > 0) * (-1) + int(y_pred <= 0)
#
# File /ceph/ssd/staff/gosl/src/ntk-robust/src/attacks/apgd.py:122, in APGD._gradient(self, idx_target, X)
#     120 idx_sort = torch.argsort(self.idx_r)
#     121 X = X_r[idx_sort, :]
# --> 122 y_pred = self._get_logits(idx_target, X)
#     123 y_pred.backward()
#     124 return X_adv.grad, y_pred[0].detach().cpu().item()
#
# File /ceph/ssd/staff/gosl/src/ntk-robust/src/attacks/apgd.py:96, in APGD._get_logits(self, idx_target, X)
#      95 def _get_logits(self, idx_target, X):
# ---> 96     ntk = NTK(self.model_params, X_trn=X, A_trn=self.A, n_classes=self.n_classes,
#      97                idx_trn_labeled=self.idx_labeled, y_trn=self.y[self.idx_labeled],
#      98                learning_setting="transductive",
#      99                pred_method=self.model_params["pred_method"],
#     100                regularizer=self.model_params["regularizer"],
#     101                bias=bool(self.model_params["bias"]),
#     102                solver=self.model_params["solver"],
#     103                alpha_tol=self.model_params["alpha_tol"],
#     104                dtype=self.dtype)
#     105     return ntk(idx_labeled=self.idx_labeled, idx_test=idx_target,
#     106                y_test=self.y, X_test=X, A_test=self.A)
#
# File /ceph/ssd/staff/gosl/src/ntk-robust/src/models/ntk.py:107, in NTK.__init__(self, model_dict, X_trn, A_trn, n_classes, idx_trn_labeled, y_trn, learning_setting, pred_method, regularizer, bias, append_dimension, solver, alpha_tol, device, dtype)
#     105 else:
#     106     self.device = X_trn.device
# --> 107 self.ntk = self.calc_ntk(X_trn, A_trn)
#     108 self.calculated_lb_ub = False
#     109 self.empty_gpu_memory()
#
# File /ceph/ssd/staff/gosl/src/ntk-robust/src/models/ntk.py:413, in NTK.calc_ntk(self, X, A)
#     410 self.empty_gpu_memory()
#     412 if self.model_dict["model"] == "GCN" or self.model_dict["model"] == "SoftMedoid":
# --> 413     kernel = self._calc_ntk_gcn(X, S)
#     414     self.empty_gpu_memory()
#     415     return kernel
#
# File /ceph/ssd/staff/gosl/src/ntk-robust/src/models/ntk.py:324, in NTK._calc_ntk_gcn(self, X, S)
#     322 # del XXT
#     323 self.empty_gpu_memory()
# --> 324 kernel = torch.zeros((S.shape), dtype=self.dtype).to(self.device)
#     325 depth = self.model_dict["depth"]
#     326 kernel_sub = torch.zeros((depth, S.shape[0], S.shape[1]),
#     327                         dtype=self.dtype).to(self.device)
#
# KeyboardInterrupt:
